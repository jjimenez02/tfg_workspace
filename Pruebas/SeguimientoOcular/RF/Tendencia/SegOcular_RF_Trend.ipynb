# %% [markdown]
# # <font color=#cd0000> Propósito principal </font>
# - La idea de este librillo es preparar el entorno para realizar pruebas para Seguimiento Ocular a ser clasificado con la Tendencia por RF
#
# ## <font color=#cd0000> Leyenda </font>
# - Los apartados titulados con el código de colores HEX: `#cd0000` serán apartados que tendrán todos los librillos, en concreto, aquellos especificados en el apartado `Síntesis de los criterios usados` del trabajo.
# - Los apartados titulados con el código de colores HEX: `#2451ff` serán apartados de conclusiones propias de este librillo resultado de aplicar un estudio personalizado para cada planteamiento.

# %% [markdown]
# # <font color=#cd0000> Prerrequisitos </font>
# ## <font color=#cd0000> Entorno de ejecución </font>
# - Cambiamos el directorio raíz del librillo para acceder cómodamente a las funciones de utilidad.

# %%
import os

os.chdir('../../../../')
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.gitmodules',
#  'data',
#  'HeartBeat_tmp_test_data.pkl',
#  'HeartBeat_tmp_train_data.pkl',
#  'pkl',
#  'Pruebas',
#  'README.md',
#  'smts_implementation',
#  'utils']

# %% [markdown]
# ## <font color=#cd0000> Constantes y variables predefinidas </font>

# %%
SEGUIMIENTO_OCULAR_PATH = "data/seguimiento-ocular/Data/Hospital"
SEGUIMIENTO_OCULAR_FOLDERS_ID = range(1, 12+1)

DATA_TO_SAVE = "SegOcular"

PKL_DIR = "pkl/RF/SegOcular/"
PKL_NAME = "segocular_RF_trend.pkl"

SEED = 1

# %% [markdown]
# # <font color=#cd0000> Carga del Dataset </font>

# %%
from utils.load_data import import_seguimiento_ocular_dataset

all_data = import_seguimiento_ocular_dataset(
    SEGUIMIENTO_OCULAR_PATH, SEGUIMIENTO_OCULAR_FOLDERS_ID)

# %%
all_data.reset_changes()

# %% [markdown]
# # <font color=#cd0000> Preprocesamiento </font>

# %% [markdown]
# ## <font color=#cd0000> Eliminación de datos inválidos y valores atípicos </font>
# - No eliminaremos aquellos valores fuera de los percentiles 5 y 95 ante la falta de información.

# %% [markdown]
# ### <font color=#2451ff> Limpieza de datos </font>
# - Eliminaremos todos aquellos valores inválidos con un "0" en alguna de las columnas `*Validity*`.

# %%
# Clean data
validity_headers = ['ValidityLeft',
                    'ValidityRight',
                    'PupilValidityLeft',
                    'PupilValidityRight']

all_data.clean_data(criterion='remove', value=0, headers=validity_headers)

# %% [markdown]
# ## <font color=#2451ff> Reducción de la dimensionalidad </font>
# - Eliminamos los atributos de validez y los redundantes/no informativos (o que puedan sesgar al modelo).

# %%
# Reduce data
columns_to_remove = validity_headers + ['GazePointX', 'GazePointY',
                                        'diagnosis', 'Age']

all_data.drop_derived_data_columns(columns_to_remove)
# Out:
#          id  TimeStamp  GazePointXLeft  GazePointYLeft  GazePointXRight  \
# 0       1-1    704.487             875             549              771
# 1       1-1    750.040             879             519              796
# 2       1-1    776.032             898             547              785
# 3       1-1    831.135             882             563              768
# 4       1-1    857.075             879             513              789
# ...     ...        ...             ...             ...              ...
# 36362  12-3  54379.209             162             808              263
# 36363  12-3  54406.850             136             816              272
# 36364  12-3  54433.946             122             942              191
# 36365  12-3  54460.926             326             918              364
# 36366  12-3  54487.080             354             938              363
#
#        GazePointYRight  PupilSizeLeft  PupilSizeRight    class
# 0                  284         2.1565          2.1575  Control
# 1                  245         2.0449          2.1528  Control
# 2                  316         2.1199          2.1833  Control
# 3                  322         2.1039          2.3215  Control
# 4                  362         2.0490          2.4636  Control
# ...                ...            ...             ...      ...
# 36362              944         2.6453          2.4885  Estudio
# 36363              969         2.6189          2.4906  Estudio
# 36364              854         2.5684          2.2774  Estudio
# 36365              936         2.3562          2.6705  Estudio
# 36366              988         2.2507          2.5588  Estudio
#
# [36367 rows x 9 columns]

# %% [markdown]
# ## <font color=#2451ff> Eliminación de series cortas </font>
# - Ante la limpieza de los datos hemos acabado con series, concretamente, la ``8-1`` (72 muestras) y ``8-2`` (202 muestras), con muy pocas muestras.
#   - Las eliminaremos con el fin de no obtener ventanas demasiado pequeñas (72/4 = 18 muestras por ventana)

# %%
all_data.derived_data = all_data.derived_data[
    all_data.derived_data['id'] != '8-1']  # 72 samples
all_data.derived_data = all_data.derived_data[
    all_data.derived_data['id'] != '8-2']  # 202 samples

# %%
import pandas as pd

# Remaining series
print("Previous number of series: {}".format(
    len(pd.unique(all_data.original_data['id']))))
print("Actual number of series: {}".format(
    len(pd.unique(all_data.derived_data['id']))))

print("Previous largest serie: {}".format(
    all_data.get_largest_serie(all_data.original_data).shape[0]))
print("Actual largest serie: {}".format(
    all_data.get_largest_serie().shape[0]))

print("Previous shortest serie: {}".format(
    all_data.get_shortest_serie(all_data.original_data).shape[0]))
print("Actual shortest serie: {}".format(
    all_data.get_shortest_serie().shape[0]))
# Out:
# Previous number of series: 25
# Actual number of series: 23
# Previous largest serie: 2113
# Actual largest serie: 1901
# Previous shortest serie: 967
# Actual shortest serie: 768

# %% [markdown]
# ## <font color=#cd0000> Resoluciones a aplicar </font>
# - Como vimos en el análisis en profundidad, mantendremos la resolución actual

# %%
# Nothing to see here

# %% [markdown]
# # <font color=#cd0000> División en ventanas </font>
# - El número de ventanas por serie será de 4 como ya vimos en el análisis en profundidad.

# %%
all_data.split_into_windows(n_windows=4)

# %% [markdown]
# # <font color=#2451ff> Particionado inicial de los datos </font>
# - Llevaremos a cabo el particionado empleado por Marta en su TFM: http://hdl.handle.net/10486/697441

# %%
from utils.data_extraction import Data

X_train, X_test, _, _ = all_data.train_test_split(
    criterion='tfm_marta',
    train_size=.8,
    random_state=SEED,
    drop_columns=[]
)

X_train_Data = Data(X_train)
X_test_Data = Data(X_test)

# %%
X_train_Data.get_derived_data_classes_count()
# Out:
# Estudio    45
# Control    24
# Name: class, dtype: int64

# %%
X_test_Data.get_derived_data_classes_count()
# Out:
# Estudio    15
# Control     8
# Name: class, dtype: int64

# %% [markdown]
# ## <font color=#cd0000> Codificación </font>

# %%
from utils.codifications import temporal_trend_fn

X_train_Data.apply_codifications([temporal_trend_fn])
X_test_Data.apply_codifications([temporal_trend_fn])

# %% [markdown]
# # <font color=#cd0000> Preparación de los datos </font>

# %%
X_train = X_train_Data.derived_data.drop(['id', 'class'], axis=1)
X_test = X_test_Data.derived_data.drop(['id', 'class'], axis=1)

y_train = X_train_Data.derived_data['class'].to_numpy()
y_test = X_test_Data.derived_data['class'].to_numpy()

# %% [markdown]
# ## <font color=#cd0000> Técnicas de balanceo </font>

# %% [markdown]
# ### <font color=#cd0000> Asignación de pesos a las clases </font>

# %%
import numpy as np
from sklearn.utils import compute_class_weight

class_weights = compute_class_weight(
    'balanced', classes=np.unique(y_train), y=y_train)
class_weights = {'Control': class_weights[0], 'Estudio': class_weights[1]}

# %% [markdown]
# # <font color=#cd0000> Diseño de la topología del bosque </font>
# - Número de estimadores inicial recomendado
# - Profundidad máxima recomendada

# %% [markdown]
# ## <font color=#cd0000> Entrenamiento </font>

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    random_state=SEED,
    class_weight=class_weights
)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight={'Control': 1.3592379800423344,
#                                      'Estudio': 0.7909554812598979},
#                        max_depth=10, random_state=1)

# %% [markdown]
# ## <font color=#cd0000> Clasificación </font>

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

y_pred = clf.predict(X_test)
y_true = np.asarray(y_test)
    
print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# [[1853 1454]
#  [1020 4663]]
#               precision    recall  f1-score   support
#
#      Control       0.64      0.56      0.60      3307
#      Estudio       0.76      0.82      0.79      5683
#
#     accuracy                           0.72      8990
#    macro avg       0.70      0.69      0.70      8990
# weighted avg       0.72      0.72      0.72      8990

# %% [markdown]
# ## <font color=#cd0000> Discusión de los resultados </font>
# - Vamos a estudiar diferentes rangos de hiper-parámetros interesantes que podrían darnos alguna pista sobre el rango en el que buscar el mejor clasificador de este tipo:
#   - Para un `n_estimators` pequeño (10) y una `max_depth` pequeño (10) no observamos una mejora notable con respecto a la clasificación sobre series en bruto:
#     ```
#     Confusion matrix:
#     [[1881 1426]
#      [1059 4624]]
#
#     Classification report:
#                    precision    recall  f1-score   support
#
#          Control       0.64      0.57      0.60      3307
#          Estudio       0.76      0.81      0.79      5683
#
#         accuracy                           0.72      8990
#        macro avg       0.70      0.69      0.70      8990
#     weighted avg       0.72      0.72      0.72      8990
#     ```
#   - Para un `n_estimators` pequeño (10) y una `max_depth` grande (200) vemos que empeora pero menos que con las series en bruto:
#     ```
#     Confusion matrix:
#     [[1605 1702]
#      [ 836 4847]]
#
#     Classification report:
#                   precision    recall  f1-score   support
#
#          Control       0.66      0.49      0.56      3307
#          Estudio       0.74      0.85      0.79      5683
#
#         accuracy                           0.72      8990
#        macro avg       0.70      0.67      0.68      8990
#     weighted avg       0.71      0.72      0.71      8990
#     ```
#   - Para un `n_estimators` grande (200) y una `max_depth` grande (200):
#     ```
#     Confusion matrix:
#     [[1328 1979]
#      [ 656 5027]]
#
#     Classification report:
#                    precision    recall  f1-score   support
#
#          Control       0.67      0.40      0.50      3307
#          Estudio       0.72      0.88      0.79      5683
#
#         accuracy                           0.71      8990
#        macro avg       0.69      0.64      0.65      8990
#     weighted avg       0.70      0.71      0.69      8990
#     ```
#   - Para un `n_estimators` grande (200) y una `max_depth` intermedio (100):
#     ```
#     Confusion matrix:
#     [[1328 1979]
#      [ 656 5027]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#          Control       0.67      0.40      0.50      3307
#          Estudio       0.72      0.88      0.79      5683
#
#         accuracy                           0.71      8990
#        macro avg       0.69      0.64      0.65      8990
#     weighted avg       0.70      0.71      0.69      8990
#     ```
#   - Para un `n_estimators` grande (200) y una `max_depth` pequeño (10):
#     ```
#     Confusion matrix:
#     [[1884 1423]
#      [1000 4683]]
#
#     Classification report:
#                    precision    recall  f1-score   support
#
#          Control       0.65      0.57      0.61      3307
#          Estudio       0.77      0.82      0.79      5683
#
#         accuracy                           0.73      8990
#        macro avg       0.71      0.70      0.70      8990
#     weighted avg       0.73      0.73      0.73      8990
#     ```
#   - Para un `n_estimators` intermedio (100) y una `max_depth` pequeño (10):
#     ```
#     Confusion matrix:
#     [[1853 1454]
#      [1020 4663]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#          Control       0.64      0.56      0.60      3307
#          Estudio       0.76      0.82      0.79      5683
#
#         accuracy                           0.72      8990
#        macro avg       0.70      0.69      0.70      8990
#     weighted avg       0.72      0.72      0.72      8990
#     ```

# %% [markdown]
# ## <font color=#cd0000> Conclusiones </font>
# - Observamos que, como ocurría con la clasificación sobre las series en bruto, a menor profundidad mejor
# - El rango de búsqueda orientativo podría ser:
#   - `n_estimators`: [10, 200]
#   - `max_depth`: [10, 50]

# %% [markdown]
# # <font color=#cd0000> Randomized Search </font>
# - Búsqueda de hiper-parámetros aleatoria con RF maximizando ``macro avg f1-score``

# %% [markdown]
# ## <font color=#cd0000> Rangos de búsqueda </font>
# - Como vimos anteriormente los rangos de búsqueda aleatoria de los mejores hiper-parámetros serán los siguientes

# %%
N_ESTIMATORS_RANGE = range(10, 100)
MAX_DEPTH_RANGE = range(10, 50)

# %% [markdown]
# # <font color=#cd0000> Randomized Search con múltiples ejecuciones en lugar de Validación Cruzada </font>
# - Ejecutaremos el mismo modelo sobre diferentes particiones del conjunto de datos original para observar su desempeño.
# - Realizaremos esto ya que aplicar validación cruzada con tan pocas series es inviable.

# %%
import random
import pickle
import utils.constants as cs
from sklearn.ensemble import RandomForestClassifier
from utils.classifier_utils import (train_validate,
                                    compute_classification_reports_means,
                                    tfm_marta_train_test_split)
from utils.plot_utils import pretty_print_classification_report_dict


def rf_randomized_search_train_validate(
        windowed_series,
        relation_with_series,
        prefix,
        class_weights,
        repetitions=5):
    global PKL_DIR
    all_clf_used = {}

    n_samples = 5
    n_estimators_list = random.sample(list(N_ESTIMATORS_RANGE), n_samples)
    max_depth_list = random.sample(list(MAX_DEPTH_RANGE), n_samples)

    best_hyp_params = None
    best_score = 0
    for n_estimators in n_estimators_list:
        for max_depth in max_depth_list:
            clf = RandomForestClassifier(
                n_estimators=n_estimators,
                max_depth=max_depth,
                random_state=SEED,
                class_weight=class_weights
            )

            reports = train_validate(
                clf,
                windowed_series,
                estimator_type=cs.ESTIMATOR_SKLEARN,
                relation_with_series=relation_with_series,
                train_test_split_method=tfm_marta_train_test_split,
                times_to_repeat=repetitions,
                train_size=0.8,
                drop_columns=['id', 'class'],
                seed=SEED
            )
            reports = list(map(lambda x: x['report'], reports))
            mean_report = compute_classification_reports_means(reports)
            all_clf_used[(n_estimators, max_depth)] = mean_report

            if mean_report['macro avg']['f1-score'][0] >= best_score:
                best_score = mean_report['macro avg']['f1-score'][0]
                best_hyp_params = (n_estimators, max_depth)
                best_report = mean_report

            print("\t\t--------------ACTUAL BEST: N_Estimators={}; Max_Depth={}--------------"
                  .format(best_hyp_params[0], best_hyp_params[1]))
            pretty_print_classification_report_dict(best_report)
            print("\t\t--------------ITERATION: N_Estimators={}; Max_Depth={}--------------"
                  .format(n_estimators, max_depth))
            pretty_print_classification_report_dict(mean_report)

    with open(PKL_DIR + prefix, 'wb') as file:
        pickle.dump(all_clf_used, file)

    return best_hyp_params, best_report

# %%
rf_randomized_search_train_validate(
    all_data.derived_data,
    all_data.derived_data_windows_per_serie,
    PKL_NAME,
    class_weights,
    repetitions=5
)
# Out:
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=20--------------
# Accuracy: 0.691445689559525 +/- 0.03881916357338162
# Control:
# 	precision: 0.6118109271554343 +/- 0.06202843462386763
# 	recall: 0.428657616892911 +/- 0.09755751251085631
# 	f1-score: 0.5007347350064592 +/- 0.08475986778636947
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7190874351181803 +/- 0.035693535211407744
# 	recall: 0.8443313443313443 +/- 0.02826871494319628
# 	f1-score: 0.7760987601936793 +/- 0.025114258597637204
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6654491811368073 +/- 0.04733582147355644
# 	recall: 0.6364944806121278 +/- 0.04971585098345917
# 	f1-score: 0.6384167476000693 +/- 0.05344741606565486
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6796309141044775 +/- 0.04385026015639791
# 	recall: 0.691445689559525 +/- 0.03881916357338162
# 	f1-score: 0.6748193034649946 +/- 0.04542825165473492
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=21; Max_Depth=20--------------
# Accuracy: 0.691445689559525 +/- 0.03881916357338162
# Control:
# 	precision: 0.6118109271554343 +/- 0.06202843462386763
# 	recall: 0.428657616892911 +/- 0.09755751251085631
# 	f1-score: 0.5007347350064592 +/- 0.08475986778636947
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7190874351181803 +/- 0.035693535211407744
# 	recall: 0.8443313443313443 +/- 0.02826871494319628
# 	f1-score: 0.7760987601936793 +/- 0.025114258597637204
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6654491811368073 +/- 0.04733582147355644
# 	recall: 0.6364944806121278 +/- 0.04971585098345917
# 	f1-score: 0.6384167476000693 +/- 0.05344741606565486
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6796309141044775 +/- 0.04385026015639791
# 	recall: 0.691445689559525 +/- 0.03881916357338162
# 	f1-score: 0.6748193034649946 +/- 0.04542825165473492
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=20--------------
# Accuracy: 0.691445689559525 +/- 0.03881916357338162
# Control:
# 	precision: 0.6118109271554343 +/- 0.06202843462386763
# 	recall: 0.428657616892911 +/- 0.09755751251085631
# 	f1-score: 0.5007347350064592 +/- 0.08475986778636947
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7190874351181803 +/- 0.035693535211407744
# 	recall: 0.8443313443313443 +/- 0.02826871494319628
# 	f1-score: 0.7760987601936793 +/- 0.025114258597637204
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6654491811368073 +/- 0.04733582147355644
# 	recall: 0.6364944806121278 +/- 0.04971585098345917
# 	f1-score: 0.6384167476000693 +/- 0.05344741606565486
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6796309141044775 +/- 0.04385026015639791
# 	recall: 0.691445689559525 +/- 0.03881916357338162
# 	f1-score: 0.6748193034649946 +/- 0.04542825165473492
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=21; Max_Depth=43--------------
# Accuracy: 0.6795961389104628 +/- 0.04792755104252929
# Control:
# 	precision: 0.5916036954582143 +/- 0.09220315158700483
# 	recall: 0.36633484162895924 +/- 0.11865026115942554
# 	f1-score: 0.4486957286044609 +/- 0.11873364726867541
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7024172223318434 +/- 0.04048109014676609
# 	recall: 0.8618462618462619 +/- 0.020310883326521048
# 	f1-score: 0.7734421506323528 +/- 0.02857500017471389
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6470104588950288 +/- 0.06625101432857536
# 	recall: 0.6140905517376106 +/- 0.06218890107852601
# 	f1-score: 0.6110689396184068 +/- 0.07288143417447222
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6616597784634222 +/- 0.059410086179131884
# 	recall: 0.6795961389104628 +/- 0.04792755104252929
# 	f1-score: 0.6539997464359185 +/- 0.06087641337752358
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=20--------------
# Accuracy: 0.691445689559525 +/- 0.03881916357338162
# Control:
# 	precision: 0.6118109271554343 +/- 0.06202843462386763
# 	recall: 0.428657616892911 +/- 0.09755751251085631
# 	f1-score: 0.5007347350064592 +/- 0.08475986778636947
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7190874351181803 +/- 0.035693535211407744
# 	recall: 0.8443313443313443 +/- 0.02826871494319628
# 	f1-score: 0.7760987601936793 +/- 0.025114258597637204
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6654491811368073 +/- 0.04733582147355644
# 	recall: 0.6364944806121278 +/- 0.04971585098345917
# 	f1-score: 0.6384167476000693 +/- 0.05344741606565486
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6796309141044775 +/- 0.04385026015639791
# 	recall: 0.691445689559525 +/- 0.03881916357338162
# 	f1-score: 0.6748193034649946 +/- 0.04542825165473492
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=21; Max_Depth=35--------------
# Accuracy: 0.660379451902807 +/- 0.03026563450163336
# Control:
# 	precision: 0.5462471897580221 +/- 0.052140808235895196
# 	recall: 0.42889894419306185 +/- 0.06864515708140612
# 	f1-score: 0.47968664211417716 +/- 0.06165461175355538
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7060284733080485 +/- 0.02657218857541389
# 	recall: 0.795050895050895 +/- 0.01719951862078079
# 	f1-score: 0.7476752618924415 +/- 0.019366045548669594
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6261378315330355 +/- 0.03892803449945563
# 	recall: 0.6119749196219784 +/- 0.037740795772557595
# 	f1-score: 0.6136809520033093 +/- 0.04003872391810288
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.647260587479985 +/- 0.03554015422501528
# 	recall: 0.660379451902807 +/- 0.03026563450163336
# 	f1-score: 0.6491084944936901 +/- 0.034410250501672304
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=20--------------
# Accuracy: 0.691445689559525 +/- 0.03881916357338162
# Control:
# 	precision: 0.6118109271554343 +/- 0.06202843462386763
# 	recall: 0.428657616892911 +/- 0.09755751251085631
# 	f1-score: 0.5007347350064592 +/- 0.08475986778636947
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7190874351181803 +/- 0.035693535211407744
# 	recall: 0.8443313443313443 +/- 0.02826871494319628
# 	f1-score: 0.7760987601936793 +/- 0.025114258597637204
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6654491811368073 +/- 0.04733582147355644
# 	recall: 0.6364944806121278 +/- 0.04971585098345917
# 	f1-score: 0.6384167476000693 +/- 0.05344741606565486
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6796309141044775 +/- 0.04385026015639791
# 	recall: 0.691445689559525 +/- 0.03881916357338162
# 	f1-score: 0.6748193034649946 +/- 0.04542825165473492
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=21; Max_Depth=33--------------
# Accuracy: 0.6806834572284479 +/- 0.01197015176946292
# Control:
# 	precision: 0.5928527239157105 +/- 0.0244926090587139
# 	recall: 0.430105580693816 +/- 0.06676320958112454
# 	f1-score: 0.4948207630797084 +/- 0.04344871757738389
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7145989019389788 +/- 0.01690796179434196
# 	recall: 0.8264654264654265 +/- 0.03618239920970854
# 	f1-score: 0.7657284901902225 +/- 0.011006082197832012
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6537258129273447 +/- 0.014426800604512633
# 	recall: 0.6282855035796213 +/- 0.01961660722046125
# 	f1-score: 0.6302746266349655 +/- 0.021199960988424443
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6698204064161635 +/- 0.013528916347912003
# 	recall: 0.6806834572284479 +/- 0.01197015176946292
# 	f1-score: 0.6660880690905494 +/- 0.015958977621509135
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=41--------------
# Accuracy: 0.7072672805946966 +/- 0.04328514415899101
# Control:
# 	precision: 0.6353575682934013 +/- 0.07449929077173607
# 	recall: 0.49616892911010557 +/- 0.08271301785626788
# 	f1-score: 0.5527893704361608 +/- 0.0697312336128959
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7397794518330277 +/- 0.033020855423177
# 	recall: 0.8300807300807301 +/- 0.05468607997444775
# 	f1-score: 0.7814795800330713 +/- 0.034930223284452486
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6875685100632145 +/- 0.04992350777655518
# 	recall: 0.6631248295954177 +/- 0.04682177900269662
# 	f1-score: 0.6671344752346161 +/- 0.04886948495044916
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7013728675731963 +/- 0.04427933324204344
# 	recall: 0.7072672805946966 +/- 0.04328514415899101
# 	f1-score: 0.6973668489985924 +/- 0.04418564010446622
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=21; Max_Depth=41--------------
# Accuracy: 0.7072672805946966 +/- 0.04328514415899101
# Control:
# 	precision: 0.6353575682934013 +/- 0.07449929077173607
# 	recall: 0.49616892911010557 +/- 0.08271301785626788
# 	f1-score: 0.5527893704361608 +/- 0.0697312336128959
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7397794518330277 +/- 0.033020855423177
# 	recall: 0.8300807300807301 +/- 0.05468607997444775
# 	f1-score: 0.7814795800330713 +/- 0.034930223284452486
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6875685100632145 +/- 0.04992350777655518
# 	recall: 0.6631248295954177 +/- 0.04682177900269662
# 	f1-score: 0.6671344752346161 +/- 0.04886948495044916
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7013728675731963 +/- 0.04427933324204344
# 	recall: 0.7072672805946966 +/- 0.04328514415899101
# 	f1-score: 0.6973668489985924 +/- 0.04418564010446622
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=41--------------
# Accuracy: 0.7072672805946966 +/- 0.04328514415899101
# Control:
# 	precision: 0.6353575682934013 +/- 0.07449929077173607
# 	recall: 0.49616892911010557 +/- 0.08271301785626788
# 	f1-score: 0.5527893704361608 +/- 0.0697312336128959
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7397794518330277 +/- 0.033020855423177
# 	recall: 0.8300807300807301 +/- 0.05468607997444775
# 	f1-score: 0.7814795800330713 +/- 0.034930223284452486
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6875685100632145 +/- 0.04992350777655518
# 	recall: 0.6631248295954177 +/- 0.04682177900269662
# 	f1-score: 0.6671344752346161 +/- 0.04886948495044916
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7013728675731963 +/- 0.04427933324204344
# 	recall: 0.7072672805946966 +/- 0.04328514415899101
# 	f1-score: 0.6973668489985924 +/- 0.04418564010446622
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=66; Max_Depth=20--------------
# Accuracy: 0.7114612226783534 +/- 0.02506257619987506
# Control:
# 	precision: 0.6470061459750416 +/- 0.03753060706864659
# 	recall: 0.4717345399698341 +/- 0.07299562445904427
# 	f1-score: 0.5431406803063936 +/- 0.06034377286903047
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7356143598909824 +/- 0.02431387338389131
# 	recall: 0.850930150930151 +/- 0.025195518138899895
# 	f1-score: 0.788624573654602 +/- 0.016440687366042258
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6913102529330118 +/- 0.02904749732741181
# 	recall: 0.6613323454499925 +/- 0.03344190115406018
# 	f1-score: 0.6658826269804978 +/- 0.036551654570737675
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7030240759531876 +/- 0.02732421941605933
# 	recall: 0.7114612226783534 +/- 0.02506257619987506
# 	f1-score: 0.6983350910795092 +/- 0.030556542116202824
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=41--------------
# Accuracy: 0.7072672805946966 +/- 0.04328514415899101
# Control:
# 	precision: 0.6353575682934013 +/- 0.07449929077173607
# 	recall: 0.49616892911010557 +/- 0.08271301785626788
# 	f1-score: 0.5527893704361608 +/- 0.0697312336128959
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7397794518330277 +/- 0.033020855423177
# 	recall: 0.8300807300807301 +/- 0.05468607997444775
# 	f1-score: 0.7814795800330713 +/- 0.034930223284452486
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6875685100632145 +/- 0.04992350777655518
# 	recall: 0.6631248295954177 +/- 0.04682177900269662
# 	f1-score: 0.6671344752346161 +/- 0.04886948495044916
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7013728675731963 +/- 0.04427933324204344
# 	recall: 0.7072672805946966 +/- 0.04328514415899101
# 	f1-score: 0.6973668489985924 +/- 0.04418564010446622
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=66; Max_Depth=43--------------
# Accuracy: 0.6692999001442361 +/- 0.03780495138794
# Control:
# 	precision: 0.5750602226477552 +/- 0.08116980885917625
# 	recall: 0.3555354449472096 +/- 0.0905895160555753
# 	f1-score: 0.43701412859313227 +/- 0.09141903741893813
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.6955010836504842 +/- 0.03065604769344199
# 	recall: 0.8518427518427518 +/- 0.024164124549613756
# 	f1-score: 0.7653780610468117 +/- 0.02331029953659865
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6352806531491197 +/- 0.05531302410503845
# 	recall: 0.6036890983949807 +/- 0.04785099312847555
# 	f1-score: 0.6011960948199719 +/- 0.05627761435610513
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6512026864215874 +/- 0.04860078070594511
# 	recall: 0.6692999001442361 +/- 0.03780495138794
# 	f1-score: 0.6446051290503679 +/- 0.047157933584754515
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=41--------------
# Accuracy: 0.7072672805946966 +/- 0.04328514415899101
# Control:
# 	precision: 0.6353575682934013 +/- 0.07449929077173607
# 	recall: 0.49616892911010557 +/- 0.08271301785626788
# 	f1-score: 0.5527893704361608 +/- 0.0697312336128959
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7397794518330277 +/- 0.033020855423177
# 	recall: 0.8300807300807301 +/- 0.05468607997444775
# 	f1-score: 0.7814795800330713 +/- 0.034930223284452486
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6875685100632145 +/- 0.04992350777655518
# 	recall: 0.6631248295954177 +/- 0.04682177900269662
# 	f1-score: 0.6671344752346161 +/- 0.04886948495044916
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7013728675731963 +/- 0.04427933324204344
# 	recall: 0.7072672805946966 +/- 0.04328514415899101
# 	f1-score: 0.6973668489985924 +/- 0.04418564010446622
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=66; Max_Depth=35--------------
# Accuracy: 0.6965938089426384 +/- 0.019486026903312526
# Control:
# 	precision: 0.6149753504322499 +/- 0.03676470483051843
# 	recall: 0.47239819004524897 +/- 0.05958390100565322
# 	f1-score: 0.5322235100714472 +/- 0.04148590253164448
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7300483875574285 +/- 0.020245714526816852
# 	recall: 0.827027027027027 +/- 0.029031484955361717
# 	f1-score: 0.7750340770847828 +/- 0.014306233271345684
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6725118689948392 +/- 0.024661919506071016
# 	recall: 0.6497126085361379 +/- 0.025059309190084998
# 	f1-score: 0.6536287935781149 +/- 0.025300386502915082
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6877242870281967 +/- 0.022422429326305556
# 	recall: 0.6965938089426384 +/- 0.019486026903312526
# 	f1-score: 0.6857278494525618 +/- 0.021498975955773467
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=41--------------
# Accuracy: 0.7072672805946966 +/- 0.04328514415899101
# Control:
# 	precision: 0.6353575682934013 +/- 0.07449929077173607
# 	recall: 0.49616892911010557 +/- 0.08271301785626788
# 	f1-score: 0.5527893704361608 +/- 0.0697312336128959
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7397794518330277 +/- 0.033020855423177
# 	recall: 0.8300807300807301 +/- 0.05468607997444775
# 	f1-score: 0.7814795800330713 +/- 0.034930223284452486
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6875685100632145 +/- 0.04992350777655518
# 	recall: 0.6631248295954177 +/- 0.04682177900269662
# 	f1-score: 0.6671344752346161 +/- 0.04886948495044916
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7013728675731963 +/- 0.04427933324204344
# 	recall: 0.7072672805946966 +/- 0.04328514415899101
# 	f1-score: 0.6973668489985924 +/- 0.04418564010446622
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=66; Max_Depth=33--------------
# Accuracy: 0.689137911905026 +/- 0.040298191394590864
# Control:
# 	precision: 0.6012633770037963 +/- 0.06929117944990727
# 	recall: 0.4383710407239819 +/- 0.09534364123666941
# 	f1-score: 0.5051889807345563 +/- 0.08563009141576489
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7202628675052042 +/- 0.03636923325467023
# 	recall: 0.8350298350298351 +/- 0.019032830183577182
# 	f1-score: 0.7729878422826058 +/- 0.02505379502853331
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6607631222545003 +/- 0.05189638117127217
# 	recall: 0.6367004378769086 +/- 0.05129657332465266
# 	f1-score: 0.6390884115085809 +/- 0.055027487151862495
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6764946093212292 +/- 0.04753057911224034
# 	recall: 0.689137911905026 +/- 0.040298191394590864
# 	f1-score: 0.6744908683525287 +/- 0.04699166081684403
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=41--------------
# Accuracy: 0.7072672805946966 +/- 0.04328514415899101
# Control:
# 	precision: 0.6353575682934013 +/- 0.07449929077173607
# 	recall: 0.49616892911010557 +/- 0.08271301785626788
# 	f1-score: 0.5527893704361608 +/- 0.0697312336128959
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7397794518330277 +/- 0.033020855423177
# 	recall: 0.8300807300807301 +/- 0.05468607997444775
# 	f1-score: 0.7814795800330713 +/- 0.034930223284452486
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6875685100632145 +/- 0.04992350777655518
# 	recall: 0.6631248295954177 +/- 0.04682177900269662
# 	f1-score: 0.6671344752346161 +/- 0.04886948495044916
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7013728675731963 +/- 0.04427933324204344
# 	recall: 0.7072672805946966 +/- 0.04328514415899101
# 	f1-score: 0.6973668489985924 +/- 0.04418564010446622
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=66; Max_Depth=41--------------
# Accuracy: 0.6734716520581383 +/- 0.04185850716485452
# Control:
# 	precision: 0.5767862781968944 +/- 0.0830882712890483
# 	recall: 0.4160482654600302 +/- 0.09634510774114934
# 	f1-score: 0.4800660153539553 +/- 0.08273158834224943
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7093897125253337 +/- 0.036363574774864155
# 	recall: 0.8232362232362233 +/- 0.039006926578738804
# 	f1-score: 0.761321364882041 +/- 0.028354124258421255
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.643087995361114 +/- 0.05685621005611468
# 	recall: 0.6196422443481268 +/- 0.05080250480874896
# 	f1-score: 0.6206936901179982 +/- 0.05379496713806568
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6606178957275108 +/- 0.05056013238535032
# 	recall: 0.6734716520581383 +/- 0.04185850716485452
# 	f1-score: 0.6578750669029437 +/- 0.046479935679882664
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=41--------------
# Accuracy: 0.7072672805946966 +/- 0.04328514415899101
# Control:
# 	precision: 0.6353575682934013 +/- 0.07449929077173607
# 	recall: 0.49616892911010557 +/- 0.08271301785626788
# 	f1-score: 0.5527893704361608 +/- 0.0697312336128959
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7397794518330277 +/- 0.033020855423177
# 	recall: 0.8300807300807301 +/- 0.05468607997444775
# 	f1-score: 0.7814795800330713 +/- 0.034930223284452486
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6875685100632145 +/- 0.04992350777655518
# 	recall: 0.6631248295954177 +/- 0.04682177900269662
# 	f1-score: 0.6671344752346161 +/- 0.04886948495044916
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7013728675731963 +/- 0.04427933324204344
# 	recall: 0.7072672805946966 +/- 0.04328514415899101
# 	f1-score: 0.6973668489985924 +/- 0.04418564010446622
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=94; Max_Depth=20--------------
# Accuracy: 0.7008099411960501 +/- 0.036234896158117605
# Control:
# 	precision: 0.6238142718568902 +/- 0.06104160485226719
# 	recall: 0.46962292609351436 +/- 0.0740923939984836
# 	f1-score: 0.5339210062073423 +/- 0.06591358216945331
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7309806257150109 +/- 0.029530982030048766
# 	recall: 0.8353106353106353 +/- 0.03484084718585429
# 	f1-score: 0.7792525484414836 +/- 0.026481235047741202
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6773974487859505 +/- 0.04371415960299726
# 	recall: 0.6524667807020749 +/- 0.04204125939182875
# 	f1-score: 0.656586777324413 +/- 0.044457619645047214
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6915646196083127 +/- 0.039506565890351016
# 	recall: 0.7008099411960501 +/- 0.036234896158117605
# 	f1-score: 0.6890191009205496 +/- 0.03915401476634741
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=41--------------
# Accuracy: 0.7072672805946966 +/- 0.04328514415899101
# Control:
# 	precision: 0.6353575682934013 +/- 0.07449929077173607
# 	recall: 0.49616892911010557 +/- 0.08271301785626788
# 	f1-score: 0.5527893704361608 +/- 0.0697312336128959
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7397794518330277 +/- 0.033020855423177
# 	recall: 0.8300807300807301 +/- 0.05468607997444775
# 	f1-score: 0.7814795800330713 +/- 0.034930223284452486
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6875685100632145 +/- 0.04992350777655518
# 	recall: 0.6631248295954177 +/- 0.04682177900269662
# 	f1-score: 0.6671344752346161 +/- 0.04886948495044916
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7013728675731963 +/- 0.04427933324204344
# 	recall: 0.7072672805946966 +/- 0.04328514415899101
# 	f1-score: 0.6973668489985924 +/- 0.04418564010446622
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=94; Max_Depth=43--------------
# Accuracy: 0.6665705092643959 +/- 0.052748437309643945
# Control:
# 	precision: 0.5590277991532667 +/- 0.08617756875867473
# 	recall: 0.3944494720965309 +/- 0.11042101967102606
# 	f1-score: 0.46032015840822227 +/- 0.10403714165667702
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7023693443482806 +/- 0.044388005549909244
# 	recall: 0.8248859248859249 +/- 0.030107033367736673
# 	f1-score: 0.7582864820595979 +/- 0.035288501432809025
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6306985717507737 +/- 0.06511302586076093
# 	recall: 0.6096676984912279 +/- 0.0640580293084552
# 	f1-score: 0.6093033202339101 +/- 0.06869428071349258
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.649648028213645 +/- 0.059585777407683706
# 	recall: 0.6665705092643959 +/- 0.052748437309643945
# 	f1-score: 0.6486938533117548 +/- 0.059536713170763124
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=94; Max_Depth=33--------------
# Accuracy: 0.6930211916121158 +/- 0.06124753771738319
# Control:
# 	precision: 0.5895420802909502 +/- 0.09788622342468664
# 	recall: 0.4751734539969834 +/- 0.14907961005241682
# 	f1-score: 0.5225810008973971 +/- 0.13223247469212765
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7324973905815103 +/- 0.05734999491602377
# 	recall: 0.8197613197613197 +/- 0.019381132065908458
# 	f1-score: 0.7727452345165584 +/- 0.03756403699649462
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6610197354362304 +/- 0.077397772811286
# 	recall: 0.6474673868791516 +/- 0.07930565372827811
# 	f1-score: 0.6476631177069777 +/- 0.08445329293156045
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6799181324418003 +/- 0.07203914873730093
# 	recall: 0.6930211916121158 +/- 0.06124753771738319
# 	f1-score: 0.6807343131310575 +/- 0.07189751263623963
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=94; Max_Depth=41--------------
# Accuracy: 0.6708754021968268 +/- 0.020436363288432933
# Control:
# 	precision: 0.5913562257977738 +/- 0.04266809023640005
# 	recall: 0.32874811463046755 +/- 0.05547195537152723
# 	f1-score: 0.4214862715116544 +/- 0.05688501020067962
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.6906114815305024 +/- 0.017405378961725865
# 	recall: 0.8699192699192698 +/- 0.008202751289060888
# 	f1-score: 0.7698265615759321 +/- 0.011337209777897615
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6409838536641381 +/- 0.029911350674966104
# 	recall: 0.5993336922748688 +/- 0.027543974594399653
# 	f1-score: 0.5956564165437932 +/- 0.03381505928350021
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6541051936403444 +/- 0.026565800066247473
# 	recall: 0.6708754021968268 +/- 0.020436363288432933
# 	f1-score: 0.641706284025385 +/- 0.02775485871948098
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=75; Max_Depth=20--------------
# Accuracy: 0.6738710751137247 +/- 0.03298108739242029
# Control:
# 	precision: 0.5849732145723161 +/- 0.07200009359319116
# 	recall: 0.4169532428355957 +/- 0.04210599520832677
# 	f1-score: 0.48483802030442025 +/- 0.04220623646957846
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.708089519780295 +/- 0.01866362595477693
# 	recall: 0.8233415233415233 +/- 0.04732606862154622
# 	f1-score: 0.760955261829709 +/- 0.02786892931970624
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6465313671763054 +/- 0.04400351641496633
# 	recall: 0.6201473830885595 +/- 0.030860299502727413
# 	f1-score: 0.6228966410670645 +/- 0.032912777446086755
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6628070886514311 +/- 0.03681105685334926
# 	recall: 0.6738710751137247 +/- 0.03298108739242029
# 	f1-score: 0.6593987705774808 +/- 0.031050257364186245
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=75; Max_Depth=43--------------
# Accuracy: 0.6621102851436814 +/- 0.021132289462796786
# Control:
# 	precision: 0.5554970236859539 +/- 0.035427952737556306
# 	recall: 0.38310708898944196 +/- 0.0850826340648389
# 	f1-score: 0.44946880819740154 +/- 0.07411724217448522
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.6979631878036303 +/- 0.023109861649734394
# 	recall: 0.8244296244296244 +/- 0.029042516509329656
# 	f1-score: 0.7552613590827152 +/- 0.011950632290902877
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.626730105744792 +/- 0.028615928850748446
# 	recall: 0.6037683567095332 +/- 0.03294585061452617
# 	f1-score: 0.6023650836400584 +/- 0.04011718249226271
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6455638386357508 +/- 0.026997053322826998
# 	recall: 0.6621102851436814 +/- 0.021132289462796786
# 	f1-score: 0.6427902278073556 +/- 0.03140941812769696
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=75; Max_Depth=35--------------
# Accuracy: 0.7051148341284811 +/- 0.025753257502318935
# Control:
# 	precision: 0.6353135430515728 +/- 0.05587569508194134
# 	recall: 0.476078431372549 +/- 0.03079016234182535
# 	f1-score: 0.543151462276372 +/- 0.03187378358052696
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7332832724867545 +/- 0.014572707347559468
# 	recall: 0.8383643383643383 +/- 0.03633709837161073
# 	f1-score: 0.7820649755029423 +/- 0.021681553505491096
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6842984077691636 +/- 0.03390497627844594
# 	recall: 0.6572213848684436 +/- 0.023977244232632724
# 	f1-score: 0.6626082188896572 +/- 0.02568823861153165
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6972498038217564 +/- 0.028303282011799078
# 	recall: 0.7051148341284811 +/- 0.025753257502318935
# 	f1-score: 0.694192092295788 +/- 0.024362608269674377
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=75; Max_Depth=33--------------
# Accuracy: 0.6828359036946633 +/- 0.03977965329221055
# Control:
# 	precision: 0.5991080371513665 +/- 0.07886256668330204
# 	recall: 0.41713423831070895 +/- 0.056426353354598
# 	f1-score: 0.4915414042829315 +/- 0.0648073077676042
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.711824666075717 +/- 0.026731754311934756
# 	recall: 0.8374166374166375 +/- 0.033425223633508146
# 	f1-score: 0.7694705387763123 +/- 0.02901424118521088
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6554663516135417 +/- 0.052636811835975586
# 	recall: 0.6272754378636731 +/- 0.04281896730094574
# 	f1-score: 0.630505971529622 +/- 0.04659319613925164
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6703672573456358 +/- 0.045733985408506865
# 	recall: 0.6828359036946633 +/- 0.03977965329221055
# 	f1-score: 0.6672476295512422 +/- 0.041850321921781154
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=75; Max_Depth=41--------------
# Accuracy: 0.6827915233551537 +/- 0.03697517563358249
# Control:
# 	precision: 0.5901143070112462 +/- 0.05808409903178485
# 	recall: 0.43408748114630474 +/- 0.1059247142531991
# 	f1-score: 0.4958515466932609 +/- 0.08627159159189013
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7174275309046949 +/- 0.03675767469868166
# 	recall: 0.8274833274833275 +/- 0.032737627933365814
# 	f1-score: 0.7676276671499958 +/- 0.02350643417948481
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6537709189579705 +/- 0.04548250551733594
# 	recall: 0.630785404314816 +/- 0.049501650744472984
# 	f1-score: 0.6317396069216283 +/- 0.05267464077515357
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6706014644221938 +/- 0.04268263344709252
# 	recall: 0.6827915233551537 +/- 0.03697517563358249
# 	f1-score: 0.6676678491854916 +/- 0.04415020504194698
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=23; Max_Depth=20--------------
# Accuracy: 0.6772217907466992 +/- 0.021928716018559488
# Control:
# 	precision: 0.5897437596905591 +/- 0.042348558873854844
# 	recall: 0.40464555052790346 +/- 0.04279972155727393
# 	f1-score: 0.47905700378956 +/- 0.039907309707586484
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7071954943246013 +/- 0.016167341485266173
# 	recall: 0.8358020358020358 +/- 0.02443592750211272
# 	f1-score: 0.7659730092348459 +/- 0.016387993133518342
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6484696270075803 +/- 0.02829560511317924
# 	recall: 0.6202237931649697 +/- 0.024519888026936807
# 	f1-score: 0.6225150065122029 +/- 0.026645337808343543
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6639965039427251 +/- 0.024778271607113513
# 	recall: 0.6772217907466992 +/- 0.021928716018559488
# 	f1-score: 0.6604447103275872 +/- 0.02345979267080807
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=23; Max_Depth=43--------------
# Accuracy: 0.6722068123821148 +/- 0.024999528365195776
# Control:
# 	precision: 0.6010163627955183 +/- 0.06962416932486316
# 	recall: 0.36953242835595773 +/- 0.05369362954262829
# 	f1-score: 0.4514588686275932 +/- 0.036486862657009296
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.6982431131009488 +/- 0.010897069998937272
# 	recall: 0.8482976482976483 +/- 0.05895568908683091
# 	f1-score: 0.7650585745291986 +/- 0.025622056710438657
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6496297379482335 +/- 0.03673566304634981
# 	recall: 0.608915038326803 +/- 0.018674487476479512
# 	f1-score: 0.608258721578396 +/- 0.0212259274681843
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6624829136931487 +/- 0.028348201128267254
# 	recall: 0.6722068123821148 +/- 0.024999528365195776
# 	f1-score: 0.6497159555273322 +/- 0.019982884207887724
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=23; Max_Depth=35--------------
# Accuracy: 0.6689670475979141 +/- 0.03906646030899903
# Control:
# 	precision: 0.5729887617691809 +/- 0.08225785278718951
# 	recall: 0.3784615384615385 +/- 0.09206280670532281
# 	f1-score: 0.4526702811550257 +/- 0.0855117125580168
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.6997942408369041 +/- 0.03226969317873856
# 	recall: 0.837978237978238 +/- 0.03452733914759584
# 	f1-score: 0.7620849859964433 +/- 0.025678666049574958
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6363915013030426 +/- 0.0554340793968431
# 	recall: 0.6082198882198883 +/- 0.048091662919452334
# 	f1-score: 0.6073776335757345 +/- 0.05376872824256687
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6531549239491307 +/- 0.04872561785203862
# 	recall: 0.6689670475979141 +/- 0.03906646030899903
# 	f1-score: 0.6482816190210412 +/- 0.0456958466193417
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=23; Max_Depth=33--------------
# Accuracy: 0.6905580827693332 +/- 0.016465046146173643
# Control:
# 	precision: 0.6051147733473139 +/- 0.026987852592231607
# 	recall: 0.4567722473604826 +/- 0.06825644165284268
# 	f1-score: 0.5179426381673489 +/- 0.048307467856941594
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7244056721710643 +/- 0.02045183762261351
# 	recall: 0.8265707265707265 +/- 0.02777417671415323
# 	f1-score: 0.7715277955793927 +/- 0.010599974487650632
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6647602227591891 +/- 0.02037952693519857
# 	recall: 0.6416714869656046 +/- 0.02529730206154021
# 	f1-score: 0.6447352168733709 +/- 0.02672598393459464
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6805302334047566 +/- 0.019631072033421598
# 	recall: 0.6905580827693332 +/- 0.016465046146173643
# 	f1-score: 0.6782586513631579 +/- 0.021358711517167787
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=94; Max_Depth=35--------------
# Accuracy: 0.7164318207034284 +/- 0.027464707755861698
# Control:
# 	precision: 0.6643747641349146 +/- 0.056202930610759406
# 	recall: 0.47239819004524886 +/- 0.0642999710799288
# 	f1-score: 0.5488754900764387 +/- 0.05194483024973051
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7372089539426606 +/- 0.020814613739599537
# 	recall: 0.8584064584064585 +/- 0.04230266365335538
# 	f1-score: 0.792556419622041 +/- 0.022262911726408815
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.7007918590387875 +/- 0.03456488990371731
# 	recall: 0.6654023242258537 +/- 0.03035920970066972
# 	f1-score: 0.67071595484924 +/- 0.03345453163064658
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7104203886244893 +/- 0.02960499475347348
# 	recall: 0.7164318207034284 +/- 0.027464707755861698
# 	f1-score: 0.7029300708542976 +/- 0.02934995201783726
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=23; Max_Depth=41--------------
# Accuracy: 0.6745811605458781 +/- 0.02609369603249096
# Control:
# 	precision: 0.5709389371023279 +/- 0.04157635489184552
# 	recall: 0.45954751131221716 +/- 0.06789129307423025
# 	f1-score: 0.5076252151095215 +/- 0.05166941542512514
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.7186897876718586 +/- 0.02581773947249948
# 	recall: 0.7996840996840996 +/- 0.026402506781440873
# 	f1-score: 0.7565671488510779 +/- 0.01798389523825586
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6448143623870932 +/- 0.031867192104894054
# 	recall: 0.6296158054981584 +/- 0.032995345593660845
# 	f1-score: 0.6320961819802997 +/- 0.03318617450961232
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6643467199210548 +/- 0.029796735507008072
# 	recall: 0.6745811605458781 +/- 0.02609369603249096
# 	f1-score: 0.665005791883003 +/- 0.028614249695153228
# 	support: 9013.0 +/- 0.0
# ((94, 35),
#  {'accuracy': (0.7164318207034284, 0.027464707755861698),
#   'Control': {'precision': (0.6643747641349146, 0.056202930610759406),
#    'recall': (0.47239819004524886, 0.0642999710799288),
#    'f1-score': (0.5488754900764387, 0.05194483024973051),
#    'support': (3315.0, 0.0)},
#   'Estudio': {'precision': (0.7372089539426606, 0.020814613739599537),
#    'recall': (0.8584064584064585, 0.04230266365335538),
#    'f1-score': (0.792556419622041, 0.022262911726408815),
#    'support': (5698.0, 0.0)},
#   'macro avg': {'precision': (0.7007918590387875, 0.03456488990371731),
#    'recall': (0.6654023242258537, 0.03035920970066972),
#    'f1-score': (0.67071595484924, 0.03345453163064658),
#    'support': (9013.0, 0.0)},
#   'weighted avg': {'precision': (0.7104203886244893, 0.02960499475347348),
#    'recall': (0.7164318207034284, 0.027464707755861698),
#    'f1-score': (0.7029300708542976, 0.02934995201783726),
#    'support': (9013.0, 0.0)}})

# %% [markdown]
# # <font color=#cd0000> Análisis de resultados </font>
# - Según la búsqueda aleatoria de hiper-parámetros, la mejor combinación, es la de ``n_estimators`` = 94 y ``max_depth`` = 35:
#     ```
#         Accuracy: 0.7164318207034284 +/- 0.027464707755861698
#         Control:
#             precision: 0.6643747641349146 +/- 0.056202930610759406
#             recall: 0.47239819004524886 +/- 0.0642999710799288
#             f1-score: 0.5488754900764387 +/- 0.05194483024973051
#             support: 3315.0 +/- 0.0
#         Estudio:
#             precision: 0.7372089539426606 +/- 0.020814613739599537
#             recall: 0.8584064584064585 +/- 0.04230266365335538
#             f1-score: 0.792556419622041 +/- 0.022262911726408815
#             support: 5698.0 +/- 0.0
#         macro avg:
#             precision: 0.7007918590387875 +/- 0.03456488990371731
#             recall: 0.6654023242258537 +/- 0.03035920970066972
#             f1-score: 0.67071595484924 +/- 0.03345453163064658
#             support: 9013.0 +/- 0.0
#         weighted avg:
#             precision: 0.7104203886244893 +/- 0.02960499475347348
#             recall: 0.7164318207034284 +/- 0.027464707755861698
#             f1-score: 0.7029300708542976 +/- 0.02934995201783726
#             support: 9013.0 +/- 0.0
#     ```
# - Ahora vamos a visualizar la evolución de los resultados (25 resultados) para observar cómo avanza nuestra métrica objetivo -> Macro Average F1-Score.

# %%
import pickle

all_reports = pickle.load(open(PKL_DIR + PKL_NAME, 'rb'))

# %%
from utils.plot_utils import plot_score

macro_avg_f1_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['macro avg']['f1-score'][0],
                   'std': all_reports[z]['macro avg']['f1-score'][1]}),
    all_reports
))

plot_score(
    [macro_avg_f1_scores],
    ('n_estimators', 'max_depth'),
    'RandomForest',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Macro Average F1-Score'
)

# %%
estudio_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['Estudio']['recall'][0],
                   'std': all_reports[z]['Estudio']['recall'][1]}),
    all_reports
))

control_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['Control']['recall'][0],
                   'std': all_reports[z]['Control']['recall'][1]}),
    all_reports
))

plot_score(
    [estudio_recall_scores],
    ('n_estimators', 'max_depth'),
    'RandomForest',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Estudio recall score'
)

plot_score(
    [control_recall_scores],
    ('n_estimators', 'max_depth'),
    'RandomForest',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Control recall score'
)

# %% [markdown]
# # <font color=#cd0000> Conclusiones </font>
# - TODO
