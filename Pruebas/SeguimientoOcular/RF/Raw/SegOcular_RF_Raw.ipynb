# %% [markdown]
# # <font color=#cd0000> Propósito principal </font>
# - La idea de este librillo es preparar el entorno para realizar pruebas para Seguimiento Ocular a ser clasificado sobre las series en bruto por RF
#
# ## <font color=#cd0000> Leyenda </font>
# - Los apartados titulados con el código de colores HEX: `#cd0000` serán apartados que tendrán todos los librillos, en concreto, aquellos especificados en el apartado `Síntesis de los criterios usados` del trabajo.
# - Los apartados titulados con el código de colores HEX: `#2451ff` serán apartados de conclusiones propias de este librillo resultado de aplicar un estudio personalizado para cada planteamiento.

# %% [markdown]
# # <font color=#cd0000> Prerrequisitos </font>
# ## <font color=#cd0000> Entorno de ejecución </font>
# - Cambiamos el directorio raíz del librillo para acceder cómodamente a las funciones de utilidad.

# %%
import os

os.chdir('../../../../')
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.gitmodules',
#  'data',
#  'HeartBeat_tmp_test_data.pkl',
#  'HeartBeat_tmp_train_data.pkl',
#  'pkl',
#  'Pruebas',
#  'README.md',
#  'smts_implementation',
#  'utils']

# %% [markdown]
# ## <font color=#cd0000> Constantes y variables predefinidas </font>

# %%
SEGUIMIENTO_OCULAR_PATH = "data/seguimiento-ocular/Data/Hospital"
SEGUIMIENTO_OCULAR_FOLDERS_ID = range(1, 12+1)

DATA_TO_SAVE = "SegOcular"

PKL_DIR = "pkl/RF/SegOcular/"
PKL_NAME = "segocular_RF_raw.pkl"

SEED = 1

# %% [markdown]
# # <font color=#cd0000> Carga del Dataset </font>

# %%
from utils.load_data import import_seguimiento_ocular_dataset

all_data = import_seguimiento_ocular_dataset(
    SEGUIMIENTO_OCULAR_PATH, SEGUIMIENTO_OCULAR_FOLDERS_ID)

# %%
all_data.reset_changes()

# %% [markdown]
# # <font color=#cd0000> Preprocesamiento </font>

# %% [markdown]
# ## <font color=#cd0000> Eliminación de datos inválidos y valores atípicos </font>
# - No eliminaremos aquellos valores fuera de los percentiles 5 y 95 ante la falta de información.

# %% [markdown]
# ### <font color=#2451ff> Limpieza de datos </font>
# - Eliminaremos todos aquellos valores inválidos con un "0" en alguna de las columnas `*Validity*`.

# %%
# Clean data
validity_headers = ['ValidityLeft',
                    'ValidityRight',
                    'PupilValidityLeft',
                    'PupilValidityRight']

all_data.clean_data(criterion='remove', value=0, headers=validity_headers)

# %% [markdown]
# ## <font color=#2451ff> Reducción de la dimensionalidad </font>
# - Eliminamos los atributos de validez y los redundantes/no informativos (o que puedan sesgar al modelo).

# %%
# Reduce data
columns_to_remove = validity_headers + ['GazePointX', 'GazePointY',
                                        'diagnosis', 'Age']

all_data.drop_derived_data_columns(columns_to_remove)
# Out:
#          id  TimeStamp  GazePointXLeft  GazePointYLeft  GazePointXRight  \
# 0       1-1    704.487             875             549              771
# 1       1-1    750.040             879             519              796
# 2       1-1    776.032             898             547              785
# 3       1-1    831.135             882             563              768
# 4       1-1    857.075             879             513              789
# ...     ...        ...             ...             ...              ...
# 36362  12-3  54379.209             162             808              263
# 36363  12-3  54406.850             136             816              272
# 36364  12-3  54433.946             122             942              191
# 36365  12-3  54460.926             326             918              364
# 36366  12-3  54487.080             354             938              363
#
#        GazePointYRight  PupilSizeLeft  PupilSizeRight    class
# 0                  284         2.1565          2.1575  Control
# 1                  245         2.0449          2.1528  Control
# 2                  316         2.1199          2.1833  Control
# 3                  322         2.1039          2.3215  Control
# 4                  362         2.0490          2.4636  Control
# ...                ...            ...             ...      ...
# 36362              944         2.6453          2.4885  Estudio
# 36363              969         2.6189          2.4906  Estudio
# 36364              854         2.5684          2.2774  Estudio
# 36365              936         2.3562          2.6705  Estudio
# 36366              988         2.2507          2.5588  Estudio
#
# [36367 rows x 9 columns]

# %% [markdown]
# ## <font color=#2451ff> Eliminación de series cortas </font>
# - Ante la limpieza de los datos hemos acabado con series, concretamente, la ``8-1`` (72 muestras) y ``8-2`` (202 muestras), con muy pocas muestras.
#   - Las eliminaremos con el fin de no obtener ventanas demasiado pequeñas (72/4 = 18 muestras por ventana)

# %%
all_data.derived_data = all_data.derived_data[
    all_data.derived_data['id'] != '8-1']  # 72 samples
all_data.derived_data = all_data.derived_data[
    all_data.derived_data['id'] != '8-2']  # 202 samples

# %%
import pandas as pd

# Remaining series
print("Previous number of series: {}".format(
    len(pd.unique(all_data.original_data['id']))))
print("Actual number of series: {}".format(
    len(pd.unique(all_data.derived_data['id']))))

print("Previous largest serie: {}".format(
    all_data.get_largest_serie(all_data.original_data).shape[0]))
print("Actual largest serie: {}".format(
    all_data.get_largest_serie().shape[0]))

print("Previous shortest serie: {}".format(
    all_data.get_shortest_serie(all_data.original_data).shape[0]))
print("Actual shortest serie: {}".format(
    all_data.get_shortest_serie().shape[0]))
# Out:
# Previous number of series: 25
# Actual number of series: 23
# Previous largest serie: 2113
# Actual largest serie: 1901
# Previous shortest serie: 967
# Actual shortest serie: 768

# %% [markdown]
# ## <font color=#cd0000> Resoluciones a aplicar </font>
# - Como vimos en el análisis en profundidad, mantendremos la resolución actual

# %%
# Nothing to see here

# %% [markdown]
# # <font color=#cd0000> División en ventanas </font>
# - El número de ventanas por serie será de 4 como ya vimos en el análisis en profundidad.

# %%
all_data.split_into_windows(n_windows=4)

# %% [markdown]
# # <font color=#2451ff> Particionado inicial de los datos </font>
# - Llevaremos a cabo el particionado empleado por Marta en su TFM: http://hdl.handle.net/10486/697441

# %%
from utils.data_extraction import Data

X_train, X_test, _, _ = all_data.train_test_split(
    criterion='tfm_marta',
    train_size=.8,
    random_state=SEED,
    drop_columns=[]
)

X_train_Data = Data(X_train)
X_test_Data = Data(X_test)

# %%
X_train_Data.get_derived_data_classes_count()
# Out:
# Estudio    45
# Control    24
# Name: class, dtype: int64

# %%
X_test_Data.get_derived_data_classes_count()
# Out:
# Estudio    15
# Control     8
# Name: class, dtype: int64

# %% [markdown]
# ## <font color=#cd0000> Codificación </font>
# - Series en bruto

# %%
# Nothing to see here

# %% [markdown]
# # <font color=#cd0000> Preparación de los datos </font>

# %%
X_train = X_train_Data.derived_data.drop(['id', 'class'], axis=1)
X_test = X_test_Data.derived_data.drop(['id', 'class'], axis=1)

y_train = X_train_Data.derived_data['class'].to_numpy()
y_test = X_test_Data.derived_data['class'].to_numpy()

# %% [markdown]
# ## <font color=#cd0000> Técnicas de balanceo </font>

# %% [markdown]
# ### <font color=#cd0000> Asignación de pesos a las clases </font>

# %%
import numpy as np
from sklearn.utils import compute_class_weight

class_weights = compute_class_weight(
    'balanced', classes=np.unique(y_train), y=y_train)
class_weights = {'Control': class_weights[0], 'Estudio': class_weights[1]}

# %% [markdown]
# # <font color=#cd0000> Diseño de la topología del bosque </font>
# - Número de estimadores inicial recomendado
# - Profundidad máxima recomendada

# %% [markdown]
# ## <font color=#cd0000> Entrenamiento </font>

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    random_state=SEED,
    class_weight=class_weights
)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight={'Control': 1.3594268476621418,
#                                      'Estudio': 0.7908915408915409},
#                        max_depth=10, random_state=1)

# %% [markdown]
# ## <font color=#cd0000> Clasificación </font>

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

y_pred = clf.predict(X_test)
y_true = np.asarray(y_test)
    
print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# [[1595 1720]
#  [1010 4688]]
#               precision    recall  f1-score   support
#
#      Control       0.61      0.48      0.54      3315
#      Estudio       0.73      0.82      0.77      5698
#
#     accuracy                           0.70      9013
#    macro avg       0.67      0.65      0.66      9013
# weighted avg       0.69      0.70      0.69      9013

# %% [markdown]
# ## <font color=#cd0000> Discusión de los resultados </font>
# - Vamos a estudiar diferentes rangos de hiper-parámetros interesantes que podrían darnos alguna pista sobre el rango en el que buscar el mejor clasificador de este tipo:
#   - Para un `n_estimators` pequeño (10) y una `max_depth` pequeño (10):
#     ```
#     Confusion matrix:
#     [[1714 1601]
#      [ 992 4706]]
#
#     Classification report:
#                    precision    recall  f1-score   support
#
#          Control       0.63      0.52      0.57      3315
#          Estudio       0.75      0.83      0.78      5698
#
#         accuracy                           0.71      9013
#        macro avg       0.69      0.67      0.68      9013
#     weighted avg       0.70      0.71      0.71      9013
#     ```
#   - Para un `n_estimators` pequeño (10) y una `max_depth` grande (200) observamos un empeoramiento en los resultados por lo que probaremos con un valor más pequeño de `max_depth`:
#     ```
#     Confusion matrix:
#     [[1378 1937]
#      [ 922 4776]]
#
#     Classification report:
#                    precision    recall  f1-score   support
#
#          Control       0.60      0.42      0.49      3315
#          Estudio       0.71      0.84      0.77      5698
#
#         accuracy                           0.68      9013
#        macro avg       0.66      0.63      0.63      9013
#     weighted avg       0.67      0.68      0.67      9013
#     ```
#   - Para un `n_estimators` pequeño (10) y una `max_depth` intermedio (100) observamos los mismos resultados por lo que, `max_depth`, debe ser más pequeño todavía:
#     ```
#     Confusion matrix:
#     [[1378 1937]
#      [ 922 4776]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#          Control       0.60      0.42      0.49      3315
#          Estudio       0.71      0.84      0.77      5698
#
#         accuracy                           0.68      9013
#        macro avg       0.66      0.63      0.63      9013
#     weighted avg       0.67      0.68      0.67      9013
#     ```
#   - Para un `n_estimators` grande (200) y una `max_depth` pequeño (10) observamos que los resultados no mejoran a las estimaciones iniciales, probaremos aumentar ligeramente el `max_depth`:
#     ```
#     Confusion matrix:
#     [[1612 1703]
#      [1031 4667]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#          Control       0.61      0.49      0.54      3315
#          Estudio       0.73      0.82      0.77      5698
#
#         accuracy                           0.70      9013
#        macro avg       0.67      0.65      0.66      9013
#     weighted avg       0.69      0.70      0.69      9013
#     ```
#   - Para un `n_estimators` pequeño (200) y una `max_depth` pequeño (50) observamos que `max_depth` sigue siendo un problema aumentarlo por lo que lo mantendremos a 10, la próxima vez disminuiremos `n_estimators`:
#     ```
#     Confusion matrix:
#     [[1184 2131]
#      [ 716 4982]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#          Control       0.62      0.36      0.45      3315
#          Estudio       0.70      0.87      0.78      5698
#
#         accuracy                           0.68      9013
#        macro avg       0.66      0.62      0.62      9013
#     weighted avg       0.67      0.68      0.66      9013
#     ```
#   - Para un `n_estimators` intermedio (100) y una `max_depth` pequeño (10) observamos:
#     ```
#     Confusion matrix:
#     [[1595 1720]
#      [1010 4688]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#          Control       0.61      0.48      0.54      3315
#          Estudio       0.73      0.82      0.77      5698
#
#         accuracy                           0.70      9013
#        macro avg       0.67      0.65      0.66      9013
#     weighted avg       0.69      0.70      0.69      9013
#     ```

# %% [markdown]
# ## <font color=#cd0000> Conclusiones </font>
# - El rango de búsqueda orientativo podría ser:
#   - `n_estimators`: [10, 100]
#   - `max_depth`: [10, 50]

# %% [markdown]
# # <font color=#cd0000> Randomized Search </font>
# - Búsqueda de hiper-parámetros aleatoria con RF maximizando ``macro avg f1-score``

# %% [markdown]
# ## <font color=#cd0000> Rangos de búsqueda </font>
# - Como vimos anteriormente los rangos de búsqueda aleatoria de los mejores hiper-parámetros serán los siguientes

# %%
N_ESTIMATORS_RANGE = range(10, 100)
MAX_DEPTH_RANGE = range(10, 50)

# %% [markdown]
# # <font color=#cd0000> Randomized Search con múltiples ejecuciones en lugar de Validación Cruzada </font>
# - Ejecutaremos el mismo modelo sobre diferentes particiones del conjunto de datos original para observar su desempeño.
# - Realizaremos esto ya que aplicar validación cruzada con tan pocas series es inviable.

# %%
import random
import pickle
import utils.constants as cs
from sklearn.ensemble import RandomForestClassifier
from utils.classifier_utils import (train_validate,
                                    compute_classification_reports_means,
                                    tfm_marta_train_test_split)
from utils.plot_utils import pretty_print_classification_report_dict


def rf_randomized_search_train_validate(
        windowed_series,
        relation_with_series,
        prefix,
        class_weights,
        repetitions=5):
    global PKL_DIR
    all_clf_used = {}

    n_samples = 5
    n_estimators_list = random.sample(list(N_ESTIMATORS_RANGE), n_samples)
    max_depth_list = random.sample(list(MAX_DEPTH_RANGE), n_samples)

    best_hyp_params = None
    best_score = 0
    for n_estimators in n_estimators_list:
        for max_depth in max_depth_list:
            clf = RandomForestClassifier(
                n_estimators=n_estimators,
                max_depth=max_depth,
                random_state=SEED,
                class_weight=class_weights
            )

            reports = train_validate(
                clf,
                windowed_series,
                estimator_type=cs.ESTIMATOR_SKLEARN,
                relation_with_series=relation_with_series,
                train_test_split_method=tfm_marta_train_test_split,
                times_to_repeat=repetitions,
                train_size=0.8,
                drop_columns=['id', 'class'],
                seed=SEED
            )
            reports = list(map(lambda x: x['report'], reports))
            mean_report = compute_classification_reports_means(reports)
            all_clf_used[(n_estimators, max_depth)] = mean_report

            if mean_report['macro avg']['f1-score'][0] >= best_score:
                best_score = mean_report['macro avg']['f1-score'][0]
                best_hyp_params = (n_estimators, max_depth)
                best_report = mean_report

            print("\t\t--------------ACTUAL BEST: N_Estimators={}; Max_Depth={}--------------"
                  .format(best_hyp_params[0], best_hyp_params[1]))
            pretty_print_classification_report_dict(best_report)
            print("\t\t--------------ITERATION: N_Estimators={}; Max_Depth={}--------------"
                  .format(n_estimators, max_depth))
            pretty_print_classification_report_dict(mean_report)

    with open(PKL_DIR + prefix, 'wb') as file:
        pickle.dump(all_clf_used, file)

    return best_hyp_params, best_report

# %%
rf_randomized_search_train_validate(
    all_data.derived_data,
    all_data.derived_data_windows_per_serie,
    PKL_NAME,
    class_weights,
    repetitions=5
)
# Out:
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=20--------------
# Accuracy: 0.6941307000998558 +/- 0.03180389388085198
# Control:
# 	precision: 0.6098979309432642 +/- 0.047546322249749334
# 	recall: 0.45357466063348423 +/- 0.08186288369993819
# 	f1-score: 0.5184472627304093 +/- 0.07136202460609138
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.72519164252494 +/- 0.02998099052526781
# 	recall: 0.834082134082134 +/- 0.016472577732442557
# 	f1-score: 0.7754813257762624 +/- 0.01966837191271665
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.667544786734102 +/- 0.03847005836082724
# 	recall: 0.6438283973578092 +/- 0.041706345617400525
# 	f1-score: 0.6469642942533358 +/- 0.04477080151515233
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6827863774752058 +/- 0.036151023057509356
# 	recall: 0.6941307000998558 +/- 0.03180389388085198
# 	f1-score: 0.6809436669504549 +/- 0.03786476785379093
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=21; Max_Depth=20--------------
# Accuracy: 0.6941307000998558 +/- 0.03180389388085198
# Control:
# 	precision: 0.6098979309432642 +/- 0.047546322249749334
# 	recall: 0.45357466063348423 +/- 0.08186288369993819
# 	f1-score: 0.5184472627304093 +/- 0.07136202460609138
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.72519164252494 +/- 0.02998099052526781
# 	recall: 0.834082134082134 +/- 0.016472577732442557
# 	f1-score: 0.7754813257762624 +/- 0.01966837191271665
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.667544786734102 +/- 0.03847005836082724
# 	recall: 0.6438283973578092 +/- 0.041706345617400525
# 	f1-score: 0.6469642942533358 +/- 0.04477080151515233
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6827863774752058 +/- 0.036151023057509356
# 	recall: 0.6941307000998558 +/- 0.03180389388085198
# 	f1-score: 0.6809436669504549 +/- 0.03786476785379093
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=20--------------
# Accuracy: 0.6941307000998558 +/- 0.03180389388085198
# Control:
# 	precision: 0.6098979309432642 +/- 0.047546322249749334
# 	recall: 0.45357466063348423 +/- 0.08186288369993819
# 	f1-score: 0.5184472627304093 +/- 0.07136202460609138
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.72519164252494 +/- 0.02998099052526781
# 	recall: 0.834082134082134 +/- 0.016472577732442557
# 	f1-score: 0.7754813257762624 +/- 0.01966837191271665
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.667544786734102 +/- 0.03847005836082724
# 	recall: 0.6438283973578092 +/- 0.041706345617400525
# 	f1-score: 0.6469642942533358 +/- 0.04477080151515233
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6827863774752058 +/- 0.036151023057509356
# 	recall: 0.6941307000998558 +/- 0.03180389388085198
# 	f1-score: 0.6809436669504549 +/- 0.03786476785379093
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=21; Max_Depth=43--------------
# Accuracy: 0.6657272828137135 +/- 0.020456929629425028
# Control:
# 	precision: 0.573053750650413 +/- 0.03636989580467009
# 	recall: 0.3551131221719457 +/- 0.0746154684603541
# 	f1-score: 0.4345233562972095 +/- 0.06401921758524187
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.6937781040878294 +/- 0.0206201489512188
# 	recall: 0.8464373464373465 +/- 0.030482718390775328
# 	f1-score: 0.7619780514402092 +/- 0.013368478367374712
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6334159273691212 +/- 0.02631289966058459
# 	recall: 0.6007752343046462 +/- 0.029411772527717244
# 	f1-score: 0.5982507038687095 +/- 0.03513944279636511
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6493754377564154 +/- 0.02421582525120054
# 	recall: 0.6657272828137135 +/- 0.020456929629425028
# 	f1-score: 0.6415395388030136 +/- 0.02792452711436767
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=20--------------
# Accuracy: 0.6941307000998558 +/- 0.03180389388085198
# Control:
# 	precision: 0.6098979309432642 +/- 0.047546322249749334
# 	recall: 0.45357466063348423 +/- 0.08186288369993819
# 	f1-score: 0.5184472627304093 +/- 0.07136202460609138
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.72519164252494 +/- 0.02998099052526781
# 	recall: 0.834082134082134 +/- 0.016472577732442557
# 	f1-score: 0.7754813257762624 +/- 0.01966837191271665
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.667544786734102 +/- 0.03847005836082724
# 	recall: 0.6438283973578092 +/- 0.041706345617400525
# 	f1-score: 0.6469642942533358 +/- 0.04477080151515233
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6827863774752058 +/- 0.036151023057509356
# 	recall: 0.6941307000998558 +/- 0.03180389388085198
# 	f1-score: 0.6809436669504549 +/- 0.03786476785379093
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=21; Max_Depth=35--------------
# Accuracy: 0.667879729279929 +/- 0.04014486895553387
# Control:
# 	precision: 0.5751668589374945 +/- 0.07190223395563615
# 	recall: 0.3554147812971342 +/- 0.09158112699226056
# 	f1-score: 0.43613966923339625 +/- 0.0861383378368667
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.6948919294104081 +/- 0.03297709951605468
# 	recall: 0.8496665496665496 +/- 0.0337628038588727
# 	f1-score: 0.7640175180409503 +/- 0.027214665214112446
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6350293941739513 +/- 0.051462036868389925
# 	recall: 0.602540665481842 +/- 0.049038604726697486
# 	f1-score: 0.6000785936371733 +/- 0.05457457886505915
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6508568014155441 +/- 0.04628424230764629
# 	recall: 0.667879729279929 +/- 0.04014486895553387
# 	f1-score: 0.6434233686126756 +/- 0.04660939672632603
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=20--------------
# Accuracy: 0.6941307000998558 +/- 0.03180389388085198
# Control:
# 	precision: 0.6098979309432642 +/- 0.047546322249749334
# 	recall: 0.45357466063348423 +/- 0.08186288369993819
# 	f1-score: 0.5184472627304093 +/- 0.07136202460609138
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.72519164252494 +/- 0.02998099052526781
# 	recall: 0.834082134082134 +/- 0.016472577732442557
# 	f1-score: 0.7754813257762624 +/- 0.01966837191271665
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.667544786734102 +/- 0.03847005836082724
# 	recall: 0.6438283973578092 +/- 0.041706345617400525
# 	f1-score: 0.6469642942533358 +/- 0.04477080151515233
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6827863774752058 +/- 0.036151023057509356
# 	recall: 0.6941307000998558 +/- 0.03180389388085198
# 	f1-score: 0.6809436669504549 +/- 0.03786476785379093
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=21; Max_Depth=33--------------
# Accuracy: 0.6971041828469988 +/- 0.028274752266199146
# Control:
# 	precision: 0.6245489587565336 +/- 0.041182649740738195
# 	recall: 0.43004524886877826 +/- 0.08986133194108797
# 	f1-score: 0.5059919181457249 +/- 0.077499680866454
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.721412048865037 +/- 0.029016980318304644
# 	recall: 0.8524745524745525 +/- 0.01964021828890819
# 	f1-score: 0.7809248977263719 +/- 0.01578910697061297
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6729805038107852 +/- 0.034305391921957855
# 	recall: 0.6412599006716653 +/- 0.040429045853822974
# 	f1-score: 0.6434584079360484 +/- 0.045594994095144906
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.685785604428147 +/- 0.032716974629788294
# 	recall: 0.6971041828469988 +/- 0.028274752266199146
# 	f1-score: 0.6798039804613275 +/- 0.03729842156391957
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=21; Max_Depth=20--------------
# Accuracy: 0.6941307000998558 +/- 0.03180389388085198
# Control:
# 	precision: 0.6098979309432642 +/- 0.047546322249749334
# 	recall: 0.45357466063348423 +/- 0.08186288369993819
# 	f1-score: 0.5184472627304093 +/- 0.07136202460609138
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.72519164252494 +/- 0.02998099052526781
# 	recall: 0.834082134082134 +/- 0.016472577732442557
# 	f1-score: 0.7754813257762624 +/- 0.01966837191271665
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.667544786734102 +/- 0.03847005836082724
# 	recall: 0.6438283973578092 +/- 0.041706345617400525
# 	f1-score: 0.6469642942533358 +/- 0.04477080151515233
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.6827863774752058 +/- 0.036151023057509356
# 	recall: 0.6941307000998558 +/- 0.03180389388085198
# 	f1-score: 0.6809436669504549 +/- 0.03786476785379093
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6913050225514807 +/- 0.04598435457922606
# 	recall: 0.6565105006281476 +/- 0.03674036272862701
# 	f1-score: 0.6623666538232771 +/- 0.03975859492889016
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7015340592076797 +/- 0.0398017921544555
# 	recall: 0.7099744813047819 +/- 0.035015708191303146
# 	f1-score: 0.6958812386279656 +/- 0.036111029895439246
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=23; Max_Depth=33--------------
# Accuracy: 0.7099744813047819 +/- 0.035015708191303146
# Control:
# 	precision: 0.6526166854208373 +/- 0.0694029937297886
# 	recall: 0.45429864253393665 +/- 0.04386210816124476
# 	f1-score: 0.5356075464608527 +/- 0.053626514883105866
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.729993359682124 +/- 0.022662882962344186
# 	recall: 0.8587223587223587 +/- 0.03071543886346777
# 	f1-score: 0.7891257611857014 +/- 0.026049154578188998
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6913050225514807 +/- 0.04598435457922606
# 	recall: 0.6565105006281476 +/- 0.03674036272862701
# 	f1-score: 0.6623666538232771 +/- 0.03975859492889016
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7015340592076797 +/- 0.0398017921544555
# 	recall: 0.7099744813047819 +/- 0.035015708191303146
# 	f1-score: 0.6958812386279656 +/- 0.036111029895439246
# 	support: 9013.0 +/- 0.0
# 		--------------ACTUAL BEST: N_Estimators=23; Max_Depth=33--------------
# Accuracy: 0.7099744813047819 +/- 0.035015708191303146
# Control:
# 	precision: 0.6526166854208373 +/- 0.0694029937297886
# 	recall: 0.45429864253393665 +/- 0.04386210816124476
# 	f1-score: 0.5356075464608527 +/- 0.053626514883105866
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.729993359682124 +/- 0.022662882962344186
# 	recall: 0.8587223587223587 +/- 0.03071543886346777
# 	f1-score: 0.7891257611857014 +/- 0.026049154578188998
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6913050225514807 +/- 0.04598435457922606
# 	recall: 0.6565105006281476 +/- 0.03674036272862701
# 	f1-score: 0.6623666538232771 +/- 0.03975859492889016
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.7015340592076797 +/- 0.0398017921544555
# 	recall: 0.7099744813047819 +/- 0.035015708191303146
# 	f1-score: 0.6958812386279656 +/- 0.036111029895439246
# 	support: 9013.0 +/- 0.0
# 		--------------ITERATION: N_Estimators=23; Max_Depth=41--------------
# Accuracy: 0.6467103073338512 +/- 0.026904828181511655
# Control:
# 	precision: 0.5289270581020631 +/- 0.05843921368700761
# 	recall: 0.3466666666666667 +/- 0.05977979728695484
# 	f1-score: 0.4174227193007253 +/- 0.057991607710793765
# 	support: 3315.0 +/- 0.0
# Estudio:
# 	precision: 0.6840474483966323 +/- 0.020425850250518265
# 	recall: 0.8212706212706212 +/- 0.027219754732351182
# 	f1-score: 0.7461317221978078 +/- 0.018632590909461972
# 	support: 5698.0 +/- 0.0
# macro avg:
# 	precision: 0.6064872532493476 +/- 0.03874062881948639
# 	recall: 0.5839686439686439 +/- 0.03191802609849335
# 	f1-score: 0.5817772207492664 +/- 0.03638750441512261
# 	support: 9013.0 +/- 0.0
# weighted avg:
# 	precision: 0.626993848726545 +/- 0.03366825235827648
# 	recall: 0.6467103073338512 +/- 0.026904828181511655
# 	f1-score: 0.6252318725801633 +/- 0.031023926736814207
# 	support: 9013.0 +/- 0.0
# ((23, 33),
#  {'accuracy': (0.7099744813047819, 0.035015708191303146),
#   'Control': {'precision': (0.6526166854208373, 0.0694029937297886),
#    'recall': (0.45429864253393665, 0.04386210816124476),
#    'f1-score': (0.5356075464608527, 0.053626514883105866),
#    'support': (3315.0, 0.0)},
#   'Estudio': {'precision': (0.729993359682124, 0.022662882962344186),
#    'recall': (0.8587223587223587, 0.03071543886346777),
#    'f1-score': (0.7891257611857014, 0.026049154578188998),
#    'support': (5698.0, 0.0)},
#   'macro avg': {'precision': (0.6913050225514807, 0.04598435457922606),
#    'recall': (0.6565105006281476, 0.03674036272862701),
#    'f1-score': (0.6623666538232771, 0.03975859492889016),
#    'support': (9013.0, 0.0)},
#   'weighted avg': {'precision': (0.7015340592076797, 0.0398017921544555),
#    'recall': (0.7099744813047819, 0.035015708191303146),
#    'f1-score': (0.6958812386279656, 0.036111029895439246),
#    'support': (9013.0, 0.0)}})

# %% [markdown]
# # <font color=#cd0000> Análisis de resultados </font>
# - Según la búsqueda aleatoria de hiper-parámetros, la mejor combinación, es la de ``n_estimators`` = 23 y ``max_depth`` = 33:
#     ```
#         Accuracy: 0.7099744813047819 +/- 0.035015708191303146
#         Control:
#             precision: 0.6526166854208373 +/- 0.0694029937297886
#             recall: 0.45429864253393665 +/- 0.04386210816124476
#             f1-score: 0.5356075464608527 +/- 0.053626514883105866
#             support: 3315.0 +/- 0.0
#         Estudio:
#             precision: 0.729993359682124 +/- 0.022662882962344186
#             recall: 0.8587223587223587 +/- 0.03071543886346777
#             f1-score: 0.7891257611857014 +/- 0.026049154578188998
#             support: 5698.0 +/- 0.0
#         macro avg:
#             precision: 0.6913050225514807 +/- 0.04598435457922606
#             recall: 0.6565105006281476 +/- 0.03674036272862701
#             f1-score: 0.6623666538232771 +/- 0.03975859492889016
#             support: 9013.0 +/- 0.0
#         weighted avg:
#             precision: 0.7015340592076797 +/- 0.0398017921544555
#             recall: 0.7099744813047819 +/- 0.035015708191303146
#             f1-score: 0.6958812386279656 +/- 0.036111029895439246
#             support: 9013.0 +/- 0.0
#     ```
# - Ahora vamos a visualizar la evolución de los resultados (25 resultados) para observar cómo avanza nuestra métrica objetivo -> Macro Average F1-Score.

# %%
import pickle

all_reports = pickle.load(open(PKL_DIR + PKL_NAME, 'rb'))

# %%
from utils.plot_utils import plot_score

macro_avg_f1_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['macro avg']['f1-score'][0],
                   'std': all_reports[z]['macro avg']['f1-score'][1]}),
    all_reports
))

plot_score(
    [macro_avg_f1_scores],
    ('n_estimators', 'max_depth'),
    'RandomForest',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Macro Average F1-Score'
)

# %%
estudio_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['Estudio']['recall'][0],
                   'std': all_reports[z]['Estudio']['recall'][1]}),
    all_reports
))

control_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['Control']['recall'][0],
                   'std': all_reports[z]['Control']['recall'][1]}),
    all_reports
))

plot_score(
    [estudio_recall_scores],
    ('n_estimators', 'max_depth'),
    'RandomForest',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Estudio recall score'
)

plot_score(
    [control_recall_scores],
    ('n_estimators', 'max_depth'),
    'RandomForest',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Control recall score'
)

# %% [markdown]
# # <font color=#cd0000> Conclusiones </font>
# - TODO
