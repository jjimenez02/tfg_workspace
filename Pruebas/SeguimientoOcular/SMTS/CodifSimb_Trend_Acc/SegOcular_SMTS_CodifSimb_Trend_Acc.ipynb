# %% [markdown]
# # <font color=#cd0000> Propósito principal </font>
# - La idea de este librillo es preparar el entorno para realizar pruebas para Seguimiento Ocular a ser clasificado por Codif Simbólica, Tendencia y Aceleración aplicada a SMTS
#
# ## <font color=#cd0000> Leyenda </font>
# - Los apartados titulados con el código de colores HEX: `#cd0000` serán apartados que tendrán todos los librillos, en concreto, aquellos especificados en el apartado `Síntesis de los criterios usados` del trabajo.
# - Los apartados titulados con el código de colores HEX: `#2451ff` serán apartados de conclusiones propias de este librillo resultado de aplicar un estudio personalizado para cada planteamiento.

# %% [markdown]
# # <font color=#cd0000> Prerrequisitos </font>
# ## <font color=#cd0000> Entorno de ejecución </font>
# - Cambiamos el directorio raíz del librillo para acceder cómodamente a las funciones de utilidad.

# %%
import os

os.chdir('../../../../')
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.gitmodules',
#  'data',
#  'HeartBeat_tmp_test_data.pkl',
#  'HeartBeat_tmp_train_data.pkl',
#  'pkl',
#  'Pruebas',
#  'README.md',
#  'smts_implementation',
#  'utils']

# %% [markdown]
# ## <font color=#cd0000> Constantes y variables predefinidas </font>

# %%
SEGUIMIENTO_OCULAR_PATH = "data/seguimiento-ocular/Data/Hospital"
SEGUIMIENTO_OCULAR_FOLDERS_ID = range(1, 12+1)

DATA_TO_SAVE = "SegOcular"

PKL_DIR = "pkl/SMTS/SegOcular/"
PKL_NAME = "segocular_SMTS_codifsimb_trend_acc.pkl"

SEED = 1

# %% [markdown]
# # <font color=#cd0000> Carga del Dataset </font>

# %%
from utils.load_data import import_seguimiento_ocular_dataset

all_data = import_seguimiento_ocular_dataset(
    SEGUIMIENTO_OCULAR_PATH, SEGUIMIENTO_OCULAR_FOLDERS_ID)

# %%
all_data.reset_changes()

# %% [markdown]
# # <font color=#cd0000> Preprocesamiento </font>

# %% [markdown]
# ## <font color=#cd0000> Eliminación de datos inválidos y valores atípicos </font>
# - No eliminaremos aquellos valores fuera de los percentiles 5 y 95 ante la falta de información.

# %% [markdown]
# ### <font color=#2451ff> Limpieza de datos </font>
# - Eliminaremos todos aquellos valores inválidos con un "0" en alguna de las columnas `*Validity*`.

# %%
# Clean data
validity_headers = ['ValidityLeft',
                    'ValidityRight',
                    'PupilValidityLeft',
                    'PupilValidityRight']

all_data.clean_data(criterion='remove', value=0, headers=validity_headers)

# %% [markdown]
# ## <font color=#2451ff> Reducción de la dimensionalidad </font>
# - Eliminamos los atributos de validez y los redundantes/no informativos (o que puedan sesgar al modelo).

# %%
# Reduce data
columns_to_remove = validity_headers + ['GazePointX', 'GazePointY',
                                        'diagnosis', 'Age']

all_data.drop_derived_data_columns(columns_to_remove)
# Out:
#          id  TimeStamp  GazePointXLeft  GazePointYLeft  GazePointXRight  \
# 0       1-1    704.487             875             549              771
# 1       1-1    750.040             879             519              796
# 2       1-1    776.032             898             547              785
# 3       1-1    831.135             882             563              768
# 4       1-1    857.075             879             513              789
# ...     ...        ...             ...             ...              ...
# 36362  12-3  54379.209             162             808              263
# 36363  12-3  54406.850             136             816              272
# 36364  12-3  54433.946             122             942              191
# 36365  12-3  54460.926             326             918              364
# 36366  12-3  54487.080             354             938              363
#
#        GazePointYRight  PupilSizeLeft  PupilSizeRight    class
# 0                  284         2.1565          2.1575  Control
# 1                  245         2.0449          2.1528  Control
# 2                  316         2.1199          2.1833  Control
# 3                  322         2.1039          2.3215  Control
# 4                  362         2.0490          2.4636  Control
# ...                ...            ...             ...      ...
# 36362              944         2.6453          2.4885  Estudio
# 36363              969         2.6189          2.4906  Estudio
# 36364              854         2.5684          2.2774  Estudio
# 36365              936         2.3562          2.6705  Estudio
# 36366              988         2.2507          2.5588  Estudio
#
# [36367 rows x 9 columns]

# %% [markdown]
# ## <font color=#2451ff> Eliminación de series cortas </font>
# - Ante la limpieza de los datos hemos acabado con series, concretamente, la ``8-1`` (72 muestras) y ``8-2`` (202 muestras), con muy pocas muestras.
#   - Las eliminaremos con el fin de no obtener ventanas demasiado pequeñas (72/4 = 18 muestras por ventana)

# %%
all_data.derived_data = all_data.derived_data[
    all_data.derived_data['id'] != '8-1']  # 72 samples
all_data.derived_data = all_data.derived_data[
    all_data.derived_data['id'] != '8-2']  # 202 samples

# %%
import pandas as pd

# Remaining series
print("Previous number of series: {}".format(
    len(pd.unique(all_data.original_data['id']))))
print("Actual number of series: {}".format(
    len(pd.unique(all_data.derived_data['id']))))

print("Previous largest serie: {}".format(
    all_data.get_largest_serie(all_data.original_data).shape[0]))
print("Actual largest serie: {}".format(
    all_data.get_largest_serie().shape[0]))

print("Previous shortest serie: {}".format(
    all_data.get_shortest_serie(all_data.original_data).shape[0]))
print("Actual shortest serie: {}".format(
    all_data.get_shortest_serie().shape[0]))
# Out:
# Previous number of series: 25
# Actual number of series: 23
# Previous largest serie: 2113
# Actual largest serie: 1901
# Previous shortest serie: 967
# Actual shortest serie: 768

# %% [markdown]
# ## <font color=#cd0000> Resoluciones a aplicar </font>
# - Como vimos en el análisis en profundidad, mantendremos la resolución actual

# %%
# Nothing to see here

# %% [markdown]
# # <font color=#cd0000> División en ventanas </font>
# - El número de ventanas por serie será de 4 como ya vimos en el análisis en profundidad.

# %%
all_data.split_into_windows(n_windows=4)

# %%
all_data.get_derived_data_classes_count()
# Out:
# Estudio    60
# Control    32
# Name: class, dtype: int64

# %% [markdown]
# # <font color=#2451ff> Particionado inicial de los datos </font>
# - Llevaremos a cabo el particionado empleado por Marta en su TFM: http://hdl.handle.net/10486/697441

# %%
from utils.data_extraction import Data

X_train, X_test, _, _ = all_data.train_test_split(
    criterion='tfm_marta',
    train_size=.8,
    random_state=SEED,
    drop_columns=[]
)

X_train_Data = Data(X_train)
X_test_Data = Data(X_test)

# %%
X_train_Data.get_derived_data_classes_count()
# Out:
# Estudio    45
# Control    24
# Name: class, dtype: int64

# %%
X_test_Data.get_derived_data_classes_count()
# Out:
# Estudio    15
# Control     8
# Name: class, dtype: int64

# %% [markdown]
# ## <font color=#cd0000> Codificación </font>
# - Codificación Simbólica en SMTS (se crea dentro del clasificador)

# %%
from utils.codifications import temporal_trend_fn

X_train_Data.apply_codifications([temporal_trend_fn])
X_test_Data.apply_codifications([temporal_trend_fn])

# %%
columns = X_train_Data.get_derived_data_columns()['attrs']
trend_columns = list(filter(lambda z: 'Diff' in z, columns))

X_train_Data.apply_codifications([temporal_trend_fn], headers=trend_columns)
X_test_Data.apply_codifications([temporal_trend_fn], headers=trend_columns)

# %% [markdown]
# # <font color=#cd0000> Preparación de los datos </font>

# %%
X_train = X_train_Data.derived_data.drop(['TimeStamp', 'class'], axis=1)
X_test = X_test_Data.derived_data.drop(['TimeStamp', 'class'], axis=1)

y_train = X_train_Data.derived_data['class'].to_numpy()
y_test = X_test_Data.derived_data['class'].to_numpy()

# %% [markdown]
# ## <font color=#cd0000> Técnicas de balanceo </font>

# %% [markdown]
# ### <font color=#cd0000> Asignación de pesos a las clases </font>

# %%
import numpy as np
from sklearn.utils import compute_class_weight

class_weights = compute_class_weight(
    'balanced', classes=np.unique(y_train), y=y_train)
class_weights = {'Control': class_weights[0], 'Estudio': class_weights[1]}

# %% [markdown]
# # <font color=#cd0000> Diseño de la topología del bosque </font>
# - Número de árboles inicial recomendado
# - Número de símbolos inicial recomendado
# - Número de árboles del segundo RandomForest recomendado

# %% [markdown]
# ## <font color=#cd0000> Entrenamiento </font>

# %%
from smts_implementation.smts import SMTS

clf = SMTS(
    j_ins=100,
    n_symbols=10,
    class_weight=class_weights,
    random_state=SEED
)
clf.fit(X_train, y_train)

# %% [markdown]
# ## <font color=#cd0000> Clasificación </font>

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = clf.predict(X_test)
y_true = X_test.assign(class_name=y_test).groupby('id', sort=False)\
    .first()['class_name'].to_numpy()

print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# [[ 7  1]
#  [ 1 14]]
#               precision    recall  f1-score   support
#
#      Control       0.88      0.88      0.88         8
#      Estudio       0.93      0.93      0.93        15
#
#     accuracy                           0.91        23
#    macro avg       0.90      0.90      0.90        23
# weighted avg       0.91      0.91      0.91        23

# %% [markdown]
# ## <font color=#cd0000> Discusión de los resultados </font>
# - Vamos a estudiar diferentes rangos de hiper-parámetros interesantes que podrían darnos alguna pista sobre el rango en el que buscar el mejor clasificador de este tipo:
#   - Para un `j_ins` pequeño (10) y un `n_symbols` pequeño (10) observamos resultados mucho mejores que para RandomForest:
#     ```
#     Confusion matrix:
#     [[ 6  2]
#      [ 1 14]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#          Control       0.86      0.75      0.80         8
#          Estudio       0.88      0.93      0.90        15
#
#         accuracy                           0.87        23
#        macro avg       0.87      0.84      0.85        23
#     weighted avg       0.87      0.87      0.87        23
#     ```
#   - Para un `j_ins` pequeño (10) y un `n_symbols` grande (200) observamos resultados perfectos:
#     ```
#     Confusion matrix:
#     [[ 8  0]
#      [ 0 15]]
#
#     Classification report:
#                       precision    recall  f1-score   support
#
#          Control       1.00      1.00      1.00         8
#          Estudio       1.00      1.00      1.00        15
#
#         accuracy                           1.00        23
#        macro avg       1.00      1.00      1.00        23
#     weighted avg       1.00      1.00      1.00        23
#     ```
#   - Para un `j_ins` grande (200) y un `n_symbols` grande (200) observamos un desempeño peor:
#     ```
#     Confusion matrix:
#     [[ 7  1]
#      [ 0 15]]
#
#     Classification report:
#                   precision    recall  f1-score   support
#
#        Control       1.00      0.88      0.93         8
#        Estudio       0.94      1.00      0.97        15
#
#       accuracy                           0.96        23
#      macro avg       0.97      0.94      0.95        23
#   weighted avg       0.96      0.96      0.96        23
#     ```
#   - Para un `j_ins` intermedio (100) y un `n_symbols` grande (200) observamos una mejora significativa:
#     ```
#     Confusion matrix:
#     [[ 7  1]
#      [ 2 13]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#          Control       0.78      0.88      0.82         8
#          Estudio       0.93      0.87      0.90        15
#
#         accuracy                           0.87        23
#        macro avg       0.85      0.87      0.86        23
#     weighted avg       0.88      0.87      0.87        23
#     ```
#   - Para un `j_ins` intermedio (100) y un `n_symbols` intermedio (100) observamos un desempeño similar al anterior:
#     ```
#     Confusion matrix:
#     [[ 7  1]
#      [ 1 14]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#          Control       0.88      0.88      0.88         8
#          Estudio       0.93      0.93      0.93        15
#
#         accuracy                           0.91        23
#        macro avg       0.90      0.90      0.90        23
#     weighted avg       0.91      0.91      0.91        23
#     ```
#   - Para un `j_ins` intermedio (100) y un `n_symbols` pequeño (10) observamos un desempeño inferior:
#     ```
#     Confusion matrix:
#     [[ 7  1]
#      [ 1 14]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#          Control       0.88      0.88      0.88         8
#          Estudio       0.93      0.93      0.93        15
#
#         accuracy                           0.91        23
#        macro avg       0.90      0.90      0.90        23
#     weighted avg       0.91      0.91      0.91        23
#     ```

# %% [markdown]
# ## <font color=#cd0000> Conclusiones </font>
# - Como podemos observar los resultados son los mismos
# - El rango orientativo:
#   - `n_estimators`: [10, 100]
#   - `max_depth`: [100, 200]

# %% [markdown]
# # <font color=#cd0000> Randomized Search </font>
# - Búsqueda de hiper-parámetros aleatoria con SMTS maximizando ``macro avg f1-score``

# %% [markdown]
# ## <font color=#cd0000> Rangos de búsqueda </font>
# - Como vimos anteriormente los rangos de búsqueda aleatoria de los mejores hiper-parámetros serán los siguientes

# %%
J_INS_RANGE = range(10, 100)
N_SYMBOLS_RANGE = range(100, 200)

# %% [markdown]
# # <font color=#cd0000> Randomized Search con múltiples ejecuciones en lugar de Validación Cruzada </font>
# - Solo si tenemos pocos datos
# - Ejecutaremos el mismo modelo sobre diferentes particiones del conjunto de datos original para observar su desempeño.

# %%
import random
import pickle
import utils.constants as cs
from smts_implementation.smts import SMTS
from utils.classifier_utils import (train_validate,
                                    tfm_marta_train_test_split,
                                    compute_classification_reports_means)
from utils.plot_utils import pretty_print_classification_report_dict


def smts_randomized_search_train_validate(
        windowed_series,
        relation_with_series,
        prefix,
        class_weights,
        repetitions=5):
    global PKL_DIR
    all_clf_used = {}

    n_samples = 5
    j_ins_list = random.sample(list(J_INS_RANGE), n_samples)
    n_symbols_list = random.sample(list(N_SYMBOLS_RANGE), n_samples)

    best_hyp_params = None
    best_score = 0
    for j_ins in j_ins_list:
        for n_symbols in n_symbols_list:
            clf = SMTS(
                j_ins=j_ins,
                n_symbols=n_symbols,
                class_weight=class_weights,
                random_state=SEED
            )

            reports = train_validate(
                clf,
                windowed_series,
                estimator_type=cs.ESTIMATOR_SMTS,
                relation_with_series=relation_with_series,
                train_test_split_method=tfm_marta_train_test_split,
                times_to_repeat=repetitions,
                train_size=0.8,
                drop_columns=['class'],
                seed=SEED
            )
            reports = list(map(lambda x: x['report'], reports))
            mean_report = compute_classification_reports_means(reports)
            all_clf_used[(j_ins, n_symbols)] = mean_report

            if mean_report['macro avg']['f1-score'][0] >= best_score:
                best_score = mean_report['macro avg']['f1-score'][0]
                best_hyp_params = (j_ins, n_symbols)
                best_report = mean_report

            print("\t\t--------------ACTUAL BEST: J_ins={}; N_symbols={}--------------"
                  .format(best_hyp_params[0], best_hyp_params[1]))
            pretty_print_classification_report_dict(best_report)
            print("\t\t--------------ITERATION: J_ins={}; N_symbols={}--------------"
                  .format(j_ins, n_symbols))
            pretty_print_classification_report_dict(mean_report)

    with open(PKL_DIR + prefix, 'wb') as file:
        pickle.dump(all_clf_used, file)

    return best_hyp_params, best_report

# %%
smts_randomized_search_train_validate(
    all_data.derived_data,
    all_data.derived_data_windows_per_serie,
    PKL_NAME,
    class_weights,
    repetitions=5
)
# Out:
# 		--------------ACTUAL BEST: J_ins=21; N_symbols=199--------------
# Accuracy: 0.8086956521739129 +/- 0.058976782461958865
# Control:
# 	precision: 0.7603174603174603 +/- 0.0806873969977069
# 	recall: 0.65 +/- 0.1457737973711325
# 	f1-score: 0.6961344537815127 +/- 0.10812040460111763
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8313025210084033 +/- 0.06372025711883506
# 	recall: 0.8933333333333333 +/- 0.03265986323710904
# 	f1-score: 0.8599555061179087 +/- 0.039854708585862195
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.7958099906629318 +/- 0.06652990720287498
# 	recall: 0.7716666666666667 +/- 0.07796901093810711
# 	f1-score: 0.7780449799497108 +/- 0.07379807199962764
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8066120651159014 +/- 0.06428805449296941
# 	recall: 0.8086956521739129 +/- 0.058976782461958865
# 	f1-score: 0.8029742705226406 +/- 0.06339922342049807
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=21; N_symbols=199--------------
# Accuracy: 0.8086956521739129 +/- 0.058976782461958865
# Control:
# 	precision: 0.7603174603174603 +/- 0.0806873969977069
# 	recall: 0.65 +/- 0.1457737973711325
# 	f1-score: 0.6961344537815127 +/- 0.10812040460111763
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8313025210084033 +/- 0.06372025711883506
# 	recall: 0.8933333333333333 +/- 0.03265986323710904
# 	f1-score: 0.8599555061179087 +/- 0.039854708585862195
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.7958099906629318 +/- 0.06652990720287498
# 	recall: 0.7716666666666667 +/- 0.07796901093810711
# 	f1-score: 0.7780449799497108 +/- 0.07379807199962764
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8066120651159014 +/- 0.06428805449296941
# 	recall: 0.8086956521739129 +/- 0.058976782461958865
# 	f1-score: 0.8029742705226406 +/- 0.06339922342049807
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=21; N_symbols=120--------------
# Accuracy: 0.8347826086956521 +/- 0.08867860023639627
# Control:
# 	precision: 0.7544444444444445 +/- 0.08435667953823248
# 	recall: 0.75 +/- 0.22360679774997896
# 	f1-score: 0.7445845004668535 +/- 0.15457518454880043
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8792156862745099 +/- 0.10541363210297379
# 	recall: 0.8800000000000001 +/- 0.02666666666666666
# 	f1-score: 0.8771510673234811 +/- 0.06151760388278744
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8168300653594771 +/- 0.09352539236737753
# 	recall: 0.8150000000000001 +/- 0.11976829482147787
# 	f1-score: 0.8108677838951672 +/- 0.1078515995157481
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8358169934640521 +/- 0.09689727489319935
# 	recall: 0.8347826086956521 +/- 0.08867860023639627
# 	f1-score: 0.8310409571124803 +/- 0.09368200985511589
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=21; N_symbols=120--------------
# Accuracy: 0.8347826086956521 +/- 0.08867860023639627
# Control:
# 	precision: 0.7544444444444445 +/- 0.08435667953823248
# 	recall: 0.75 +/- 0.22360679774997896
# 	f1-score: 0.7445845004668535 +/- 0.15457518454880043
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8792156862745099 +/- 0.10541363210297379
# 	recall: 0.8800000000000001 +/- 0.02666666666666666
# 	f1-score: 0.8771510673234811 +/- 0.06151760388278744
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8168300653594771 +/- 0.09352539236737753
# 	recall: 0.8150000000000001 +/- 0.11976829482147787
# 	f1-score: 0.8108677838951672 +/- 0.1078515995157481
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8358169934640521 +/- 0.09689727489319935
# 	recall: 0.8347826086956521 +/- 0.08867860023639627
# 	f1-score: 0.8310409571124803 +/- 0.09368200985511589
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=21; N_symbols=120--------------
# Accuracy: 0.8347826086956521 +/- 0.08867860023639627
# Control:
# 	precision: 0.7544444444444445 +/- 0.08435667953823248
# 	recall: 0.75 +/- 0.22360679774997896
# 	f1-score: 0.7445845004668535 +/- 0.15457518454880043
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8792156862745099 +/- 0.10541363210297379
# 	recall: 0.8800000000000001 +/- 0.02666666666666666
# 	f1-score: 0.8771510673234811 +/- 0.06151760388278744
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8168300653594771 +/- 0.09352539236737753
# 	recall: 0.8150000000000001 +/- 0.11976829482147787
# 	f1-score: 0.8108677838951672 +/- 0.1078515995157481
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8358169934640521 +/- 0.09689727489319935
# 	recall: 0.8347826086956521 +/- 0.08867860023639627
# 	f1-score: 0.8310409571124803 +/- 0.09368200985511589
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=21; N_symbols=166--------------
# Accuracy: 0.826086956521739 +/- 0.03888813873912675
# Control:
# 	precision: 0.7626984126984128 +/- 0.05290740734126652
# 	recall: 0.725 +/- 0.09354143466934853
# 	f1-score: 0.7413725490196078 +/- 0.06545731239709926
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8590476190476192 +/- 0.04354181923939029
# 	recall: 0.8800000000000001 +/- 0.026666666666666665
# 	f1-score: 0.8687727104189842 +/- 0.02746159775392266
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.810873015873016 +/- 0.04324689581031823
# 	recall: 0.8025 +/- 0.0503184304648351
# 	f1-score: 0.805072629719296 +/- 0.04623065280022743
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8255348516218082 +/- 0.04215496483714023
# 	recall: 0.826086956521739 +/- 0.03888813873912675
# 	f1-score: 0.8244596108018097 +/- 0.04044027195292932
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=21; N_symbols=120--------------
# Accuracy: 0.8347826086956521 +/- 0.08867860023639627
# Control:
# 	precision: 0.7544444444444445 +/- 0.08435667953823248
# 	recall: 0.75 +/- 0.22360679774997896
# 	f1-score: 0.7445845004668535 +/- 0.15457518454880043
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8792156862745099 +/- 0.10541363210297379
# 	recall: 0.8800000000000001 +/- 0.02666666666666666
# 	f1-score: 0.8771510673234811 +/- 0.06151760388278744
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8168300653594771 +/- 0.09352539236737753
# 	recall: 0.8150000000000001 +/- 0.11976829482147787
# 	f1-score: 0.8108677838951672 +/- 0.1078515995157481
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8358169934640521 +/- 0.09689727489319935
# 	recall: 0.8347826086956521 +/- 0.08867860023639627
# 	f1-score: 0.8310409571124803 +/- 0.09368200985511589
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=21; N_symbols=150--------------
# Accuracy: 0.782608695652174 +/- 0.1099922664406393
# Control:
# 	precision: 0.7214285714285715 +/- 0.23589459193334925
# 	recall: 0.55 +/- 0.21794494717703367
# 	f1-score: 0.621904761904762 +/- 0.230027110696389
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.7954334365325076 +/- 0.08431759379156303
# 	recall: 0.9066666666666668 +/- 0.05333333333333333
# 	f1-score: 0.8468216318785577 +/- 0.07131251299262865
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.7584310039805395 +/- 0.15948840558126456
# 	recall: 0.7283333333333334 +/- 0.13510284148669036
# 	f1-score: 0.7343631968916599 +/- 0.15066869039394645
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.7696926138876604 +/- 0.13638491618096443
# 	recall: 0.782608695652174 +/- 0.1099922664406393
# 	f1-score: 0.7685896771050637 +/- 0.1265163786253748
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=21; N_symbols=120--------------
# Accuracy: 0.8347826086956521 +/- 0.08867860023639627
# Control:
# 	precision: 0.7544444444444445 +/- 0.08435667953823248
# 	recall: 0.75 +/- 0.22360679774997896
# 	f1-score: 0.7445845004668535 +/- 0.15457518454880043
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8792156862745099 +/- 0.10541363210297379
# 	recall: 0.8800000000000001 +/- 0.02666666666666666
# 	f1-score: 0.8771510673234811 +/- 0.06151760388278744
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8168300653594771 +/- 0.09352539236737753
# 	recall: 0.8150000000000001 +/- 0.11976829482147787
# 	f1-score: 0.8108677838951672 +/- 0.1078515995157481
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8358169934640521 +/- 0.09689727489319935
# 	recall: 0.8347826086956521 +/- 0.08867860023639627
# 	f1-score: 0.8310409571124803 +/- 0.09368200985511589
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=21; N_symbols=147--------------
# Accuracy: 0.8347826086956521 +/- 0.050703929520393924
# Control:
# 	precision: 0.7984126984126985 +/- 0.07197323205558498
# 	recall: 0.7 +/- 0.1274754878398196
# 	f1-score: 0.7418487394957983 +/- 0.09299206897531562
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8533613445378151 +/- 0.055394502884236495
# 	recall: 0.9066666666666666 +/- 0.03265986323710904
# 	f1-score: 0.8781006674082313 +/- 0.034397815108297106
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8258870214752567 +/- 0.05678884329949076
# 	recall: 0.8033333333333333 +/- 0.06705097563297147
# 	f1-score: 0.8099747034520147 +/- 0.06345958454756528
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8342487719725572 +/- 0.05465299666441314
# 	recall: 0.8347826086956521 +/- 0.050703929520393924
# 	f1-score: 0.8307086924821677 +/- 0.0545300021637043
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=66; N_symbols=199--------------
# Accuracy: 0.8434782608695652 +/- 0.044339300118198095
# Control:
# 	precision: 0.7892857142857144 +/- 0.06428571428571428
# 	recall: 0.75 +/- 0.07905694150420949
# 	f1-score: 0.7683333333333333 +/- 0.06839428176227731
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8708333333333333 +/- 0.0383695481107378
# 	recall: 0.8933333333333333 +/- 0.03265986323710904
# 	f1-score: 0.881720430107527 +/- 0.032953086123660984
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8300595238095237 +/- 0.049350228077870796
# 	recall: 0.8216666666666667 +/- 0.05159941860137573
# 	f1-score: 0.82502688172043 +/- 0.05051764074879101
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8424689440993788 +/- 0.045437764981105126
# 	recall: 0.8434782608695652 +/- 0.044339300118198095
# 	f1-score: 0.8422814399251987 +/- 0.04512197154566213
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=66; N_symbols=199--------------
# Accuracy: 0.8434782608695652 +/- 0.044339300118198095
# Control:
# 	precision: 0.7892857142857144 +/- 0.06428571428571428
# 	recall: 0.75 +/- 0.07905694150420949
# 	f1-score: 0.7683333333333333 +/- 0.06839428176227731
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8708333333333333 +/- 0.0383695481107378
# 	recall: 0.8933333333333333 +/- 0.03265986323710904
# 	f1-score: 0.881720430107527 +/- 0.032953086123660984
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8300595238095237 +/- 0.049350228077870796
# 	recall: 0.8216666666666667 +/- 0.05159941860137573
# 	f1-score: 0.82502688172043 +/- 0.05051764074879101
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8424689440993788 +/- 0.045437764981105126
# 	recall: 0.8434782608695652 +/- 0.044339300118198095
# 	f1-score: 0.8422814399251987 +/- 0.04512197154566213
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=66; N_symbols=199--------------
# Accuracy: 0.8434782608695652 +/- 0.044339300118198095
# Control:
# 	precision: 0.7892857142857144 +/- 0.06428571428571428
# 	recall: 0.75 +/- 0.07905694150420949
# 	f1-score: 0.7683333333333333 +/- 0.06839428176227731
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8708333333333333 +/- 0.0383695481107378
# 	recall: 0.8933333333333333 +/- 0.03265986323710904
# 	f1-score: 0.881720430107527 +/- 0.032953086123660984
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8300595238095237 +/- 0.049350228077870796
# 	recall: 0.8216666666666667 +/- 0.05159941860137573
# 	f1-score: 0.82502688172043 +/- 0.05051764074879101
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8424689440993788 +/- 0.045437764981105126
# 	recall: 0.8434782608695652 +/- 0.044339300118198095
# 	f1-score: 0.8422814399251987 +/- 0.04512197154566213
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=66; N_symbols=120--------------
# Accuracy: 0.826086956521739 +/- 0.047628048478710105
# Control:
# 	precision: 0.7527777777777778 +/- 0.06938886664887109
# 	recall: 0.75 +/- 0.11180339887498948
# 	f1-score: 0.7472689075630253 +/- 0.07439941486801153
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8694677871148461 +/- 0.05278339685746962
# 	recall: 0.8666666666666666 +/- 0.04216370213557838
# 	f1-score: 0.8669540229885058 +/- 0.035495659849429234
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8111227824463118 +/- 0.05209708780398136
# 	recall: 0.8083333333333333 +/- 0.059744827763116404
# 	f1-score: 0.8071114652757656 +/- 0.054242544800235847
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8288799577802136 +/- 0.05006008962668727
# 	recall: 0.826086956521739 +/- 0.047628048478710105
# 	f1-score: 0.8253244176231211 +/- 0.04830981403343056
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=66; N_symbols=199--------------
# Accuracy: 0.8434782608695652 +/- 0.044339300118198095
# Control:
# 	precision: 0.7892857142857144 +/- 0.06428571428571428
# 	recall: 0.75 +/- 0.07905694150420949
# 	f1-score: 0.7683333333333333 +/- 0.06839428176227731
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8708333333333333 +/- 0.0383695481107378
# 	recall: 0.8933333333333333 +/- 0.03265986323710904
# 	f1-score: 0.881720430107527 +/- 0.032953086123660984
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8300595238095237 +/- 0.049350228077870796
# 	recall: 0.8216666666666667 +/- 0.05159941860137573
# 	f1-score: 0.82502688172043 +/- 0.05051764074879101
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8424689440993788 +/- 0.045437764981105126
# 	recall: 0.8434782608695652 +/- 0.044339300118198095
# 	f1-score: 0.8422814399251987 +/- 0.04512197154566213
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=66; N_symbols=166--------------
# Accuracy: 0.8 +/- 0.03478260869565219
# Control:
# 	precision: 0.7128571428571429 +/- 0.05809914116475074
# 	recall: 0.725 +/- 0.049999999999999996
# 	f1-score: 0.7166666666666666 +/- 0.040824829046386346
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8517307692307693 +/- 0.02116316810919732
# 	recall: 0.8400000000000001 +/- 0.053333333333333365
# 	f1-score: 0.844884792626728 +/- 0.03150438396850506
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.7822939560439561 +/- 0.03434546852772111
# 	recall: 0.7825 +/- 0.03166666666666666
# 	f1-score: 0.7807757296466974 +/- 0.0347756390304173
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8034268991877687 +/- 0.028318075061067902
# 	recall: 0.8 +/- 0.03478260869565219
# 	f1-score: 0.8002871835971416 +/- 0.033434967835293004
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=66; N_symbols=199--------------
# Accuracy: 0.8434782608695652 +/- 0.044339300118198095
# Control:
# 	precision: 0.7892857142857144 +/- 0.06428571428571428
# 	recall: 0.75 +/- 0.07905694150420949
# 	f1-score: 0.7683333333333333 +/- 0.06839428176227731
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8708333333333333 +/- 0.0383695481107378
# 	recall: 0.8933333333333333 +/- 0.03265986323710904
# 	f1-score: 0.881720430107527 +/- 0.032953086123660984
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8300595238095237 +/- 0.049350228077870796
# 	recall: 0.8216666666666667 +/- 0.05159941860137573
# 	f1-score: 0.82502688172043 +/- 0.05051764074879101
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8424689440993788 +/- 0.045437764981105126
# 	recall: 0.8434782608695652 +/- 0.044339300118198095
# 	f1-score: 0.8422814399251987 +/- 0.04512197154566213
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=66; N_symbols=150--------------
# Accuracy: 0.7999999999999999 +/- 0.06507230237867723
# Control:
# 	precision: 0.7326984126984126 +/- 0.08462327406499624
# 	recall: 0.65 +/- 0.16583123951777
# 	f1-score: 0.6836802413273001 +/- 0.1288518300241983
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8301587301587302 +/- 0.06923835633088331
# 	recall: 0.8800000000000001 +/- 0.026666666666666665
# 	f1-score: 0.8530151346614083 +/- 0.04258774957864095
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.7814285714285715 +/- 0.07407937847126446
# 	recall: 0.765 +/- 0.087860369020648
# 	f1-score: 0.7683476879943543 +/- 0.08539707452085804
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.7962594893029676 +/- 0.07192289116860584
# 	recall: 0.7999999999999999 +/- 0.06507230237867723
# 	f1-score: 0.7941160413278053 +/- 0.07224669870312396
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=66; N_symbols=199--------------
# Accuracy: 0.8434782608695652 +/- 0.044339300118198095
# Control:
# 	precision: 0.7892857142857144 +/- 0.06428571428571428
# 	recall: 0.75 +/- 0.07905694150420949
# 	f1-score: 0.7683333333333333 +/- 0.06839428176227731
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8708333333333333 +/- 0.0383695481107378
# 	recall: 0.8933333333333333 +/- 0.03265986323710904
# 	f1-score: 0.881720430107527 +/- 0.032953086123660984
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8300595238095237 +/- 0.049350228077870796
# 	recall: 0.8216666666666667 +/- 0.05159941860137573
# 	f1-score: 0.82502688172043 +/- 0.05051764074879101
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8424689440993788 +/- 0.045437764981105126
# 	recall: 0.8434782608695652 +/- 0.044339300118198095
# 	f1-score: 0.8422814399251987 +/- 0.04512197154566213
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=66; N_symbols=147--------------
# Accuracy: 0.8 +/- 0.03478260869565219
# Control:
# 	precision: 0.7428571428571428 +/- 0.05460640448180819
# 	recall: 0.65 +/- 0.09354143466934853
# 	f1-score: 0.6904761904761905 +/- 0.06692128248835805
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8268137254901962 +/- 0.038077729643581575
# 	recall: 0.8800000000000001 +/- 0.026666666666666665
# 	f1-score: 0.8519086021505377 +/- 0.023220952300391957
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.7848354341736694 +/- 0.04061107918931455
# 	recall: 0.765 +/- 0.046889349655450656
# 	f1-score: 0.7711923963133641 +/- 0.044560795198258174
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.7976114358786993 +/- 0.03832261498424095
# 	recall: 0.8 +/- 0.03478260869565219
# 	f1-score: 0.7957581980898951 +/- 0.03787709254509519
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=66; N_symbols=199--------------
# Accuracy: 0.8434782608695652 +/- 0.044339300118198095
# Control:
# 	precision: 0.7892857142857144 +/- 0.06428571428571428
# 	recall: 0.75 +/- 0.07905694150420949
# 	f1-score: 0.7683333333333333 +/- 0.06839428176227731
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8708333333333333 +/- 0.0383695481107378
# 	recall: 0.8933333333333333 +/- 0.03265986323710904
# 	f1-score: 0.881720430107527 +/- 0.032953086123660984
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8300595238095237 +/- 0.049350228077870796
# 	recall: 0.8216666666666667 +/- 0.05159941860137573
# 	f1-score: 0.82502688172043 +/- 0.05051764074879101
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8424689440993788 +/- 0.045437764981105126
# 	recall: 0.8434782608695652 +/- 0.044339300118198095
# 	f1-score: 0.8422814399251987 +/- 0.04512197154566213
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=94; N_symbols=199--------------
# Accuracy: 0.791304347826087 +/- 0.07480282840906631
# Control:
# 	precision: 0.7050793650793651 +/- 0.11305064562259949
# 	recall: 0.65 +/- 0.22912878474779202
# 	f1-score: 0.6631185807656397 +/- 0.1733593608960814
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8343776579457695 +/- 0.08931574311828656
# 	recall: 0.8666666666666666 +/- 0.04216370213557838
# 	f1-score: 0.8464220282106169 +/- 0.04512567319589701
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.7697285115125672 +/- 0.09353876939650194
# 	recall: 0.7583333333333333 +/- 0.10909985232702094
# 	f1-score: 0.7547703044881283 +/- 0.1085719770444335
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.7894043386878897 +/- 0.09038535704742454
# 	recall: 0.791304347826087 +/- 0.07480282840906631
# 	f1-score: 0.78266430736019 +/- 0.08898715607020863
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=94; N_symbols=120--------------
# Accuracy: 0.8608695652173912 +/- 0.0325361511893386
# Control:
# 	precision: 0.786984126984127 +/- 0.03977956392701193
# 	recall: 0.825 +/- 0.1
# 	f1-score: 0.8024836601307189 +/- 0.05181510387458412
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9073809523809523 +/- 0.051751630819878575
# 	recall: 0.8800000000000001 +/- 0.026666666666666665
# 	f1-score: 0.8923364584988611 +/- 0.023525287861449324
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8471825396825396 +/- 0.035216191533618844
# 	recall: 0.8525 +/- 0.04666666666666666
# 	f1-score: 0.8474100593147902 +/- 0.03739339317186448
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8655037957211871 +/- 0.038592573707727555
# 	recall: 0.8608695652173912 +/- 0.0325361511893386
# 	f1-score: 0.861083311240377 +/- 0.0330814896564021
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=94; N_symbols=120--------------
# Accuracy: 0.8608695652173912 +/- 0.0325361511893386
# Control:
# 	precision: 0.786984126984127 +/- 0.03977956392701193
# 	recall: 0.825 +/- 0.1
# 	f1-score: 0.8024836601307189 +/- 0.05181510387458412
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9073809523809523 +/- 0.051751630819878575
# 	recall: 0.8800000000000001 +/- 0.026666666666666665
# 	f1-score: 0.8923364584988611 +/- 0.023525287861449324
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8471825396825396 +/- 0.035216191533618844
# 	recall: 0.8525 +/- 0.04666666666666666
# 	f1-score: 0.8474100593147902 +/- 0.03739339317186448
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8655037957211871 +/- 0.038592573707727555
# 	recall: 0.8608695652173912 +/- 0.0325361511893386
# 	f1-score: 0.861083311240377 +/- 0.0330814896564021
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=94; N_symbols=120--------------
# Accuracy: 0.8608695652173912 +/- 0.0325361511893386
# Control:
# 	precision: 0.786984126984127 +/- 0.03977956392701193
# 	recall: 0.825 +/- 0.1
# 	f1-score: 0.8024836601307189 +/- 0.05181510387458412
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9073809523809523 +/- 0.051751630819878575
# 	recall: 0.8800000000000001 +/- 0.026666666666666665
# 	f1-score: 0.8923364584988611 +/- 0.023525287861449324
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8471825396825396 +/- 0.035216191533618844
# 	recall: 0.8525 +/- 0.04666666666666666
# 	f1-score: 0.8474100593147902 +/- 0.03739339317186448
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8655037957211871 +/- 0.038592573707727555
# 	recall: 0.8608695652173912 +/- 0.0325361511893386
# 	f1-score: 0.861083311240377 +/- 0.0330814896564021
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=94; N_symbols=166--------------
# Accuracy: 0.8347826086956521 +/- 0.04259982161362046
# Control:
# 	precision: 0.7428571428571428 +/- 0.04534240272090699
# 	recall: 0.8 +/- 0.09999999999999999
# 	f1-score: 0.7686274509803923 +/- 0.06837488538887335
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8910714285714286 +/- 0.04804865731097756
# 	recall: 0.8533333333333333 +/- 0.026666666666666665
# 	f1-score: 0.8711902113459399 +/- 0.031259920925918186
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8169642857142858 +/- 0.044350897156756865
# 	recall: 0.8266666666666668 +/- 0.05487359211051443
# 	f1-score: 0.819908831163166 +/- 0.04935143119602849
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8395186335403727 +/- 0.04500450380498833
# 	recall: 0.8347826086956521 +/- 0.04259982161362046
# 	f1-score: 0.8355162077405319 +/- 0.043692251369463884
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=94; N_symbols=120--------------
# Accuracy: 0.8608695652173912 +/- 0.0325361511893386
# Control:
# 	precision: 0.786984126984127 +/- 0.03977956392701193
# 	recall: 0.825 +/- 0.1
# 	f1-score: 0.8024836601307189 +/- 0.05181510387458412
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9073809523809523 +/- 0.051751630819878575
# 	recall: 0.8800000000000001 +/- 0.026666666666666665
# 	f1-score: 0.8923364584988611 +/- 0.023525287861449324
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8471825396825396 +/- 0.035216191533618844
# 	recall: 0.8525 +/- 0.04666666666666666
# 	f1-score: 0.8474100593147902 +/- 0.03739339317186448
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8655037957211871 +/- 0.038592573707727555
# 	recall: 0.8608695652173912 +/- 0.0325361511893386
# 	f1-score: 0.861083311240377 +/- 0.0330814896564021
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=94; N_symbols=150--------------
# Accuracy: 0.8173913043478261 +/- 0.0325361511893386
# Control:
# 	precision: 0.7317460317460317 +/- 0.038276684291388884
# 	recall: 0.75 +/- 0.07905694150420949
# 	f1-score: 0.7392156862745098 +/- 0.052375334859580736
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8663095238095238 +/- 0.03703050773890849
# 	recall: 0.8533333333333333 +/- 0.02666666666666666
# 	f1-score: 0.8592361883574343 +/- 0.024190627127707035
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.7990277777777779 +/- 0.033920587568951825
# 	recall: 0.8016666666666667 +/- 0.041716636702612754
# 	f1-score: 0.799225937315972 +/- 0.03764513254262762
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8195048309178745 +/- 0.03407506704718638
# 	recall: 0.8173913043478261 +/- 0.0325361511893386
# 	f1-score: 0.8174899267633735 +/- 0.033341380789413
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=94; N_symbols=120--------------
# Accuracy: 0.8608695652173912 +/- 0.0325361511893386
# Control:
# 	precision: 0.786984126984127 +/- 0.03977956392701193
# 	recall: 0.825 +/- 0.1
# 	f1-score: 0.8024836601307189 +/- 0.05181510387458412
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9073809523809523 +/- 0.051751630819878575
# 	recall: 0.8800000000000001 +/- 0.026666666666666665
# 	f1-score: 0.8923364584988611 +/- 0.023525287861449324
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8471825396825396 +/- 0.035216191533618844
# 	recall: 0.8525 +/- 0.04666666666666666
# 	f1-score: 0.8474100593147902 +/- 0.03739339317186448
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8655037957211871 +/- 0.038592573707727555
# 	recall: 0.8608695652173912 +/- 0.0325361511893386
# 	f1-score: 0.861083311240377 +/- 0.0330814896564021
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=94; N_symbols=147--------------
# Accuracy: 0.782608695652174 +/- 0.153102755318774
# Control:
# 	precision: 0.7234126984126984 +/- 0.1793440077522917
# 	recall: 0.775 +/- 0.049999999999999996
# 	f1-score: 0.7347058823529411 +/- 0.11978065304668636
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8519047619047619 +/- 0.07225160748786492
# 	recall: 0.7866666666666666 +/- 0.2286190426597633
# 	f1-score: 0.8048430916506557 +/- 0.17566979216993836
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.7876587301587303 +/- 0.12334795167804596
# 	recall: 0.7808333333333334 +/- 0.12120918557051141
# 	f1-score: 0.7697744870017985 +/- 0.14736830200902465
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8072118702553486 +/- 0.10694234534691176
# 	recall: 0.782608695652174 +/- 0.153102755318774
# 	f1-score: 0.7804475405905811 +/- 0.15592393197750284
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=75; N_symbols=199--------------
# Accuracy: 0.8608695652173912 +/- 0.017391304347826077
# Control:
# 	precision: 0.7880952380952381 +/- 0.036161224602839714
# 	recall: 0.825 +/- 0.06123724356957945
# 	f1-score: 0.8041176470588237 +/- 0.02855214376355673
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9054761904761905 +/- 0.028408264263380303
# 	recall: 0.8800000000000001 +/- 0.02666666666666666
# 	f1-score: 0.8919095291064145 +/- 0.012883401423827415
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8467857142857144 +/- 0.01986443092626084
# 	recall: 0.8525 +/- 0.02480479344356203
# 	f1-score: 0.8480135880826192 +/- 0.020106826804617867
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8646480331262939 +/- 0.019488568589694368
# 	recall: 0.8608695652173912 +/- 0.017391304347826077
# 	f1-score: 0.8613732223072524 +/- 0.01770542784261888
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=75; N_symbols=199--------------
# Accuracy: 0.8608695652173912 +/- 0.017391304347826077
# Control:
# 	precision: 0.7880952380952381 +/- 0.036161224602839714
# 	recall: 0.825 +/- 0.06123724356957945
# 	f1-score: 0.8041176470588237 +/- 0.02855214376355673
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9054761904761905 +/- 0.028408264263380303
# 	recall: 0.8800000000000001 +/- 0.02666666666666666
# 	f1-score: 0.8919095291064145 +/- 0.012883401423827415
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8467857142857144 +/- 0.01986443092626084
# 	recall: 0.8525 +/- 0.02480479344356203
# 	f1-score: 0.8480135880826192 +/- 0.020106826804617867
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8646480331262939 +/- 0.019488568589694368
# 	recall: 0.8608695652173912 +/- 0.017391304347826077
# 	f1-score: 0.8613732223072524 +/- 0.01770542784261888
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=75; N_symbols=120--------------
# Accuracy: 0.8695652173913043 +/- 0.07275304578557176
# Control:
# 	precision: 0.8156349206349205 +/- 0.06269117900807113
# 	recall: 0.8 +/- 0.203100960115899
# 	f1-score: 0.7974233283056812 +/- 0.13060203079968913
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9047222222222222 +/- 0.09337466016266849
# 	recall: 0.9066666666666668 +/- 0.03265986323710904
# 	f1-score: 0.9029233058376551 +/- 0.05017475949567549
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8601785714285715 +/- 0.07081119880029849
# 	recall: 0.8533333333333333 +/- 0.10204165815979277
# 	f1-score: 0.8501733170716681 +/- 0.08996964060570177
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8737353347135954 +/- 0.07657872103082448
# 	recall: 0.8695652173913043 +/- 0.07275304578557176
# 	f1-score: 0.8662276614787077 +/- 0.07770977107181772
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=75; N_symbols=120--------------
# Accuracy: 0.8695652173913043 +/- 0.07275304578557176
# Control:
# 	precision: 0.8156349206349205 +/- 0.06269117900807113
# 	recall: 0.8 +/- 0.203100960115899
# 	f1-score: 0.7974233283056812 +/- 0.13060203079968913
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9047222222222222 +/- 0.09337466016266849
# 	recall: 0.9066666666666668 +/- 0.03265986323710904
# 	f1-score: 0.9029233058376551 +/- 0.05017475949567549
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8601785714285715 +/- 0.07081119880029849
# 	recall: 0.8533333333333333 +/- 0.10204165815979277
# 	f1-score: 0.8501733170716681 +/- 0.08996964060570177
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8737353347135954 +/- 0.07657872103082448
# 	recall: 0.8695652173913043 +/- 0.07275304578557176
# 	f1-score: 0.8662276614787077 +/- 0.07770977107181772
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=75; N_symbols=120--------------
# Accuracy: 0.8695652173913043 +/- 0.07275304578557176
# Control:
# 	precision: 0.8156349206349205 +/- 0.06269117900807113
# 	recall: 0.8 +/- 0.203100960115899
# 	f1-score: 0.7974233283056812 +/- 0.13060203079968913
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9047222222222222 +/- 0.09337466016266849
# 	recall: 0.9066666666666668 +/- 0.03265986323710904
# 	f1-score: 0.9029233058376551 +/- 0.05017475949567549
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8601785714285715 +/- 0.07081119880029849
# 	recall: 0.8533333333333333 +/- 0.10204165815979277
# 	f1-score: 0.8501733170716681 +/- 0.08996964060570177
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8737353347135954 +/- 0.07657872103082448
# 	recall: 0.8695652173913043 +/- 0.07275304578557176
# 	f1-score: 0.8662276614787077 +/- 0.07770977107181772
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=75; N_symbols=166--------------
# Accuracy: 0.8434782608695652 +/- 0.05217391304347822
# Control:
# 	precision: 0.7726984126984128 +/- 0.05426993180027453
# 	recall: 0.775 +/- 0.1457737973711325
# 	f1-score: 0.7691503267973856 +/- 0.08860238332901592
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8857142857142858 +/- 0.0717403908092881
# 	recall: 0.8800000000000001 +/- 0.02666666666666666
# 	f1-score: 0.8811536627999365 +/- 0.036264881411864625
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8292063492063493 +/- 0.05587143052179057
# 	recall: 0.8275 +/- 0.07296308046615843
# 	f1-score: 0.8251519947986612 +/- 0.06229721167805671
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8464044168391995 +/- 0.05951672410595383
# 	recall: 0.8434782608695652 +/- 0.05217391304347822
# 	f1-score: 0.8421959807120926 +/- 0.05432731612481526
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=75; N_symbols=150--------------
# Accuracy: 0.8782608695652174 +/- 0.017391304347826077
# Control:
# 	precision: 0.7871212121212121 +/- 0.048096614836585984
# 	recall: 0.9 +/- 0.049999999999999996
# 	f1-score: 0.8375386996904025 +/- 0.020064809828870475
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9438095238095239 +/- 0.028155705712560906
# 	recall: 0.8666666666666668 +/- 0.04216370213557838
# 	f1-score: 0.9023754789272032 +/- 0.015760870660147044
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8654653679653681 +/- 0.019770303363521594
# 	recall: 0.8833333333333332 +/- 0.015365907428821478
# 	f1-score: 0.8699570893088028 +/- 0.01723484313250363
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8893092414831546 +/- 0.01634397045130462
# 	recall: 0.8782608695652174 +/- 0.017391304347826077
# 	f1-score: 0.8798235557144028 +/- 0.016619631781203303
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=75; N_symbols=150--------------
# Accuracy: 0.8782608695652174 +/- 0.017391304347826077
# Control:
# 	precision: 0.7871212121212121 +/- 0.048096614836585984
# 	recall: 0.9 +/- 0.049999999999999996
# 	f1-score: 0.8375386996904025 +/- 0.020064809828870475
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9438095238095239 +/- 0.028155705712560906
# 	recall: 0.8666666666666668 +/- 0.04216370213557838
# 	f1-score: 0.9023754789272032 +/- 0.015760870660147044
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8654653679653681 +/- 0.019770303363521594
# 	recall: 0.8833333333333332 +/- 0.015365907428821478
# 	f1-score: 0.8699570893088028 +/- 0.01723484313250363
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8893092414831546 +/- 0.01634397045130462
# 	recall: 0.8782608695652174 +/- 0.017391304347826077
# 	f1-score: 0.8798235557144028 +/- 0.016619631781203303
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=75; N_symbols=150--------------
# Accuracy: 0.8782608695652174 +/- 0.017391304347826077
# Control:
# 	precision: 0.7871212121212121 +/- 0.048096614836585984
# 	recall: 0.9 +/- 0.049999999999999996
# 	f1-score: 0.8375386996904025 +/- 0.020064809828870475
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9438095238095239 +/- 0.028155705712560906
# 	recall: 0.8666666666666668 +/- 0.04216370213557838
# 	f1-score: 0.9023754789272032 +/- 0.015760870660147044
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8654653679653681 +/- 0.019770303363521594
# 	recall: 0.8833333333333332 +/- 0.015365907428821478
# 	f1-score: 0.8699570893088028 +/- 0.01723484313250363
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8893092414831546 +/- 0.01634397045130462
# 	recall: 0.8782608695652174 +/- 0.017391304347826077
# 	f1-score: 0.8798235557144028 +/- 0.016619631781203303
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=75; N_symbols=147--------------
# Accuracy: 0.8434782608695652 +/- 0.044339300118198095
# Control:
# 	precision: 0.8072222222222223 +/- 0.043518124505702534
# 	recall: 0.725 +/- 0.1457737973711325
# 	f1-score: 0.7556399482870072 +/- 0.08974334659493445
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8659757236227824 +/- 0.06006049335105103
# 	recall: 0.9066666666666666 +/- 0.03265986323710904
# 	f1-score: 0.8840073145245558 +/- 0.02910015024253231
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8365989729225024 +/- 0.03995510718769181
# 	recall: 0.8158333333333333 +/- 0.06642665127793211
# 	f1-score: 0.8198236314057816 +/- 0.05868851092783489
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8455397231356312 +/- 0.04431766584953586
# 	recall: 0.8434782608695652 +/- 0.044339300118198095
# 	f1-score: 0.8393577958332346 +/- 0.049404452797641135
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=75; N_symbols=150--------------
# Accuracy: 0.8782608695652174 +/- 0.017391304347826077
# Control:
# 	precision: 0.7871212121212121 +/- 0.048096614836585984
# 	recall: 0.9 +/- 0.049999999999999996
# 	f1-score: 0.8375386996904025 +/- 0.020064809828870475
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9438095238095239 +/- 0.028155705712560906
# 	recall: 0.8666666666666668 +/- 0.04216370213557838
# 	f1-score: 0.9023754789272032 +/- 0.015760870660147044
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8654653679653681 +/- 0.019770303363521594
# 	recall: 0.8833333333333332 +/- 0.015365907428821478
# 	f1-score: 0.8699570893088028 +/- 0.01723484313250363
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8893092414831546 +/- 0.01634397045130462
# 	recall: 0.8782608695652174 +/- 0.017391304347826077
# 	f1-score: 0.8798235557144028 +/- 0.016619631781203303
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=23; N_symbols=199--------------
# Accuracy: 0.8347826086956521 +/- 0.06956521739130433
# Control:
# 	precision: 0.7928571428571429 +/- 0.08629104892581012
# 	recall: 0.7 +/- 0.15
# 	f1-score: 0.7404761904761905 +/- 0.119083327977797
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8534803921568628 +/- 0.0681327407165952
# 	recall: 0.9066666666666666 +/- 0.03265986323710904
# 	f1-score: 0.8785752688172043 +/- 0.04891805460765273
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8231687675070027 +/- 0.07519928205660173
# 	recall: 0.8033333333333333 +/- 0.08789197915623471
# 	f1-score: 0.8095257296466973 +/- 0.08388863435272635
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8323940445743514 +/- 0.072555312724888
# 	recall: 0.8347826086956521 +/- 0.06956521739130433
# 	f1-score: 0.8305408067855472 +/- 0.0732068686306249
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=75; N_symbols=150--------------
# Accuracy: 0.8782608695652174 +/- 0.017391304347826077
# Control:
# 	precision: 0.7871212121212121 +/- 0.048096614836585984
# 	recall: 0.9 +/- 0.049999999999999996
# 	f1-score: 0.8375386996904025 +/- 0.020064809828870475
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9438095238095239 +/- 0.028155705712560906
# 	recall: 0.8666666666666668 +/- 0.04216370213557838
# 	f1-score: 0.9023754789272032 +/- 0.015760870660147044
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8654653679653681 +/- 0.019770303363521594
# 	recall: 0.8833333333333332 +/- 0.015365907428821478
# 	f1-score: 0.8699570893088028 +/- 0.01723484313250363
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8893092414831546 +/- 0.01634397045130462
# 	recall: 0.8782608695652174 +/- 0.017391304347826077
# 	f1-score: 0.8798235557144028 +/- 0.016619631781203303
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=23; N_symbols=120--------------
# Accuracy: 0.826086956521739 +/- 0.027498066610159803
# Control:
# 	precision: 0.7484126984126984 +/- 0.020171849249426718
# 	recall: 0.75 +/- 0.07905694150420949
# 	f1-score: 0.7480392156862745 +/- 0.049662451536917444
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8682142857142857 +/- 0.0367539159836888
# 	recall: 0.8666666666666668 +/- 1.1102230246251565e-16
# 	f1-score: 0.8670522803114572 +/- 0.01829735728688621
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.808313492063492 +/- 0.028391491376200687
# 	recall: 0.8083333333333333 +/- 0.03952847075210474
# 	f1-score: 0.8075457479988659 +/- 0.03396150948815451
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8265441683919945 +/- 0.03092675490038098
# 	recall: 0.826086956521739 +/- 0.027498066610159803
# 	f1-score: 0.8256564317461763 +/- 0.029187535419383768
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=75; N_symbols=150--------------
# Accuracy: 0.8782608695652174 +/- 0.017391304347826077
# Control:
# 	precision: 0.7871212121212121 +/- 0.048096614836585984
# 	recall: 0.9 +/- 0.049999999999999996
# 	f1-score: 0.8375386996904025 +/- 0.020064809828870475
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9438095238095239 +/- 0.028155705712560906
# 	recall: 0.8666666666666668 +/- 0.04216370213557838
# 	f1-score: 0.9023754789272032 +/- 0.015760870660147044
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8654653679653681 +/- 0.019770303363521594
# 	recall: 0.8833333333333332 +/- 0.015365907428821478
# 	f1-score: 0.8699570893088028 +/- 0.01723484313250363
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8893092414831546 +/- 0.01634397045130462
# 	recall: 0.8782608695652174 +/- 0.017391304347826077
# 	f1-score: 0.8798235557144028 +/- 0.016619631781203303
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=23; N_symbols=166--------------
# Accuracy: 0.8 +/- 0.08064016083039742
# Control:
# 	precision: 0.758095238095238 +/- 0.0775123426642888
# 	recall: 0.6 +/- 0.25495097567963926
# 	f1-score: 0.6478676878676879 +/- 0.18380478444842013
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8234967320261438 +/- 0.10450265051321542
# 	recall: 0.9066666666666666 +/- 0.03265986323710904
# 	f1-score: 0.858556416701578 +/- 0.0500977848022012
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.7907959850606909 +/- 0.08340891610100805
# 	recall: 0.7533333333333333 +/- 0.12048513047951877
# 	f1-score: 0.7532120522846331 +/- 0.11614515142953463
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8007483863110462 +/- 0.08856778902012971
# 	recall: 0.8 +/- 0.08064016083039742
# 	f1-score: 0.7852733805854424 +/- 0.09571802860168493
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=75; N_symbols=150--------------
# Accuracy: 0.8782608695652174 +/- 0.017391304347826077
# Control:
# 	precision: 0.7871212121212121 +/- 0.048096614836585984
# 	recall: 0.9 +/- 0.049999999999999996
# 	f1-score: 0.8375386996904025 +/- 0.020064809828870475
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9438095238095239 +/- 0.028155705712560906
# 	recall: 0.8666666666666668 +/- 0.04216370213557838
# 	f1-score: 0.9023754789272032 +/- 0.015760870660147044
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8654653679653681 +/- 0.019770303363521594
# 	recall: 0.8833333333333332 +/- 0.015365907428821478
# 	f1-score: 0.8699570893088028 +/- 0.01723484313250363
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8893092414831546 +/- 0.01634397045130462
# 	recall: 0.8782608695652174 +/- 0.017391304347826077
# 	f1-score: 0.8798235557144028 +/- 0.016619631781203303
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=23; N_symbols=150--------------
# Accuracy: 0.8695652173913043 +/- 0.06735623210795508
# Control:
# 	precision: 0.7864285714285715 +/- 0.09794834123669684
# 	recall: 0.875 +/- 0.11180339887498948
# 	f1-score: 0.8238888888888889 +/- 0.08526646685755417
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9308974358974359 +/- 0.06302739352052246
# 	recall: 0.8666666666666666 +/- 0.07302967433402217
# 	f1-score: 0.8958832565284178 +/- 0.05609038528186582
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8586630036630037 +/- 0.06917593206802428
# 	recall: 0.8708333333333332 +/- 0.07274384280931731
# 	f1-score: 0.8598860727086534 +/- 0.07024986596637758
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8806473960821787 +/- 0.06414773457747373
# 	recall: 0.8695652173913043 +/- 0.06735623210795508
# 	f1-score: 0.8708417373494513 +/- 0.06582361733280892
# 	support: 23.0 +/- 0.0
# 		--------------ACTUAL BEST: J_ins=75; N_symbols=150--------------
# Accuracy: 0.8782608695652174 +/- 0.017391304347826077
# Control:
# 	precision: 0.7871212121212121 +/- 0.048096614836585984
# 	recall: 0.9 +/- 0.049999999999999996
# 	f1-score: 0.8375386996904025 +/- 0.020064809828870475
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.9438095238095239 +/- 0.028155705712560906
# 	recall: 0.8666666666666668 +/- 0.04216370213557838
# 	f1-score: 0.9023754789272032 +/- 0.015760870660147044
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8654653679653681 +/- 0.019770303363521594
# 	recall: 0.8833333333333332 +/- 0.015365907428821478
# 	f1-score: 0.8699570893088028 +/- 0.01723484313250363
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8893092414831546 +/- 0.01634397045130462
# 	recall: 0.8782608695652174 +/- 0.017391304347826077
# 	f1-score: 0.8798235557144028 +/- 0.016619631781203303
# 	support: 23.0 +/- 0.0
# 		--------------ITERATION: J_ins=23; N_symbols=147--------------
# Accuracy: 0.8608695652173912 +/- 0.0325361511893386
# Control:
# 	precision: 0.8269841269841269 +/- 0.09499307104990905
# 	recall: 0.775 +/- 0.049999999999999996
# 	f1-score: 0.7961344537815126 +/- 0.0418191991855553
# 	support: 8.0 +/- 0.0
# Estudio:
# 	precision: 0.8838515406162465 +/- 0.023113215854189968
# 	recall: 0.9066666666666666 +/- 0.053333333333333316
# 	f1-score: 0.8941221727845754 +/- 0.026374322330761358
# 	support: 15.0 +/- 0.0
# macro avg:
# 	precision: 0.8554178338001867 +/- 0.04879953958258224
# 	recall: 0.8408333333333333 +/- 0.02891558595482912
# 	f1-score: 0.845128313283044 +/- 0.0337528891460363
# 	support: 23.0 +/- 0.0
# weighted avg:
# 	precision: 0.8640715706572484 +/- 0.03621602195476972
# 	recall: 0.8608695652173912 +/- 0.0325361511893386
# 	f1-score: 0.8600394879139449 +/- 0.03141125407937188
# 	support: 23.0 +/- 0.0
# ((75, 150),
#  {'accuracy': (0.8782608695652174, 0.017391304347826077),
#   'Control': {'precision': (0.7871212121212121, 0.048096614836585984),
#    'recall': (0.9, 0.049999999999999996),
#    'f1-score': (0.8375386996904025, 0.020064809828870475),
#    'support': (8.0, 0.0)},
#   'Estudio': {'precision': (0.9438095238095239, 0.028155705712560906),
#    'recall': (0.8666666666666668, 0.04216370213557838),
#    'f1-score': (0.9023754789272032, 0.015760870660147044),
#    'support': (15.0, 0.0)},
#   'macro avg': {'precision': (0.8654653679653681, 0.019770303363521594),
#    'recall': (0.8833333333333332, 0.015365907428821478),
#    'f1-score': (0.8699570893088028, 0.01723484313250363),
#    'support': (23.0, 0.0)},
#   'weighted avg': {'precision': (0.8893092414831546, 0.01634397045130462),
#    'recall': (0.8782608695652174, 0.017391304347826077),
#    'f1-score': (0.8798235557144028, 0.016619631781203303),
#    'support': (23.0, 0.0)}})

# %% [markdown]
# # <font color=#cd0000> Análisis de resultados </font>
# - Según la búsqueda aleatoria de hiper-parámetros, la mejor combinación, es la de ``j_ins`` = 75 y ``n_symbols`` = 150:
#     ```
#         Accuracy: 0.8782608695652174 +/- 0.017391304347826077
#         Control:
#             precision: 0.7871212121212121 +/- 0.048096614836585984
#             recall: 0.9 +/- 0.049999999999999996
#             f1-score: 0.8375386996904025 +/- 0.020064809828870475
#             support: 8.0 +/- 0.0
#         Estudio:
#             precision: 0.9438095238095239 +/- 0.028155705712560906
#             recall: 0.8666666666666668 +/- 0.04216370213557838
#             f1-score: 0.9023754789272032 +/- 0.015760870660147044
#             support: 15.0 +/- 0.0
#         macro avg:
#             precision: 0.8654653679653681 +/- 0.019770303363521594
#             recall: 0.8833333333333332 +/- 0.015365907428821478
#             f1-score: 0.8699570893088028 +/- 0.01723484313250363
#             support: 23.0 +/- 0.0
#         weighted avg:
#             precision: 0.8893092414831546 +/- 0.01634397045130462
#             recall: 0.8782608695652174 +/- 0.017391304347826077
#             f1-score: 0.8798235557144028 +/- 0.016619631781203303
#             support: 23.0 +/- 0.0
#     ```
# - Ahora vamos a visualizar la evolución de los resultados (25 resultados) para observar cómo avanza nuestra métrica objetivo -> Macro Average F1-Score.

# %%
import pickle

all_reports = pickle.load(open(PKL_DIR + PKL_NAME, 'rb'))

# %%
from utils.plot_utils import plot_score

macro_avg_f1_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['macro avg']['f1-score'][0],
                   'std': all_reports[z]['macro avg']['f1-score'][1]}),
    all_reports
))

plot_score(
    [macro_avg_f1_scores],
    ('j_ins', 'n_symbols'),
    'SMTS',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Macro Average F1-Score'
)

# %%
estudio_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['Estudio']['recall'][0],
                   'std': all_reports[z]['Estudio']['recall'][1]}),
    all_reports
))

control_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['Control']['recall'][0],
                   'std': all_reports[z]['Control']['recall'][1]}),
    all_reports
))

plot_score(
    [estudio_recall_scores],
    ('j_ins', 'n_symbols'),
    'SMTS',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Estudio recall score'
)

plot_score(
    [control_recall_scores],
    ('j_ins', 'n_symbols'),
    'SMTS',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Control recall score'
)

# %% [markdown]
# # <font color=#cd0000> Conclusiones </font>
# - TODO - Unas breves conclusiones sobre los resultados obtenidos (influencia de la codificación, ...)
