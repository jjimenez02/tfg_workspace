# %% [markdown]
# # <font color=#cd0000> Propósito principal </font>
# - La idea de este librillo es preparar el entorno para realizar pruebas para Seguimiento Ocular a ser clasificado con la Tendencia y Aceleración y LSTM
#
# ## <font color=#cd0000> Leyenda </font>
# - Los apartados titulados con el código de colores HEX: `#cd0000` serán apartados que tendrán todos los librillos, en concreto, aquellos especificados en el apartado `Síntesis de los criterios usados` del trabajo.
# - Los apartados titulados con el código de colores HEX: `#2451ff` serán apartados de conclusiones propias de este librillo resultado de aplicar un estudio personalizado para cada planteamiento.

# %% [markdown]
# # <font color=#cd0000> Prerrequisitos </font>
# ## <font color=#cd0000> Entorno de ejecución </font>
# - Cambiamos el directorio raíz del librillo para acceder cómodamente a las funciones de utilidad.

# %%
import os

os.chdir('../../../../')
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.gitmodules',
#  'data',
#  'HeartBeat_tmp_test_data.pkl',
#  'HeartBeat_tmp_train_data.pkl',
#  'pkl',
#  'Pruebas',
#  'README.md',
#  'smts_implementation',
#  'utils']

# %% [markdown]
# ## <font color=#cd0000> Constantes y variables predefinidas </font>

# %%
SEGUIMIENTO_OCULAR_PATH = "data/seguimiento-ocular/Data/Hospital"
SEGUIMIENTO_OCULAR_FOLDERS_ID = range(1, 12+1)

DATA_TO_SAVE = "SegOcular"

PKL_DIR = "pkl/LSTM/SegOcular/"
PKL_NAME = "segocular_LSTM_trend_acc.pkl"

SEED = 1

# %% [markdown]
# # <font color=#cd0000> Carga del Dataset </font>

# %%
from utils.load_data import import_seguimiento_ocular_dataset

all_data = import_seguimiento_ocular_dataset(
    SEGUIMIENTO_OCULAR_PATH, SEGUIMIENTO_OCULAR_FOLDERS_ID)

# %%
all_data.reset_changes()

# %% [markdown]
# # <font color=#cd0000> Preprocesamiento </font>

# %% [markdown]
# ## <font color=#cd0000> Eliminación de datos inválidos y valores atípicos </font>
# - No eliminaremos aquellos valores fuera de los percentiles 5 y 95 ante la falta de información.

# %% [markdown]
# ### <font color=#2451ff> Limpieza de datos </font>
# - Eliminaremos todos aquellos valores inválidos con un "0" en alguna de las columnas `*Validity*`.

# %%
# Clean data
validity_headers = ['ValidityLeft',
                    'ValidityRight',
                    'PupilValidityLeft',
                    'PupilValidityRight']

all_data.clean_data(criterion='remove', value=0, headers=validity_headers, drop_columns=validity_headers)

# %% [markdown]
# ## <font color=#2451ff> Reducción de la dimensionalidad </font>
# - Eliminamos los atributos redundantes/no informativos (o que puedan sesgar al modelo).

# %%
# Reduce data
columns_to_remove = ['GazePointX', 'GazePointY', 'diagnosis', 'Age']
all_data.drop_derived_data_columns(columns_to_remove)
# Out:
#          id  TimeStamp  GazePointXLeft  GazePointYLeft  GazePointXRight  \
# 0       1-1    704.487             875             549              771
# 1       1-1    750.040             879             519              796
# 2       1-1    776.032             898             547              785
# 3       1-1    831.135             882             563              768
# 4       1-1    857.075             879             513              789
# ...     ...        ...             ...             ...              ...
# 36362  12-3  54379.209             162             808              263
# 36363  12-3  54406.850             136             816              272
# 36364  12-3  54433.946             122             942              191
# 36365  12-3  54460.926             326             918              364
# 36366  12-3  54487.080             354             938              363
#
#        GazePointYRight  PupilSizeLeft  PupilSizeRight    class
# 0                  284         2.1565          2.1575  Control
# 1                  245         2.0449          2.1528  Control
# 2                  316         2.1199          2.1833  Control
# 3                  322         2.1039          2.3215  Control
# 4                  362         2.0490          2.4636  Control
# ...                ...            ...             ...      ...
# 36362              944         2.6453          2.4885  Estudio
# 36363              969         2.6189          2.4906  Estudio
# 36364              854         2.5684          2.2774  Estudio
# 36365              936         2.3562          2.6705  Estudio
# 36366              988         2.2507          2.5588  Estudio
#
# [36367 rows x 9 columns]

# %% [markdown]
# ## <font color=#2451ff> Eliminación de series cortas </font>
# - Ante la limpieza de los datos hemos acabado con series, concretamente, la ``8-1`` (72 muestras) y ``8-2`` (202 muestras), con muy pocas muestras.
#   - Las eliminaremos con el fin de no obtener ventanas demasiado pequeñas (72/4 = 18 muestras por ventana)

# %%
all_data.derived_data = all_data.derived_data[
    all_data.derived_data['id'] != '8-1']  # 72 samples
all_data.derived_data = all_data.derived_data[
    all_data.derived_data['id'] != '8-2']  # 202 samples

# %%
import pandas as pd

# Remaining series
print("Previous number of series: {}".format(
    len(pd.unique(all_data.original_data['id']))))
print("Actual number of series: {}".format(
    len(pd.unique(all_data.derived_data['id']))))

print("Previous largest serie: {}".format(
    all_data.get_largest_serie(all_data.original_data).shape[0]))
print("Actual largest serie: {}".format(
    all_data.get_largest_serie().shape[0]))

print("Previous shortest serie: {}".format(
    all_data.get_shortest_serie(all_data.original_data).shape[0]))
print("Actual shortest serie: {}".format(
    all_data.get_shortest_serie().shape[0]))
# Out:
# Previous number of series: 25
# Actual number of series: 23
# Previous largest serie: 2113
# Actual largest serie: 1901
# Previous shortest serie: 967
# Actual shortest serie: 768

# %% [markdown]
# ## <font color=#cd0000> Resoluciones a aplicar </font>
# - Como vimos en el análisis en profundidad, mantendremos la resolución actual

# %%
# Nothing to see here

# %% [markdown]
# # <font color=#cd0000> División en ventanas </font>
# - El número de ventanas por serie será de 4 como ya vimos en el análisis en profundidad.

# %%
all_data.split_into_windows(n_windows=4)

# %%
all_data.get_derived_data_classes_count()
# Out:
# Estudio    60
# Control    32
# Name: class, dtype: int64

# %% [markdown]
# # <font color=#cd0000> Codificación </font>
# - Trend + Acc

# %%
from utils.codifications import temporal_trend_fn

# Trend
all_data.apply_codifications([temporal_trend_fn])

# %%
columns = all_data.get_derived_data_columns()['attrs']
trend_columns = list(filter(lambda z: 'Diff' in z, columns))

# Acceleration
all_data.apply_codifications([temporal_trend_fn], headers=trend_columns)

# %% [markdown]
# ## <font color=#2451ff> Codificación de la clase </font>

# %%
from sklearn.preprocessing import LabelEncoder

enc = LabelEncoder()
all_data.apply_codification_to_class(enc)

# %% [markdown]
# # <font color=#2451ff> Particionado inicial de los datos y normalización </font>
# - Llevaremos a cabo el particionado empleado por Marta en su TFM: http://hdl.handle.net/10486/697441

# %%
import numpy as np
from utils.data_extraction import Data

X_train, X_test, y_train, y_test = all_data.train_test_split(
    criterion='tfm_marta',
    train_size=.8,
    random_state=SEED,
    standardize_columns=all_data.get_derived_data_columns()['attrs'],
    drop_columns=['TimeStamp', 'class']
)

y_train = np.asarray(y_train)
y_test = np.asarray(y_test)

X_train_Data = Data(X_train)
X_test_Data = Data(X_test)

# %% [markdown]
# ## <font color=#cd0000> Preparación de los datos </font>

# %%
max_sequence_length = max(X_train_Data.get_largest_serie().shape[0],
                          X_test_Data.get_largest_serie().shape[0])

X_train = X_train.drop('id', axis=1).to_numpy()
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))

X_test = X_test.drop('id', axis=1).to_numpy()
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# %% [markdown]
# ## <font color=#cd0000> Técnicas de balanceo </font>

# %% [markdown]
# ### <font color=#cd0000> Asignación de pesos a las clases </font>

# %%
import numpy as np
from sklearn.utils import compute_class_weight

class_weights = compute_class_weight(
    'balanced', classes=np.unique(y_train), y=y_train)
class_weights = {0: class_weights[0], 1: class_weights[1]}

# %% [markdown]
# # <font color=#cd0000> Diseño de la topología de red </font>

# %%
X_train.shape[2]
# Out:
# 18

# %%
import keras as k
from keras.models import Sequential
from keras.layers import LSTM, Dense, Masking

nn = Sequential()

# Number of initial dimensions
nn.add(LSTM(units=4))
# Number of SegOcular's classes
nn.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## <font color=#cd0000> Compilación de la red </font>

# %%
from keras.optimizers import Adam

metrics = [
    k.metrics.CategoricalAccuracy(name="ACC"),
    k.metrics.Precision(name='Prec'),
    k.metrics.Recall(name='Rec'),
    k.metrics.AUC(name='AUC')
]

nn.compile(optimizer=Adam(learning_rate=1e-3), loss='mse', metrics=metrics)

# %% [markdown]
# ## <font color=#cd0000> Visualización de resultados preliminares </font>

# %%
import matplotlib.pyplot as plt


def show_metrics(history):
    for metric in history.history.keys():
        if not metric.startswith('val_'):
            plt.plot(history.history[metric], label=metric)
            plt.plot(history.history[f'val_{metric}'], label=f'val_{metric}')
            plt.title(metric)
            plt.ylabel('')
            plt.xlabel('Epoch')
            plt.legend(loc="upper left")
            plt.show()

# %% [markdown]
# ## <font color=#cd0000> Entrenamiento del modelo </font>

# %%
import numpy as np
from keras import backend as K
from sklearn.metrics import confusion_matrix, classification_report

epochs = 100

history = nn.fit(X_train, y_train, epochs=epochs,
                 validation_data=(X_test, y_test),
                 batch_size=max_sequence_length,
                 class_weight=class_weights,
                 verbose=1)
nn.summary()
print('\n\n')

y_pred = nn.predict(X_test)
y_pred = y_pred > 0.5

show_metrics(history)
# Out:
# Epoch 1/100
# 57/57 [==============================] - 1s 11ms/step - loss: 0.0740 - ACC: 1.0000 - Prec: 0.9533 - Rec: 0.8783 - AUC: 0.9589 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9515 - val_Rec: 0.8751 - val_AUC: 0.9496
# Epoch 2/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0738 - ACC: 1.0000 - Prec: 0.9546 - Rec: 0.8772 - AUC: 0.9589 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9522 - val_Rec: 0.8747 - val_AUC: 0.9498
# Epoch 3/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0738 - ACC: 1.0000 - Prec: 0.9531 - Rec: 0.8806 - AUC: 0.9591 - val_loss: 0.0825 - val_ACC: 1.0000 - val_Prec: 0.9529 - val_Rec: 0.8751 - val_AUC: 0.9495
# Epoch 4/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0738 - ACC: 1.0000 - Prec: 0.9540 - Rec: 0.8788 - AUC: 0.9591 - val_loss: 0.0826 - val_ACC: 1.0000 - val_Prec: 0.9533 - val_Rec: 0.8742 - val_AUC: 0.9496
# Epoch 5/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0738 - ACC: 1.0000 - Prec: 0.9545 - Rec: 0.8789 - AUC: 0.9590 - val_loss: 0.0827 - val_ACC: 1.0000 - val_Prec: 0.9518 - val_Rec: 0.8739 - val_AUC: 0.9494
# Epoch 6/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0738 - ACC: 1.0000 - Prec: 0.9537 - Rec: 0.8794 - AUC: 0.9589 - val_loss: 0.0824 - val_ACC: 1.0000 - val_Prec: 0.9515 - val_Rec: 0.8754 - val_AUC: 0.9494
# Epoch 7/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0738 - ACC: 1.0000 - Prec: 0.9542 - Rec: 0.8776 - AUC: 0.9590 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9513 - val_Rec: 0.8758 - val_AUC: 0.9495
# Epoch 8/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0737 - ACC: 1.0000 - Prec: 0.9536 - Rec: 0.8809 - AUC: 0.9593 - val_loss: 0.0828 - val_ACC: 1.0000 - val_Prec: 0.9531 - val_Rec: 0.8721 - val_AUC: 0.9496
# Epoch 9/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0738 - ACC: 1.0000 - Prec: 0.9542 - Rec: 0.8789 - AUC: 0.9590 - val_loss: 0.0829 - val_ACC: 1.0000 - val_Prec: 0.9539 - val_Rec: 0.8716 - val_AUC: 0.9493
# Epoch 10/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0737 - ACC: 1.0000 - Prec: 0.9538 - Rec: 0.8802 - AUC: 0.9591 - val_loss: 0.0827 - val_ACC: 1.0000 - val_Prec: 0.9532 - val_Rec: 0.8723 - val_AUC: 0.9495
# Epoch 11/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0737 - ACC: 1.0000 - Prec: 0.9552 - Rec: 0.8774 - AUC: 0.9591 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9520 - val_Rec: 0.8749 - val_AUC: 0.9497
# Epoch 12/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0737 - ACC: 1.0000 - Prec: 0.9533 - Rec: 0.8799 - AUC: 0.9591 - val_loss: 0.0827 - val_ACC: 1.0000 - val_Prec: 0.9532 - val_Rec: 0.8730 - val_AUC: 0.9495
# Epoch 13/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0737 - ACC: 1.0000 - Prec: 0.9548 - Rec: 0.8783 - AUC: 0.9590 - val_loss: 0.0825 - val_ACC: 1.0000 - val_Prec: 0.9516 - val_Rec: 0.8740 - val_AUC: 0.9494
# Epoch 14/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0737 - ACC: 1.0000 - Prec: 0.9535 - Rec: 0.8813 - AUC: 0.9591 - val_loss: 0.0825 - val_ACC: 1.0000 - val_Prec: 0.9522 - val_Rec: 0.8753 - val_AUC: 0.9495
# Epoch 15/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0737 - ACC: 1.0000 - Prec: 0.9546 - Rec: 0.8785 - AUC: 0.9590 - val_loss: 0.0826 - val_ACC: 1.0000 - val_Prec: 0.9516 - val_Rec: 0.8737 - val_AUC: 0.9496
# Epoch 16/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0737 - ACC: 1.0000 - Prec: 0.9537 - Rec: 0.8786 - AUC: 0.9591 - val_loss: 0.0826 - val_ACC: 1.0000 - val_Prec: 0.9532 - val_Rec: 0.8731 - val_AUC: 0.9495
# Epoch 17/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0737 - ACC: 1.0000 - Prec: 0.9541 - Rec: 0.8788 - AUC: 0.9590 - val_loss: 0.0826 - val_ACC: 1.0000 - val_Prec: 0.9522 - val_Rec: 0.8753 - val_AUC: 0.9494
# Epoch 18/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9532 - Rec: 0.8809 - AUC: 0.9593 - val_loss: 0.0827 - val_ACC: 1.0000 - val_Prec: 0.9538 - val_Rec: 0.8735 - val_AUC: 0.9496
# Epoch 19/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0737 - ACC: 1.0000 - Prec: 0.9549 - Rec: 0.8785 - AUC: 0.9590 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9526 - val_Rec: 0.8754 - val_AUC: 0.9494
# Epoch 20/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9539 - Rec: 0.8794 - AUC: 0.9592 - val_loss: 0.0829 - val_ACC: 1.0000 - val_Prec: 0.9528 - val_Rec: 0.8733 - val_AUC: 0.9494
# Epoch 21/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0737 - ACC: 1.0000 - Prec: 0.9541 - Rec: 0.8795 - AUC: 0.9590 - val_loss: 0.0830 - val_ACC: 1.0000 - val_Prec: 0.9527 - val_Rec: 0.8733 - val_AUC: 0.9490
# Epoch 22/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9540 - Rec: 0.8800 - AUC: 0.9591 - val_loss: 0.0824 - val_ACC: 1.0000 - val_Prec: 0.9525 - val_Rec: 0.8746 - val_AUC: 0.9496
# Epoch 23/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9537 - Rec: 0.8792 - AUC: 0.9594 - val_loss: 0.0827 - val_ACC: 1.0000 - val_Prec: 0.9530 - val_Rec: 0.8733 - val_AUC: 0.9496
# Epoch 24/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9536 - Rec: 0.8795 - AUC: 0.9592 - val_loss: 0.0826 - val_ACC: 1.0000 - val_Prec: 0.9519 - val_Rec: 0.8737 - val_AUC: 0.9496
# Epoch 25/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9540 - Rec: 0.8799 - AUC: 0.9592 - val_loss: 0.0824 - val_ACC: 1.0000 - val_Prec: 0.9536 - val_Rec: 0.8744 - val_AUC: 0.9496
# Epoch 26/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9552 - Rec: 0.8770 - AUC: 0.9590 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9512 - val_Rec: 0.8770 - val_AUC: 0.9494
# Epoch 27/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9527 - Rec: 0.8803 - AUC: 0.9593 - val_loss: 0.0830 - val_ACC: 1.0000 - val_Prec: 0.9534 - val_Rec: 0.8726 - val_AUC: 0.9492
# Epoch 28/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0735 - ACC: 1.0000 - Prec: 0.9547 - Rec: 0.8782 - AUC: 0.9593 - val_loss: 0.0822 - val_ACC: 1.0000 - val_Prec: 0.9504 - val_Rec: 0.8765 - val_AUC: 0.9496
# Epoch 29/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9529 - Rec: 0.8811 - AUC: 0.9593 - val_loss: 0.0827 - val_ACC: 1.0000 - val_Prec: 0.9531 - val_Rec: 0.8742 - val_AUC: 0.9495
# Epoch 30/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9546 - Rec: 0.8796 - AUC: 0.9592 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9522 - val_Rec: 0.8747 - val_AUC: 0.9497
# Epoch 31/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9541 - Rec: 0.8794 - AUC: 0.9591 - val_loss: 0.0826 - val_ACC: 1.0000 - val_Prec: 0.9536 - val_Rec: 0.8735 - val_AUC: 0.9497
# Epoch 32/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0735 - ACC: 1.0000 - Prec: 0.9537 - Rec: 0.8804 - AUC: 0.9593 - val_loss: 0.0827 - val_ACC: 1.0000 - val_Prec: 0.9534 - val_Rec: 0.8726 - val_AUC: 0.9494
# Epoch 33/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9543 - Rec: 0.8796 - AUC: 0.9592 - val_loss: 0.0828 - val_ACC: 1.0000 - val_Prec: 0.9538 - val_Rec: 0.8733 - val_AUC: 0.9495
# Epoch 34/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0736 - ACC: 1.0000 - Prec: 0.9537 - Rec: 0.8796 - AUC: 0.9592 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9515 - val_Rec: 0.8758 - val_AUC: 0.9498
# Epoch 35/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0735 - ACC: 1.0000 - Prec: 0.9548 - Rec: 0.8792 - AUC: 0.9592 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9520 - val_Rec: 0.8744 - val_AUC: 0.9496
# Epoch 36/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0735 - ACC: 1.0000 - Prec: 0.9545 - Rec: 0.8791 - AUC: 0.9594 - val_loss: 0.0828 - val_ACC: 1.0000 - val_Prec: 0.9534 - val_Rec: 0.8735 - val_AUC: 0.9493
# Epoch 37/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0735 - ACC: 1.0000 - Prec: 0.9533 - Rec: 0.8804 - AUC: 0.9594 - val_loss: 0.0821 - val_ACC: 1.0000 - val_Prec: 0.9535 - val_Rec: 0.8749 - val_AUC: 0.9498
# Epoch 38/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0734 - ACC: 1.0000 - Prec: 0.9542 - Rec: 0.8794 - AUC: 0.9593 - val_loss: 0.0825 - val_ACC: 1.0000 - val_Prec: 0.9529 - val_Rec: 0.8740 - val_AUC: 0.9496
# Epoch 39/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0734 - ACC: 1.0000 - Prec: 0.9537 - Rec: 0.8804 - AUC: 0.9594 - val_loss: 0.0826 - val_ACC: 1.0000 - val_Prec: 0.9527 - val_Rec: 0.8747 - val_AUC: 0.9495
# Epoch 40/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0734 - ACC: 1.0000 - Prec: 0.9538 - Rec: 0.8794 - AUC: 0.9593 - val_loss: 0.0827 - val_ACC: 1.0000 - val_Prec: 0.9527 - val_Rec: 0.8740 - val_AUC: 0.9497
# Epoch 41/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0734 - ACC: 1.0000 - Prec: 0.9542 - Rec: 0.8794 - AUC: 0.9594 - val_loss: 0.0825 - val_ACC: 1.0000 - val_Prec: 0.9536 - val_Rec: 0.8739 - val_AUC: 0.9497
# Epoch 42/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0734 - ACC: 1.0000 - Prec: 0.9547 - Rec: 0.8801 - AUC: 0.9593 - val_loss: 0.0822 - val_ACC: 1.0000 - val_Prec: 0.9526 - val_Rec: 0.8754 - val_AUC: 0.9498
# Epoch 43/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0734 - ACC: 1.0000 - Prec: 0.9538 - Rec: 0.8798 - AUC: 0.9594 - val_loss: 0.0822 - val_ACC: 1.0000 - val_Prec: 0.9524 - val_Rec: 0.8751 - val_AUC: 0.9497
# Epoch 44/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0734 - ACC: 1.0000 - Prec: 0.9539 - Rec: 0.8804 - AUC: 0.9594 - val_loss: 0.0825 - val_ACC: 1.0000 - val_Prec: 0.9531 - val_Rec: 0.8749 - val_AUC: 0.9496
# Epoch 45/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0734 - ACC: 1.0000 - Prec: 0.9537 - Rec: 0.8804 - AUC: 0.9593 - val_loss: 0.0820 - val_ACC: 1.0000 - val_Prec: 0.9515 - val_Rec: 0.8763 - val_AUC: 0.9499
# Epoch 46/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0734 - ACC: 1.0000 - Prec: 0.9543 - Rec: 0.8810 - AUC: 0.9594 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9531 - val_Rec: 0.8756 - val_AUC: 0.9496
# Epoch 47/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0734 - ACC: 1.0000 - Prec: 0.9558 - Rec: 0.8783 - AUC: 0.9594 - val_loss: 0.0820 - val_ACC: 1.0000 - val_Prec: 0.9511 - val_Rec: 0.8776 - val_AUC: 0.9498
# Epoch 48/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9532 - Rec: 0.8813 - AUC: 0.9594 - val_loss: 0.0824 - val_ACC: 1.0000 - val_Prec: 0.9524 - val_Rec: 0.8751 - val_AUC: 0.9496
# Epoch 49/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0734 - ACC: 1.0000 - Prec: 0.9542 - Rec: 0.8806 - AUC: 0.9593 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9520 - val_Rec: 0.8784 - val_AUC: 0.9497
# Epoch 50/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0735 - ACC: 1.0000 - Prec: 0.9544 - Rec: 0.8789 - AUC: 0.9593 - val_loss: 0.0824 - val_ACC: 1.0000 - val_Prec: 0.9531 - val_Rec: 0.8746 - val_AUC: 0.9497
# Epoch 51/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9535 - Rec: 0.8812 - AUC: 0.9595 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9529 - val_Rec: 0.8753 - val_AUC: 0.9499
# Epoch 52/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9546 - Rec: 0.8809 - AUC: 0.9594 - val_loss: 0.0822 - val_ACC: 1.0000 - val_Prec: 0.9535 - val_Rec: 0.8756 - val_AUC: 0.9499
# Epoch 53/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9546 - Rec: 0.8802 - AUC: 0.9594 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9530 - val_Rec: 0.8763 - val_AUC: 0.9497
# Epoch 54/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9547 - Rec: 0.8803 - AUC: 0.9593 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9531 - val_Rec: 0.8753 - val_AUC: 0.9498
# Epoch 55/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9538 - Rec: 0.8810 - AUC: 0.9594 - val_loss: 0.0820 - val_ACC: 1.0000 - val_Prec: 0.9510 - val_Rec: 0.8770 - val_AUC: 0.9497
# Epoch 56/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9555 - Rec: 0.8787 - AUC: 0.9594 - val_loss: 0.0819 - val_ACC: 1.0000 - val_Prec: 0.9515 - val_Rec: 0.8783 - val_AUC: 0.9497
# Epoch 57/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9535 - Rec: 0.8811 - AUC: 0.9595 - val_loss: 0.0824 - val_ACC: 1.0000 - val_Prec: 0.9531 - val_Rec: 0.8746 - val_AUC: 0.9498
# Epoch 58/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9549 - Rec: 0.8797 - AUC: 0.9594 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9538 - val_Rec: 0.8749 - val_AUC: 0.9497
# Epoch 59/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9542 - Rec: 0.8814 - AUC: 0.9594 - val_loss: 0.0819 - val_ACC: 1.0000 - val_Prec: 0.9518 - val_Rec: 0.8777 - val_AUC: 0.9499
# Epoch 60/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9545 - Rec: 0.8804 - AUC: 0.9595 - val_loss: 0.0820 - val_ACC: 1.0000 - val_Prec: 0.9512 - val_Rec: 0.8767 - val_AUC: 0.9498
# Epoch 61/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9546 - Rec: 0.8812 - AUC: 0.9595 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9535 - val_Rec: 0.8749 - val_AUC: 0.9498
# Epoch 62/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9544 - Rec: 0.8806 - AUC: 0.9595 - val_loss: 0.0821 - val_ACC: 1.0000 - val_Prec: 0.9528 - val_Rec: 0.8754 - val_AUC: 0.9500
# Epoch 63/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9552 - Rec: 0.8794 - AUC: 0.9594 - val_loss: 0.0820 - val_ACC: 1.0000 - val_Prec: 0.9519 - val_Rec: 0.8765 - val_AUC: 0.9498
# Epoch 64/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9547 - Rec: 0.8809 - AUC: 0.9596 - val_loss: 0.0820 - val_ACC: 1.0000 - val_Prec: 0.9521 - val_Rec: 0.8770 - val_AUC: 0.9499
# Epoch 65/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9543 - Rec: 0.8819 - AUC: 0.9596 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9540 - val_Rec: 0.8749 - val_AUC: 0.9498
# Epoch 66/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9543 - Rec: 0.8810 - AUC: 0.9594 - val_loss: 0.0823 - val_ACC: 1.0000 - val_Prec: 0.9539 - val_Rec: 0.8760 - val_AUC: 0.9497
# Epoch 67/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9550 - Rec: 0.8801 - AUC: 0.9595 - val_loss: 0.0821 - val_ACC: 1.0000 - val_Prec: 0.9539 - val_Rec: 0.8758 - val_AUC: 0.9499
# Epoch 68/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9548 - Rec: 0.8803 - AUC: 0.9595 - val_loss: 0.0819 - val_ACC: 1.0000 - val_Prec: 0.9518 - val_Rec: 0.8770 - val_AUC: 0.9499
# Epoch 69/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9540 - Rec: 0.8805 - AUC: 0.9595 - val_loss: 0.0822 - val_ACC: 1.0000 - val_Prec: 0.9536 - val_Rec: 0.8747 - val_AUC: 0.9500
# Epoch 70/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9537 - Rec: 0.8814 - AUC: 0.9596 - val_loss: 0.0817 - val_ACC: 1.0000 - val_Prec: 0.9509 - val_Rec: 0.8784 - val_AUC: 0.9500
# Epoch 71/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9546 - Rec: 0.8810 - AUC: 0.9596 - val_loss: 0.0817 - val_ACC: 1.0000 - val_Prec: 0.9511 - val_Rec: 0.8777 - val_AUC: 0.9501
# Epoch 72/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9552 - Rec: 0.8796 - AUC: 0.9595 - val_loss: 0.0819 - val_ACC: 1.0000 - val_Prec: 0.9521 - val_Rec: 0.8760 - val_AUC: 0.9499
# Epoch 73/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9541 - Rec: 0.8819 - AUC: 0.9596 - val_loss: 0.0819 - val_ACC: 1.0000 - val_Prec: 0.9532 - val_Rec: 0.8760 - val_AUC: 0.9502
# Epoch 74/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9548 - Rec: 0.8810 - AUC: 0.9596 - val_loss: 0.0819 - val_ACC: 1.0000 - val_Prec: 0.9530 - val_Rec: 0.8761 - val_AUC: 0.9500
# Epoch 75/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9547 - Rec: 0.8803 - AUC: 0.9596 - val_loss: 0.0820 - val_ACC: 1.0000 - val_Prec: 0.9523 - val_Rec: 0.8776 - val_AUC: 0.9497
# Epoch 76/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9537 - Rec: 0.8814 - AUC: 0.9597 - val_loss: 0.0821 - val_ACC: 1.0000 - val_Prec: 0.9535 - val_Rec: 0.8754 - val_AUC: 0.9499
# Epoch 77/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9546 - Rec: 0.8796 - AUC: 0.9595 - val_loss: 0.0821 - val_ACC: 1.0000 - val_Prec: 0.9534 - val_Rec: 0.8763 - val_AUC: 0.9500
# Epoch 78/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9543 - Rec: 0.8811 - AUC: 0.9596 - val_loss: 0.0817 - val_ACC: 1.0000 - val_Prec: 0.9525 - val_Rec: 0.8767 - val_AUC: 0.9502
# Epoch 79/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9547 - Rec: 0.8797 - AUC: 0.9596 - val_loss: 0.0819 - val_ACC: 1.0000 - val_Prec: 0.9522 - val_Rec: 0.8786 - val_AUC: 0.9499
# Epoch 80/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0730 - ACC: 1.0000 - Prec: 0.9548 - Rec: 0.8814 - AUC: 0.9596 - val_loss: 0.0818 - val_ACC: 1.0000 - val_Prec: 0.9524 - val_Rec: 0.8781 - val_AUC: 0.9499
# Epoch 81/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9538 - Rec: 0.8815 - AUC: 0.9597 - val_loss: 0.0817 - val_ACC: 1.0000 - val_Prec: 0.9520 - val_Rec: 0.8777 - val_AUC: 0.9501
# Epoch 82/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9549 - Rec: 0.8809 - AUC: 0.9596 - val_loss: 0.0817 - val_ACC: 1.0000 - val_Prec: 0.9513 - val_Rec: 0.8786 - val_AUC: 0.9499
# Epoch 83/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9546 - Rec: 0.8801 - AUC: 0.9596 - val_loss: 0.0815 - val_ACC: 1.0000 - val_Prec: 0.9494 - val_Rec: 0.8813 - val_AUC: 0.9501
# Epoch 84/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0732 - ACC: 1.0000 - Prec: 0.9534 - Rec: 0.8822 - AUC: 0.9595 - val_loss: 0.0821 - val_ACC: 1.0000 - val_Prec: 0.9524 - val_Rec: 0.8753 - val_AUC: 0.9500
# Epoch 85/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9554 - Rec: 0.8791 - AUC: 0.9596 - val_loss: 0.0816 - val_ACC: 1.0000 - val_Prec: 0.9515 - val_Rec: 0.8799 - val_AUC: 0.9502
# Epoch 86/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9548 - Rec: 0.8805 - AUC: 0.9596 - val_loss: 0.0818 - val_ACC: 1.0000 - val_Prec: 0.9530 - val_Rec: 0.8767 - val_AUC: 0.9500
# Epoch 87/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9548 - Rec: 0.8807 - AUC: 0.9596 - val_loss: 0.0820 - val_ACC: 1.0000 - val_Prec: 0.9536 - val_Rec: 0.8769 - val_AUC: 0.9499
# Epoch 88/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9533 - Rec: 0.8816 - AUC: 0.9597 - val_loss: 0.0821 - val_ACC: 1.0000 - val_Prec: 0.9537 - val_Rec: 0.8758 - val_AUC: 0.9499
# Epoch 89/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0730 - ACC: 1.0000 - Prec: 0.9547 - Rec: 0.8806 - AUC: 0.9596 - val_loss: 0.0815 - val_ACC: 1.0000 - val_Prec: 0.9508 - val_Rec: 0.8790 - val_AUC: 0.9502
# Epoch 90/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0730 - ACC: 1.0000 - Prec: 0.9546 - Rec: 0.8799 - AUC: 0.9596 - val_loss: 0.0819 - val_ACC: 1.0000 - val_Prec: 0.9526 - val_Rec: 0.8765 - val_AUC: 0.9499
# Epoch 91/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0730 - ACC: 1.0000 - Prec: 0.9550 - Rec: 0.8808 - AUC: 0.9596 - val_loss: 0.0814 - val_ACC: 1.0000 - val_Prec: 0.9496 - val_Rec: 0.8811 - val_AUC: 0.9502
# Epoch 92/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0729 - ACC: 1.0000 - Prec: 0.9537 - Rec: 0.8830 - AUC: 0.9598 - val_loss: 0.0818 - val_ACC: 1.0000 - val_Prec: 0.9534 - val_Rec: 0.8772 - val_AUC: 0.9501
# Epoch 93/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0730 - ACC: 1.0000 - Prec: 0.9550 - Rec: 0.8797 - AUC: 0.9598 - val_loss: 0.0814 - val_ACC: 1.0000 - val_Prec: 0.9503 - val_Rec: 0.8797 - val_AUC: 0.9501
# Epoch 94/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0730 - ACC: 1.0000 - Prec: 0.9544 - Rec: 0.8809 - AUC: 0.9597 - val_loss: 0.0819 - val_ACC: 1.0000 - val_Prec: 0.9530 - val_Rec: 0.8760 - val_AUC: 0.9501
# Epoch 95/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0730 - ACC: 1.0000 - Prec: 0.9545 - Rec: 0.8826 - AUC: 0.9597 - val_loss: 0.0817 - val_ACC: 1.0000 - val_Prec: 0.9526 - val_Rec: 0.8786 - val_AUC: 0.9502
# Epoch 96/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0729 - ACC: 1.0000 - Prec: 0.9555 - Rec: 0.8798 - AUC: 0.9598 - val_loss: 0.0813 - val_ACC: 1.0000 - val_Prec: 0.9503 - val_Rec: 0.8806 - val_AUC: 0.9501
# Epoch 97/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0729 - ACC: 1.0000 - Prec: 0.9539 - Rec: 0.8818 - AUC: 0.9597 - val_loss: 0.0816 - val_ACC: 1.0000 - val_Prec: 0.9513 - val_Rec: 0.8795 - val_AUC: 0.9500
# Epoch 98/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0730 - ACC: 1.0000 - Prec: 0.9548 - Rec: 0.8805 - AUC: 0.9597 - val_loss: 0.0814 - val_ACC: 1.0000 - val_Prec: 0.9508 - val_Rec: 0.8791 - val_AUC: 0.9502
# Epoch 99/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0729 - ACC: 1.0000 - Prec: 0.9550 - Rec: 0.8814 - AUC: 0.9598 - val_loss: 0.0816 - val_ACC: 1.0000 - val_Prec: 0.9509 - val_Rec: 0.8781 - val_AUC: 0.9500
# Epoch 100/100
# 57/57 [==============================] - 0s 1ms/step - loss: 0.0730 - ACC: 1.0000 - Prec: 0.9545 - Rec: 0.8808 - AUC: 0.9598 - val_loss: 0.0813 - val_ACC: 1.0000 - val_Prec: 0.9511 - val_Rec: 0.8811 - val_AUC: 0.9502
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 4)                 368
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 373
# Trainable params: 373
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## <font color=#cd0000> Clasificación </font>

# %%
y_pred = y_pred.astype('int')
y_pred = enc.inverse_transform(y_pred)
y_real = enc.inverse_transform(y_test)
print(confusion_matrix(y_real, y_pred))
print(classification_report(y_real, y_pred, zero_division=0))
# Out:
# [[3042  257]
#  [ 674 4994]]
#               precision    recall  f1-score   support
#
#      Control       0.82      0.92      0.87      3299
#      Estudio       0.95      0.88      0.91      5668
#
#     accuracy                           0.90      8967
#    macro avg       0.88      0.90      0.89      8967
# weighted avg       0.90      0.90      0.90      8967
# c:\Users\Javier\anaconda3\envs\tfg_env\lib\site-packages\sklearn\preprocessing\_label.py:154: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ## <font color=#cd0000> Discusión de los resultados </font>
# - Dimensionalidad de entrada inicial -> 18
# > **IMPORTANTE**
# > - Hemos decidido cambiar el optimizador a Adam ya que es un problema con muy pocas clases y, este optimizador, utiliza una tasa de aprendizaje adaptativo que suele ir bien para este tipo de problemas.
# > - También hemos decidido cambiar la función de error a un MSE que ha brindado mejores resultados.
# - Vamos a estudiar diferentes rangos de hiper-parámetros que podrían darnos alguna pista sobre el rango en el que buscar el mejor clasificador de este tipo:
#   - Para una red de, inicialmente, 1 capa oculta puesto que las series del problema no son muy complejas y, además, podríamos correr el riesgo de sobreajustar la red al tener tan pocos ejemplos:
#    - Para un `n_units_capa1` de la mitad de la dim_entrada (9) y un `learning_rate` rápido (1e-2) obtenemos :
#    ```
#    Confusion matrix:
#    [[2861  438]
#     [ 710 4958]]
#
#    Classification report:
#                   precision    recall  f1-score   support
#
#        Control       0.80      0.87      0.83      3299
#        Estudio       0.92      0.87      0.90      5668
#
#       accuracy                           0.87      8967
#      macro avg       0.86      0.87      0.86      8967
#   weighted avg       0.88      0.87      0.87      8967
#    ```
#    - Para un `n_units_capa1` de la mitad de la mitad de la dim_entrada (4) y un `learning_rate` rápido (1e-2) obtenemos una mejora notable y disminuimos aún más el sobreajuste:
#    ```
#    Confusion matrix:
#    [[3063  236]
#     [ 755 4913]]
#
#    Classification report:
#                   precision    recall  f1-score   support
#
#        Control       0.80      0.93      0.86      3299
#        Estudio       0.95      0.87      0.91      5668
#
#       accuracy                           0.89      8967
#      macro avg       0.88      0.90      0.88      8967
#   weighted avg       0.90      0.89      0.89      8967
#    ```
#    - Para un `n_units_capa1`  de la mitad de la mitad de la dim_entrada (4) y un `learning_rate` lento (1e-4) obtenemos resultados ligeramente mejores:
#    ```
#    Confusion matrix:
#    [[3051  248]
#     [ 713 4955]]
#
#    Classification report:
#                   precision    recall  f1-score   support
#
#         Control       0.81      0.92      0.86      3299
#         Estudio       0.95      0.87      0.91      5668
#
#        accuracy                           0.89      8967
#       macro avg       0.88      0.90      0.89      8967
#    weighted avg       0.90      0.89      0.89      8967
#    ```
#    - Para un `n_units_capa1`  de la mitad de la mitad de la dim_entrada (4) y un `learning_rate` intermedio (1e-3) obtenemos los mismos resultados:
#    ```
#    Confusion matrix:
#    [[3042  257]
#     [ 674 4994]]
#
#    Classification report:
#                   precision    recall  f1-score   support
#
#         Control       0.82      0.92      0.87      3299
#         Estudio       0.95      0.88      0.91      5668
#
#        accuracy                           0.90      8967
#       macro avg       0.88      0.90      0.89      8967
#    weighted avg       0.90      0.90      0.90      8967
#    ```

# %% [markdown]
# ## <font color=#cd0000> Conclusiones </font>
# - Como podemos observar cuanta menor complejidad en la red mejor clasifica
# - Rango orientativo:
#   - `n_units`: [4, 9]
#   - `learning_rate`: [1e-2, 8e-3, 7e-3, 5e-3, 1e-3]
#   - Sin tasa de Dropout

# %% [markdown]
# # <font color=#cd0000> Randomized Search </font>
# - Búsqueda de hiper-parámetros aleatoria con LSTM maximizando ``macro avg f1-score``

# %% [markdown]
# ## <font color=#cd0000> Rangos de búsqueda </font>
# - Como vimos anteriormente los rangos de búsqueda aleatoria de los mejores hiper-parámetros serán los siguientes

# %%
N_UNITS_RANGE = range(4, 9)
LEARNING_RATE_CHOICES = [1e-2, 8e-3, 7e-3, 5e-3, 1e-3]

# %% [markdown]
# # <font color=#cd0000> Randomized Search con múltiples ejecuciones en lugar de Validación Cruzada </font>
# - Ejecutaremos el mismo modelo sobre diferentes particiones del conjunto de datos original para observar su desempeño.

# %%
import random
import pickle
import utils.constants as cs
from utils.classifier_utils import (train_validate,
                                    tfm_marta_train_test_split,
                                    compute_classification_reports_means)
from utils.plot_utils import pretty_print_classification_report_dict
from keras.layers import LSTM, Dense
from keras.optimizers import RMSprop

def lstm_randomized_search_train_validate(
        windowed_series,
        relation_with_series,
        prefix,
        repetitions=5,
        standardize_columns=[],
        lstm_dict={}):
    global PKL_DIR
    all_clf_used = {}

    n_samples = 5
    units_list = random.sample(
        list(N_UNITS_RANGE), n_samples)
    learning_rate_list = random.sample(
        LEARNING_RATE_CHOICES, n_samples)

    best_hyp_params = None
    best_score = 0
    for units in units_list:
        for learning_rate in learning_rate_list:
            lstm_dict[cs.LSTM_HYP_PARAM_UNITS] = units
            lstm_dict[cs.LSTM_HYP_PARAM_LEARNING_RATE] = learning_rate
            reports = train_validate(
                None,
                windowed_series,
                estimator_type=cs.ESTIMATOR_LSTM,
                relation_with_series=relation_with_series,
                train_test_split_method=tfm_marta_train_test_split,
                times_to_repeat=repetitions,
                train_size=0.8,
                drop_columns=['TimeStamp', 'class'],
                seed=SEED,
                standardize_columns=standardize_columns,
                lstm_dict=lstm_dict
            )
            reports = list(map(lambda x: x['report'], reports))
            mean_report = compute_classification_reports_means(reports)
            all_clf_used[(units, learning_rate)] = mean_report

            if mean_report['macro avg']['f1-score'][0] >= best_score:
                best_score = mean_report['macro avg']['f1-score'][0]
                best_hyp_params = (units, learning_rate)
                best_report = mean_report

            print("\t\t--------------ACTUAL BEST: Units={}; Learning Rate={}--------------"
                  .format(best_hyp_params[0], best_hyp_params[1]))
            pretty_print_classification_report_dict(best_report)
            print("\t\t--------------ITERATION: Units={}; Learning Rate={}--------------"
                  .format(units, learning_rate))
            pretty_print_classification_report_dict(mean_report)

    with open(PKL_DIR + prefix, 'wb') as file:
        pickle.dump(all_clf_used, file)

    return best_hyp_params, best_report

# %%
# IMPORTANTE -> ALGUNOS DE LOS PARÁMETROS DEL MODELO SON FIJADOS EN EL MÉTODO 
# lstm_build_model y lstm_compile_model del módulo classifier_utils.py ante 
# problemas a la hora de clonar modelos neuronales de Keras.

# Los parámetros fijados a fuego en el código son:
#   · El optimizador será "Adam"
#   · La función de pérdida será "mse"
#   · El batch_size en entrenamiento será del tamaño de la ventana más larga

lstm_dict = {
    cs.LSTM_ARGMAX_FUNCTION: None,
    cs.LSTM_N_CLASSES: 2,
    cs.LSTM_CLASS_WEIGHTS: class_weights,
    cs.LSTM_HYP_PARAM_EPOCHS: 100,
    cs.LSTM_FITTED_LABELS_ENCODER: enc,
    
    cs.LSTM_RESHAPE_TO_ONE_TIMESTEP: True,
    cs.LSTM_SERIES_LENGTH: max_sequence_length
}

lstm_randomized_search_train_validate(
    all_data.derived_data,
    all_data.derived_data_windows_per_serie,
    PKL_NAME,
    repetitions=5,
    standardize_columns=all_data.get_derived_data_columns()['attrs'],
    lstm_dict=lstm_dict
)
# Out:
# 		--------------ACTUAL BEST: Units=4; Learning Rate=0.001--------------
# Accuracy: 0.801182112189138 +/- 0.015349206246529521
# Control:
# 	precision: 0.6870953488051983 +/- 0.022498835897537556
# 	recall: 0.8466808123673841 +/- 0.021620409724823177
# 	f1-score: 0.7582196466402167 +/- 0.01548991991994844
# 	support: 3299.0 +/- 0.0
# Estudio:
# 	precision: 0.8969443718457704 +/- 0.012133025200316576
# 	recall: 0.7747000705716303 +/- 0.0260109356707733
# 	f1-score: 0.8310438651196647 +/- 0.015328519420141854
# 	support: 5668.0 +/- 0.0
# macro avg:
# 	precision: 0.7920198603254842 +/- 0.013203617723265539
# 	recall: 0.8106904414695071 +/- 0.013440933050728866
# 	f1-score: 0.7946317558799405 +/- 0.014944748266394968
# 	support: 8967.0 +/- 0.0
# weighted avg:
# 	precision: 0.8197399637928152 +/- 0.011728161061550127
# 	recall: 0.801182112189138 +/- 0.015349206246529521
# 	f1-score: 0.8042515046017993 +/- 0.014955698981965616
# 	support: 8967.0 +/- 0.0
# 		--------------ITERATION: Units=4; Learning Rate=0.001--------------
# Accuracy: 0.801182112189138 +/- 0.015349206246529521
# Control:
# 	precision: 0.6870953488051983 +/- 0.022498835897537556
# 	recall: 0.8466808123673841 +/- 0.021620409724823177
# 	f1-score: 0.7582196466402167 +/- 0.01548991991994844
# 	support: 3299.0 +/- 0.0
# Estudio:
# 	precision: 0.8969443718457704 +/- 0.012133025200316576
# 	recall: 0.7747000705716303 +/- 0.0260109356707733
# 	f1-score: 0.8310438651196647 +/- 0.015328519420141854
# 	support: 5668.0 +/- 0.0
# macro avg:
# 	precision: 0.7920198603254842 +/- 0.013203617723265539
# 	recall: 0.8106904414695071 +/- 0.013440933050728866
# 	f1-score: 0.7946317558799405 +/- 0.014944748266394968
# 	support: 8967.0 +/- 0.0
# weighted avg:
# 	precision: 0.8197399637928152 +/- 0.011728161061550127
# 	recall: 0.801182112189138 +/- 0.015349206246529521
# 	f1-score: 0.8042515046017993 +/- 0.014955698981965616
# 	support: 8967.0 +/- 0.0
# 		--------------ACTUAL BEST: Units=4; Learning Rate=0.005--------------
# Accuracy: 0.8310025649604104 +/- 0.014465242556628205
# Control:
# 	precision: 0.7395612937604843 +/- 0.009927402509603722
# 	recall: 0.8345559260381934 +/- 0.05115329895936699
# 	f1-score: 0.7834802421534027 +/- 0.024591640685547367
# 	support: 3299.0 +/- 0.0
# Estudio:
# 	precision: 0.8970554860238682 +/- 0.02761152267661381
# 	recall: 0.8289343683839097 +/- 0.012265869063590451
# 	f1-score: 0.8612676517505374 +/- 0.009716985353125923
# 	support: 5668.0 +/- 0.0
# macro avg:
# 	precision: 0.8183083898921761 +/- 0.015783593785594293
# 	recall: 0.8317451472110514 +/- 0.021710574246395067
# 	f1-score: 0.82237394695197 +/- 0.01694098809541108
# 	support: 8967.0 +/- 0.0
# weighted avg:
# 	precision: 0.
# 	recall: 0.8322738931638229 +/- 0.024274913512832143
# 	f1-score: 0.8327481543110256 +/- 0.024905112196560122
# 	support: 8967.0 +/- 0.0
# ((6, 0.007),
#  {'accuracy': (0.8509423441507751, 0.022418308639783287),
#   'Control': {'precision': (0.7895150033054446, 0.023778503534704377),
#    'recall': (0.811821764170961, 0.06323433369844933),
#    'f1-score': (0.7992900861004636, 0.03513649421366092),
#    'support': (3299.0, 0.0)},
#   'Estudio': {'precision': (0.8900214482924766, 0.032808752187692886),
#    'recall': (0.8737120677487651, 0.020046691110438858),
#    'f1-score': (0.8812681086041326, 0.016548745033337538),
#    'support': (5668.0, 0.0)},
#   'macro avg': {'precision': (0.8397682257989606, 0.02244253441272679),
#    'recall': (0.842766915959863, 0.029765047748190936),
#    'f1-score': (0.8402790973522981, 0.02550385852877711),
#    'support': (8967.0, 0.0)},
#   'weighted avg': {'precision': (0.8530446709965898, 0.024357969311411688),
#    'recall': (0.8509423441507751, 0.022418308639783287),
#    'f1-score': (0.8511080220378782, 0.02303874799900318),
#    'support': (8967.0, 0.0)}})

# %% [markdown]
# # <font color=#cd0000> Análisis de resultados </font>
# - Según la búsqueda aleatoria de hiper-parámetros, la mejor combinación, es la de ``n_units`` = 6 y ``learning_rate`` = 0.007:
#     ```
#         Accuracy: 0.8509423441507751 +/- 0.022418308639783287
#         Control:
#             precision: 0.7895150033054446 +/- 0.023778503534704377
#             recall: 0.811821764170961 +/- 0.06323433369844933
#             f1-score: 0.7992900861004636 +/- 0.03513649421366092
#             support: 3299.0 +/- 0.0
#         Estudio:
#             precision: 0.8900214482924766 +/- 0.032808752187692886
#             recall: 0.8737120677487651 +/- 0.020046691110438858
#             f1-score: 0.8812681086041326 +/- 0.016548745033337538
#             support: 5668.0 +/- 0.0
#         macro avg:
#             precision: 0.8397682257989606 +/- 0.02244253441272679
#             recall: 0.842766915959863 +/- 0.029765047748190936
#             f1-score: 0.8402790973522981 +/- 0.02550385852877711
#             support: 8967.0 +/- 0.0
#         weighted avg:
#             precision: 0.8530446709965898 +/- 0.024357969311411688
#             recall: 0.8509423441507751 +/- 0.022418308639783287
#             f1-score: 0.8511080220378782 +/- 0.02303874799900318
#             support: 8967.0 +/- 0.0
#     ```
# - Ahora vamos a visualizar la evolución de los resultados (25 resultados) para observar cómo avanza nuestra métrica objetivo -> Macro Average F1-Score.

# %%
import pickle

all_reports = pickle.load(open(PKL_DIR + PKL_NAME, 'rb'))

# %%
from utils.plot_utils import plot_score

macro_avg_f1_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['macro avg']['f1-score'][0],
                   'std': all_reports[z]['macro avg']['f1-score'][1]}),
    all_reports
))

plot_score(
    [macro_avg_f1_scores],
    ('n_units', 'learning_rate'),
    'LSTM',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Macro Average F1-Score'
)

# %%
estudio_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['Estudio']['recall'][0],
                   'std': all_reports[z]['Estudio']['recall'][1]}),
    all_reports
))

control_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['Control']['recall'][0],
                   'std': all_reports[z]['Control']['recall'][1]}),
    all_reports
))

plot_score(
    [estudio_recall_scores],
    ('n_units', 'learning_rate'),
    'LSTM',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Estudio recall score'
)

plot_score(
    [control_recall_scores],
    ('n_units', 'learning_rate'),
    'LSTM',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Control recall score'
)

# %% [markdown]
# ## <font color=#cd0000> Evaluación sobre el conjunto de validación </font>
# - Vamos a llevar a cabo la evaluación final sobre el conjunto de validación (esto es lo que irá al apartado de ``Pruebas y Resultados`` de la memoria).

# %% [markdown]
# ### <font color=#cd0000> Construcción del modelo </font>

# %%
import keras as k
from keras.models import Sequential
from keras.layers import LSTM, Dense

nn = Sequential()

# Number of initial dimensions
nn.add(LSTM(units=6))
# Number of SegOcular's classes
nn.add(Dense(1, activation='sigmoid'))

# %%
from keras.optimizers import Adam

metrics = [
    k.metrics.CategoricalAccuracy(name="ACC"),
    k.metrics.Precision(name='Prec'),
    k.metrics.Recall(name='Rec'),
    k.metrics.AUC(name='AUC')
]

nn.compile(optimizer=Adam(
    learning_rate=0.007), loss='mse', metrics=metrics)

# %% [markdown]
# ### <font color=#cd0000> Entrenamiento </font>

# %%
import numpy as np
from keras import backend as K
from sklearn.metrics import confusion_matrix, classification_report

epochs = 100

history = nn.fit(X_train, y_train, epochs=epochs,
                 validation_data=(X_test, y_test),
                 batch_size=max_sequence_length,
                 class_weight=class_weights,
                 verbose=1)
nn.summary()
print('\n\n')

y_pred = nn.predict(X_test)
y_pred = y_pred > .5

show_metrics(history)
# Out:
# Epoch 1/100
# 57/57 [==============================] - 1s 16ms/step - loss: 0.2369 - ACC: 1.0000 - Prec: 0.7237 - Rec: 0.6037 - AUC: 0.6428 - val_loss: 0.2310 - val_ACC: 1.0000 - val_Prec: 0.7187 - val_Rec: 0.6380 - val_AUC: 0.6550
# Epoch 2/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.2111 - ACC: 1.0000 - Prec: 0.7819 - Rec: 0.7190 - AUC: 0.7325 - val_loss: 0.2223 - val_ACC: 1.0000 - val_Prec: 0.7390 - val_Rec: 0.6965 - val_AUC: 0.6773
# Epoch 3/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1970 - ACC: 1.0000 - Prec: 0.8017 - Rec: 0.7524 - AUC: 0.7688 - val_loss: 0.2211 - val_ACC: 1.0000 - val_Prec: 0.7616 - val_Rec: 0.6611 - val_AUC: 0.7097
# Epoch 4/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1851 - ACC: 1.0000 - Prec: 0.8142 - Rec: 0.7605 - AUC: 0.7980 - val_loss: 0.2045 - val_ACC: 1.0000 - val_Prec: 0.7925 - val_Rec: 0.7195 - val_AUC: 0.7486
# Epoch 5/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1743 - ACC: 1.0000 - Prec: 0.8318 - Rec: 0.7636 - AUC: 0.8218 - val_loss: 0.1938 - val_ACC: 1.0000 - val_Prec: 0.8257 - val_Rec: 0.7239 - val_AUC: 0.7824
# Epoch 6/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1621 - ACC: 1.0000 - Prec: 0.8562 - Rec: 0.7739 - AUC: 0.8451 - val_loss: 0.1768 - val_ACC: 1.0000 - val_Prec: 0.8622 - val_Rec: 0.7244 - val_AUC: 0.8214
# Epoch 7/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1487 - ACC: 1.0000 - Prec: 0.8894 - Rec: 0.7716 - AUC: 0.8664 - val_loss: 0.1594 - val_ACC: 1.0000 - val_Prec: 0.8816 - val_Rec: 0.7544 - val_AUC: 0.8474
# Epoch 8/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1387 - ACC: 1.0000 - Prec: 0.9092 - Rec: 0.7751 - AUC: 0.8794 - val_loss: 0.1526 - val_ACC: 1.0000 - val_Prec: 0.8933 - val_Rec: 0.7592 - val_AUC: 0.8566
# Epoch 9/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1315 - ACC: 1.0000 - Prec: 0.9219 - Rec: 0.7765 - AUC: 0.8890 - val_loss: 0.1456 - val_ACC: 1.0000 - val_Prec: 0.9007 - val_Rec: 0.7682 - val_AUC: 0.8670
# Epoch 10/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1255 - ACC: 1.0000 - Prec: 0.9286 - Rec: 0.7815 - AUC: 0.8969 - val_loss: 0.1396 - val_ACC: 1.0000 - val_Prec: 0.9090 - val_Rec: 0.7698 - val_AUC: 0.8761
# Epoch 11/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1209 - ACC: 1.0000 - Prec: 0.9326 - Rec: 0.7864 - AUC: 0.9033 - val_loss: 0.1356 - val_ACC: 1.0000 - val_Prec: 0.9170 - val_Rec: 0.7738 - val_AUC: 0.8827
# Epoch 12/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1172 - ACC: 1.0000 - Prec: 0.9366 - Rec: 0.7910 - AUC: 0.9091 - val_loss: 0.1325 - val_ACC: 1.0000 - val_Prec: 0.9180 - val_Rec: 0.7819 - val_AUC: 0.8864
# Epoch 13/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1140 - ACC: 1.0000 - Prec: 0.9398 - Rec: 0.7926 - AUC: 0.9126 - val_loss: 0.1298 - val_ACC: 1.0000 - val_Prec: 0.9116 - val_Rec: 0.7936 - val_AUC: 0.8890
# Epoch 14/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1115 - ACC: 1.0000 - Prec: 0.9400 - Rec: 0.7964 - AUC: 0.9169 - val_loss: 0.1264 - val_ACC: 1.0000 - val_Prec: 0.9243 - val_Rec: 0.7885 - val_AUC: 0.8960
# Epoch 15/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1093 - ACC: 1.0000 - Prec: 0.9426 - Rec: 0.7982 - AUC: 0.9201 - val_loss: 0.1256 - val_ACC: 1.0000 - val_Prec: 0.9196 - val_Rec: 0.7913 - val_AUC: 0.8966
# Epoch 16/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1073 - ACC: 1.0000 - Prec: 0.9427 - Rec: 0.8008 - AUC: 0.9229 - val_loss: 0.1248 - val_ACC: 1.0000 - val_Prec: 0.9209 - val_Rec: 0.7908 - val_AUC: 0.8991
# Epoch 17/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1054 - ACC: 1.0000 - Prec: 0.9443 - Rec: 0.8042 - AUC: 0.9254 - val_loss: 0.1215 - val_ACC: 1.0000 - val_Prec: 0.9201 - val_Rec: 0.8010 - val_AUC: 0.9032
# Epoch 18/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1038 - ACC: 1.0000 - Prec: 0.9455 - Rec: 0.8073 - AUC: 0.9278 - val_loss: 0.1199 - val_ACC: 1.0000 - val_Prec: 0.9231 - val_Rec: 0.8001 - val_AUC: 0.9061
# Epoch 19/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1023 - ACC: 1.0000 - Prec: 0.9469 - Rec: 0.8071 - AUC: 0.9299 - val_loss: 0.1180 - val_ACC: 1.0000 - val_Prec: 0.9180 - val_Rec: 0.8061 - val_AUC: 0.9083
# Epoch 20/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.1011 - ACC: 1.0000 - Prec: 0.9461 - Rec: 0.8125 - AUC: 0.9316 - val_loss: 0.1191 - val_ACC: 1.0000 - val_Prec: 0.9220 - val_Rec: 0.7983 - val_AUC: 0.9087
# Epoch 21/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0993 - ACC: 1.0000 - Prec: 0.9485 - Rec: 0.8133 - AUC: 0.9341 - val_loss: 0.1196 - val_ACC: 1.0000 - val_Prec: 0.9233 - val_Rec: 0.7962 - val_AUC: 0.9089
# Epoch 22/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0982 - ACC: 1.0000 - Prec: 0.9471 - Rec: 0.8149 - AUC: 0.9358 - val_loss: 0.1158 - val_ACC: 1.0000 - val_Prec: 0.9213 - val_Rec: 0.8072 - val_AUC: 0.9130
# Epoch 23/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0971 - ACC: 1.0000 - Prec: 0.9488 - Rec: 0.8159 - AUC: 0.9370 - val_loss: 0.1175 - val_ACC: 1.0000 - val_Prec: 0.9235 - val_Rec: 0.8024 - val_AUC: 0.9110
# Epoch 24/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0959 - ACC: 1.0000 - Prec: 0.9495 - Rec: 0.8179 - AUC: 0.9386 - val_loss: 0.1161 - val_ACC: 1.0000 - val_Prec: 0.9244 - val_Rec: 0.7999 - val_AUC: 0.9143
# Epoch 25/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0949 - ACC: 1.0000 - Prec: 0.9485 - Rec: 0.8229 - AUC: 0.9399 - val_loss: 0.1147 - val_ACC: 1.0000 - val_Prec: 0.9232 - val_Rec: 0.8020 - val_AUC: 0.9166
# Epoch 26/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0938 - ACC: 1.0000 - Prec: 0.9498 - Rec: 0.8227 - AUC: 0.9412 - val_loss: 0.1145 - val_ACC: 1.0000 - val_Prec: 0.9248 - val_Rec: 0.8026 - val_AUC: 0.9160
# Epoch 27/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0928 - ACC: 1.0000 - Prec: 0.9504 - Rec: 0.8247 - AUC: 0.9427 - val_loss: 0.1130 - val_ACC: 1.0000 - val_Prec: 0.9232 - val_Rec: 0.8100 - val_AUC: 0.9178
# Epoch 28/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0917 - ACC: 1.0000 - Prec: 0.9511 - Rec: 0.8276 - AUC: 0.9441 - val_loss: 0.1109 - val_ACC: 1.0000 - val_Prec: 0.9225 - val_Rec: 0.8130 - val_AUC: 0.9202
# Epoch 29/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0912 - ACC: 1.0000 - Prec: 0.9503 - Rec: 0.8268 - AUC: 0.9442 - val_loss: 0.1097 - val_ACC: 1.0000 - val_Prec: 0.9242 - val_Rec: 0.8149 - val_AUC: 0.9226
# Epoch 30/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0901 - ACC: 1.0000 - Prec: 0.9507 - Rec: 0.8306 - AUC: 0.9455 - val_loss: 0.1101 - val_ACC: 1.0000 - val_Prec: 0.9162 - val_Rec: 0.8239 - val_AUC: 0.9200
# Epoch 31/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0895 - ACC: 1.0000 - Prec: 0.9511 - Rec: 0.8319 - AUC: 0.9462 - val_loss: 0.1081 - val_ACC: 1.0000 - val_Prec: 0.9224 - val_Rec: 0.8199 - val_AUC: 0.9249
# Epoch 32/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0886 - ACC: 1.0000 - Prec: 0.9526 - Rec: 0.8313 - AUC: 0.9471 - val_loss: 0.1065 - val_ACC: 1.0000 - val_Prec: 0.9167 - val_Rec: 0.8324 - val_AUC: 0.9248
# Epoch 33/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0876 - ACC: 1.0000 - Prec: 0.9523 - Rec: 0.8378 - AUC: 0.9484 - val_loss: 0.1060 - val_ACC: 1.0000 - val_Prec: 0.9257 - val_Rec: 0.8225 - val_AUC: 0.9271
# Epoch 34/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0869 - ACC: 1.0000 - Prec: 0.9531 - Rec: 0.8372 - AUC: 0.9491 - val_loss: 0.1069 - val_ACC: 1.0000 - val_Prec: 0.9269 - val_Rec: 0.8232 - val_AUC: 0.9261
# Epoch 35/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0862 - ACC: 1.0000 - Prec: 0.9536 - Rec: 0.8393 - AUC: 0.9497 - val_loss: 0.1060 - val_ACC: 1.0000 - val_Prec: 0.9263 - val_Rec: 0.8273 - val_AUC: 0.9264
# Epoch 36/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0851 - ACC: 1.0000 - Prec: 0.9546 - Rec: 0.8389 - AUC: 0.9507 - val_loss: 0.1035 - val_ACC: 1.0000 - val_Prec: 0.9279 - val_Rec: 0.8289 - val_AUC: 0.9300
# Epoch 37/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0849 - ACC: 1.0000 - Prec: 0.9538 - Rec: 0.8403 - AUC: 0.9510 - val_loss: 0.1039 - val_ACC: 1.0000 - val_Prec: 0.9201 - val_Rec: 0.8389 - val_AUC: 0.9279
# Epoch 38/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0838 - ACC: 1.0000 - Prec: 0.9544 - Rec: 0.8426 - AUC: 0.9522 - val_loss: 0.1014 - val_ACC: 1.0000 - val_Prec: 0.9232 - val_Rec: 0.8444 - val_AUC: 0.9312
# Epoch 39/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0830 - ACC: 1.0000 - Prec: 0.9548 - Rec: 0.8442 - AUC: 0.9530 - val_loss: 0.1012 - val_ACC: 1.0000 - val_Prec: 0.9302 - val_Rec: 0.8366 - val_AUC: 0.9324
# Epoch 40/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0822 - ACC: 1.0000 - Prec: 0.9548 - Rec: 0.8468 - AUC: 0.9539 - val_loss: 0.1008 - val_ACC: 1.0000 - val_Prec: 0.9300 - val_Rec: 0.8386 - val_AUC: 0.9325
# Epoch 41/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0816 - ACC: 1.0000 - Prec: 0.9557 - Rec: 0.8461 - AUC: 0.9543 - val_loss: 0.1020 - val_ACC: 1.0000 - val_Prec: 0.9221 - val_Rec: 0.8433 - val_AUC: 0.9302
# Epoch 42/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0809 - ACC: 1.0000 - Prec: 0.9552 - Rec: 0.8470 - AUC: 0.9553 - val_loss: 0.1020 - val_ACC: 1.0000 - val_Prec: 0.9342 - val_Rec: 0.8292 - val_AUC: 0.9327
# Epoch 43/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0802 - ACC: 1.0000 - Prec: 0.9575 - Rec: 0.8484 - AUC: 0.9555 - val_loss: 0.1000 - val_ACC: 1.0000 - val_Prec: 0.9357 - val_Rec: 0.8349 - val_AUC: 0.9343
# Epoch 44/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0794 - ACC: 1.0000 - Prec: 0.9569 - Rec: 0.8492 - AUC: 0.9568 - val_loss: 0.1001 - val_ACC: 1.0000 - val_Prec: 0.9342 - val_Rec: 0.8361 - val_AUC: 0.9330
# Epoch 45/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0786 - ACC: 1.0000 - Prec: 0.9575 - Rec: 0.8519 - AUC: 0.9575 - val_loss: 0.1003 - val_ACC: 1.0000 - val_Prec: 0.9363 - val_Rec: 0.8356 - val_AUC: 0.9334
# Epoch 46/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0782 - ACC: 1.0000 - Prec: 0.9575 - Rec: 0.8518 - AUC: 0.9578 - val_loss: 0.1007 - val_ACC: 1.0000 - val_Prec: 0.9386 - val_Rec: 0.8338 - val_AUC: 0.9325
# Epoch 47/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0777 - ACC: 1.0000 - Prec: 0.9557 - Rec: 0.8544 - AUC: 0.9584 - val_loss: 0.1006 - val_ACC: 1.0000 - val_Prec: 0.9446 - val_Rec: 0.8301 - val_AUC: 0.9339
# Epoch 48/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0776 - ACC: 1.0000 - Prec: 0.9565 - Rec: 0.8532 - AUC: 0.9584 - val_loss: 0.1010 - val_ACC: 1.0000 - val_Prec: 0.9476 - val_Rec: 0.8264 - val_AUC: 0.9345
# Epoch 49/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0766 - ACC: 1.0000 - Prec: 0.9578 - Rec: 0.8562 - AUC: 0.9594 - val_loss: 0.0981 - val_ACC: 1.0000 - val_Prec: 0.9400 - val_Rec: 0.8405 - val_AUC: 0.9351
# Epoch 50/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0764 - ACC: 1.0000 - Prec: 0.9583 - Rec: 0.8556 - AUC: 0.9592 - val_loss: 0.0983 - val_ACC: 1.0000 - val_Prec: 0.9440 - val_Rec: 0.8352 - val_AUC: 0.9357
# Epoch 51/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0755 - ACC: 1.0000 - Prec: 0.9571 - Rec: 0.8603 - AUC: 0.9604 - val_loss: 0.0981 - val_ACC: 1.0000 - val_Prec: 0.9398 - val_Rec: 0.8405 - val_AUC: 0.9344
# Epoch 52/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0754 - ACC: 1.0000 - Prec: 0.9584 - Rec: 0.8587 - AUC: 0.9604 - val_loss: 0.0976 - val_ACC: 1.0000 - val_Prec: 0.9414 - val_Rec: 0.8424 - val_AUC: 0.9351
# Epoch 53/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0751 - ACC: 1.0000 - Prec: 0.9580 - Rec: 0.8604 - AUC: 0.9604 - val_loss: 0.0986 - val_ACC: 1.0000 - val_Prec: 0.9501 - val_Rec: 0.8324 - val_AUC: 0.9347
# Epoch 54/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0746 - ACC: 1.0000 - Prec: 0.9588 - Rec: 0.8627 - AUC: 0.9611 - val_loss: 0.0944 - val_ACC: 1.0000 - val_Prec: 0.9501 - val_Rec: 0.8402 - val_AUC: 0.9401
# Epoch 55/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0741 - ACC: 1.0000 - Prec: 0.9596 - Rec: 0.8612 - AUC: 0.9613 - val_loss: 0.0956 - val_ACC: 1.0000 - val_Prec: 0.9530 - val_Rec: 0.8363 - val_AUC: 0.9392
# Epoch 56/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0740 - ACC: 1.0000 - Prec: 0.9594 - Rec: 0.8627 - AUC: 0.9614 - val_loss: 0.0950 - val_ACC: 1.0000 - val_Prec: 0.9451 - val_Rec: 0.8451 - val_AUC: 0.9375
# Epoch 57/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9583 - Rec: 0.8636 - AUC: 0.9621 - val_loss: 0.0976 - val_ACC: 1.0000 - val_Prec: 0.9478 - val_Rec: 0.8354 - val_AUC: 0.9375
# Epoch 58/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0734 - ACC: 1.0000 - Prec: 0.9589 - Rec: 0.8640 - AUC: 0.9620 - val_loss: 0.0969 - val_ACC: 1.0000 - val_Prec: 0.9353 - val_Rec: 0.8497 - val_AUC: 0.9340
# Epoch 59/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0733 - ACC: 1.0000 - Prec: 0.9584 - Rec: 0.8640 - AUC: 0.9620 - val_loss: 0.0951 - val_ACC: 1.0000 - val_Prec: 0.9441 - val_Rec: 0.8488 - val_AUC: 0.9353
# Epoch 60/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0731 - ACC: 1.0000 - Prec: 0.9578 - Rec: 0.8656 - AUC: 0.9624 - val_loss: 0.0939 - val_ACC: 1.0000 - val_Prec: 0.9526 - val_Rec: 0.8439 - val_AUC: 0.9382
# Epoch 61/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0724 - ACC: 1.0000 - Prec: 0.9586 - Rec: 0.8653 - AUC: 0.9628 - val_loss: 0.0971 - val_ACC: 1.0000 - val_Prec: 0.9506 - val_Rec: 0.8393 - val_AUC: 0.9356
# Epoch 62/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0721 - ACC: 1.0000 - Prec: 0.9584 - Rec: 0.8661 - AUC: 0.9631 - val_loss: 0.0948 - val_ACC: 1.0000 - val_Prec: 0.9485 - val_Rec: 0.8419 - val_AUC: 0.9383
# Epoch 63/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0716 - ACC: 1.0000 - Prec: 0.9610 - Rec: 0.8668 - AUC: 0.9632 - val_loss: 0.0924 - val_ACC: 1.0000 - val_Prec: 0.9366 - val_Rec: 0.8608 - val_AUC: 0.9395
# Epoch 64/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0716 - ACC: 1.0000 - Prec: 0.9585 - Rec: 0.8689 - AUC: 0.9632 - val_loss: 0.0938 - val_ACC: 1.0000 - val_Prec: 0.9522 - val_Rec: 0.8430 - val_AUC: 0.9395
# Epoch 65/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0716 - ACC: 1.0000 - Prec: 0.9584 - Rec: 0.8706 - AUC: 0.9633 - val_loss: 0.0965 - val_ACC: 1.0000 - val_Prec: 0.9570 - val_Rec: 0.8329 - val_AUC: 0.9391
# Epoch 66/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0718 - ACC: 1.0000 - Prec: 0.9586 - Rec: 0.8684 - AUC: 0.9631 - val_loss: 0.0962 - val_ACC: 1.0000 - val_Prec: 0.9559 - val_Rec: 0.8340 - val_AUC: 0.9381
# Epoch 67/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0707 - ACC: 1.0000 - Prec: 0.9609 - Rec: 0.8700 - AUC: 0.9637 - val_loss: 0.0936 - val_ACC: 1.0000 - val_Prec: 0.9519 - val_Rec: 0.8442 - val_AUC: 0.9392
# Epoch 68/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0711 - ACC: 1.0000 - Prec: 0.9603 - Rec: 0.8694 - AUC: 0.9635 - val_loss: 0.0916 - val_ACC: 1.0000 - val_Prec: 0.9494 - val_Rec: 0.8541 - val_AUC: 0.9407
# Epoch 69/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0704 - ACC: 1.0000 - Prec: 0.9603 - Rec: 0.8701 - AUC: 0.9642 - val_loss: 0.0964 - val_ACC: 1.0000 - val_Prec: 0.9573 - val_Rec: 0.8338 - val_AUC: 0.9372
# Epoch 70/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0703 - ACC: 1.0000 - Prec: 0.9606 - Rec: 0.8721 - AUC: 0.9642 - val_loss: 0.0936 - val_ACC: 1.0000 - val_Prec: 0.9497 - val_Rec: 0.8492 - val_AUC: 0.9378
# Epoch 71/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0705 - ACC: 1.0000 - Prec: 0.9595 - Rec: 0.8724 - AUC: 0.9639 - val_loss: 0.0952 - val_ACC: 1.0000 - val_Prec: 0.9506 - val_Rec: 0.8416 - val_AUC: 0.9374
# Epoch 72/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0701 - ACC: 1.0000 - Prec: 0.9609 - Rec: 0.8707 - AUC: 0.9642 - val_loss: 0.0933 - val_ACC: 1.0000 - val_Prec: 0.9475 - val_Rec: 0.8507 - val_AUC: 0.9379
# Epoch 73/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0701 - ACC: 1.0000 - Prec: 0.9592 - Rec: 0.8731 - AUC: 0.9644 - val_loss: 0.0921 - val_ACC: 1.0000 - val_Prec: 0.9513 - val_Rec: 0.8477 - val_AUC: 0.9404
# Epoch 74/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0702 - ACC: 1.0000 - Prec: 0.9614 - Rec: 0.8708 - AUC: 0.9642 - val_loss: 0.0947 - val_ACC: 1.0000 - val_Prec: 0.9494 - val_Rec: 0.8449 - val_AUC: 0.9389
# Epoch 75/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0699 - ACC: 1.0000 - Prec: 0.9596 - Rec: 0.8730 - AUC: 0.9644 - val_loss: 0.0927 - val_ACC: 1.0000 - val_Prec: 0.9488 - val_Rec: 0.8525 - val_AUC: 0.9386
# Epoch 76/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0700 - ACC: 1.0000 - Prec: 0.9608 - Rec: 0.8713 - AUC: 0.9645 - val_loss: 0.0943 - val_ACC: 1.0000 - val_Prec: 0.9492 - val_Rec: 0.8446 - val_AUC: 0.9376
# Epoch 77/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0699 - ACC: 1.0000 - Prec: 0.9590 - Rec: 0.8717 - AUC: 0.9646 - val_loss: 0.0966 - val_ACC: 1.0000 - val_Prec: 0.9562 - val_Rec: 0.8354 - val_AUC: 0.9364
# Epoch 78/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0695 - ACC: 1.0000 - Prec: 0.9594 - Rec: 0.8749 - AUC: 0.9649 - val_loss: 0.0937 - val_ACC: 1.0000 - val_Prec: 0.9495 - val_Rec: 0.8500 - val_AUC: 0.9376
# Epoch 79/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0693 - ACC: 1.0000 - Prec: 0.9606 - Rec: 0.8737 - AUC: 0.9650 - val_loss: 0.0927 - val_ACC: 1.0000 - val_Prec: 0.9505 - val_Rec: 0.8497 - val_AUC: 0.9388
# Epoch 80/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0692 - ACC: 1.0000 - Prec: 0.9602 - Rec: 0.8730 - AUC: 0.9654 - val_loss: 0.0941 - val_ACC: 1.0000 - val_Prec: 0.9518 - val_Rec: 0.8439 - val_AUC: 0.9384
# Epoch 81/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0689 - ACC: 1.0000 - Prec: 0.9610 - Rec: 0.8736 - AUC: 0.9652 - val_loss: 0.0932 - val_ACC: 1.0000 - val_Prec: 0.9485 - val_Rec: 0.8507 - val_AUC: 0.9384
# Epoch 82/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0689 - ACC: 1.0000 - Prec: 0.9599 - Rec: 0.8764 - AUC: 0.9653 - val_loss: 0.0920 - val_ACC: 1.0000 - val_Prec: 0.9495 - val_Rec: 0.8495 - val_AUC: 0.9402
# Epoch 83/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0688 - ACC: 1.0000 - Prec: 0.9615 - Rec: 0.8736 - AUC: 0.9653 - val_loss: 0.0946 - val_ACC: 1.0000 - val_Prec: 0.9486 - val_Rec: 0.8470 - val_AUC: 0.9375
# Epoch 84/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0686 - ACC: 1.0000 - Prec: 0.9608 - Rec: 0.8754 - AUC: 0.9656 - val_loss: 0.0929 - val_ACC: 1.0000 - val_Prec: 0.9450 - val_Rec: 0.8548 - val_AUC: 0.9384
# Epoch 85/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0685 - ACC: 1.0000 - Prec: 0.9616 - Rec: 0.8756 - AUC: 0.9658 - val_loss: 0.0941 - val_ACC: 1.0000 - val_Prec: 0.9457 - val_Rec: 0.8548 - val_AUC: 0.9357
# Epoch 86/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0688 - ACC: 1.0000 - Prec: 0.9608 - Rec: 0.8753 - AUC: 0.9654 - val_loss: 0.0944 - val_ACC: 1.0000 - val_Prec: 0.9460 - val_Rec: 0.8495 - val_AUC: 0.9360
# Epoch 87/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0688 - ACC: 1.0000 - Prec: 0.9609 - Rec: 0.8762 - AUC: 0.9656 - val_loss: 0.0918 - val_ACC: 1.0000 - val_Prec: 0.9500 - val_Rec: 0.8518 - val_AUC: 0.9400
# Epoch 88/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0679 - ACC: 1.0000 - Prec: 0.9618 - Rec: 0.8771 - AUC: 0.9660 - val_loss: 0.0923 - val_ACC: 1.0000 - val_Prec: 0.9430 - val_Rec: 0.8578 - val_AUC: 0.9387
# Epoch 89/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0679 - ACC: 1.0000 - Prec: 0.9613 - Rec: 0.8777 - AUC: 0.9662 - val_loss: 0.0926 - val_ACC: 1.0000 - val_Prec: 0.9489 - val_Rec: 0.8516 - val_AUC: 0.9391
# Epoch 90/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0683 - ACC: 1.0000 - Prec: 0.9620 - Rec: 0.8751 - AUC: 0.9655 - val_loss: 0.0924 - val_ACC: 1.0000 - val_Prec: 0.9400 - val_Rec: 0.8603 - val_AUC: 0.9384
# Epoch 91/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0676 - ACC: 1.0000 - Prec: 0.9626 - Rec: 0.8770 - AUC: 0.9662 - val_loss: 0.0920 - val_ACC: 1.0000 - val_Prec: 0.9440 - val_Rec: 0.8597 - val_AUC: 0.9390
# Epoch 92/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0678 - ACC: 1.0000 - Prec: 0.9598 - Rec: 0.8773 - AUC: 0.9661 - val_loss: 0.0924 - val_ACC: 1.0000 - val_Prec: 0.9484 - val_Rec: 0.8493 - val_AUC: 0.9402
# Epoch 93/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0674 - ACC: 1.0000 - Prec: 0.9631 - Rec: 0.8782 - AUC: 0.9665 - val_loss: 0.0930 - val_ACC: 1.0000 - val_Prec: 0.9499 - val_Rec: 0.8469 - val_AUC: 0.9397
# Epoch 94/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0679 - ACC: 1.0000 - Prec: 0.9614 - Rec: 0.8784 - AUC: 0.9656 - val_loss: 0.0930 - val_ACC: 1.0000 - val_Prec: 0.9461 - val_Rec: 0.8514 - val_AUC: 0.9391
# Epoch 95/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0670 - ACC: 1.0000 - Prec: 0.9622 - Rec: 0.8783 - AUC: 0.9668 - val_loss: 0.0928 - val_ACC: 1.0000 - val_Prec: 0.9517 - val_Rec: 0.8474 - val_AUC: 0.9391
# Epoch 96/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0674 - ACC: 1.0000 - Prec: 0.9605 - Rec: 0.8761 - AUC: 0.9664 - val_loss: 0.0932 - val_ACC: 1.0000 - val_Prec: 0.9489 - val_Rec: 0.8516 - val_AUC: 0.9377
# Epoch 97/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0666 - ACC: 1.0000 - Prec: 0.9630 - Rec: 0.8806 - AUC: 0.9671 - val_loss: 0.0913 - val_ACC: 1.0000 - val_Prec: 0.9443 - val_Rec: 0.8615 - val_AUC: 0.9392
# Epoch 98/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0666 - ACC: 1.0000 - Prec: 0.9630 - Rec: 0.8796 - AUC: 0.9670 - val_loss: 0.0927 - val_ACC: 1.0000 - val_Prec: 0.9377 - val_Rec: 0.8610 - val_AUC: 0.9375
# Epoch 99/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0672 - ACC: 1.0000 - Prec: 0.9630 - Rec: 0.8776 - AUC: 0.9663 - val_loss: 0.0920 - val_ACC: 1.0000 - val_Prec: 0.9441 - val_Rec: 0.8574 - val_AUC: 0.9391
# Epoch 100/100
# 57/57 [==============================] - 0s 2ms/step - loss: 0.0670 - ACC: 1.0000 - Prec: 0.9616 - Rec: 0.8784 - AUC: 0.9669 - val_loss: 0.0936 - val_ACC: 1.0000 - val_Prec: 0.9472 - val_Rec: 0.8518 - val_AUC: 0.9382
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 6)                 600
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 607
# Trainable params: 607
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### <font color=#cd0000> Clasificación </font>

# %%
y_real = enc.inverse_transform(y_test)
y_pred = y_pred.astype('int')
y_pred = enc.inverse_transform(y_pred)
print(confusion_matrix(y_real, y_pred))
print(classification_report(y_real, y_pred, zero_division=0))
# Out:
# [[3030  269]
#  [ 840 4828]]
#               precision    recall  f1-score   support
#
#      Control       0.78      0.92      0.85      3299
#      Estudio       0.95      0.85      0.90      5668
#
#     accuracy                           0.88      8967
#    macro avg       0.87      0.89      0.87      8967
# weighted avg       0.89      0.88      0.88      8967
# c:\Users\Javier\anaconda3\envs\tfg_env\lib\site-packages\sklearn\preprocessing\_label.py:154: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # <font color=#cd0000> Conclusiones </font>
# - TODO
