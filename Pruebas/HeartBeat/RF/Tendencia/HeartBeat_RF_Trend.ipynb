# %% [markdown]
# # <font color=#cd0000> Propósito principal </font>
# - La idea de este librillo es comprobar el desempeño de Random Forest sobre el conjunto de datos HeartBeat con la codificación de la `Tendencia`.
#
# ## <font color=#cd0000> Leyenda </font>
# - Los apartados titulados con el código de colores HEX: `#cd0000` serán apartados que tendrán todos los librillos, en concreto, aquellos especificados en el apartado `Síntesis de los criterios usados` del trabajo.
# - Los apartados titulados con el código de colores HEX: `#2451ff` serán apartados de conclusiones propias de este librillo resultado de aplicar un estudio personalizado para cada planteamiento.

# %% [markdown]
# # <font color=#cd0000> Prerrequisitos </font>
# ## <font color=#cd0000> Entorno de ejecución </font>
# - Cambiamos el directorio raíz del librillo para acceder cómodamente a las funciones de utilidad.

# %%
import os

os.chdir('../../../../')
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.gitmodules',
#  'data',
#  'HeartBeat_tmp_test_data.pkl',
#  'HeartBeat_tmp_train_data.pkl',
#  'pkl',
#  'Pruebas',
#  'README.md',
#  'smts_implementation',
#  'utils']

# %% [markdown]
# ## <font color=#cd0000> Constantes y variables predefinidas </font>

# %%
HEARTBEAT_PATH = "data/heartbeat"

DATA_TO_SAVE = "HeartBeat"

PKL_DIR = "pkl/RF/HeartBeat/"
PKL_NAME = "heartbeat_RF_trend.pkl"

SEED = 1

# %% [markdown]
# # <font color=#cd0000> Carga del Dataset </font>

# %%
from utils.load_data import import_heartbeat_dataset

train, test = import_heartbeat_dataset(HEARTBEAT_PATH)

# %%
import pickle

pickle.dump(train, open(DATA_TO_SAVE + "_tmp_train_data.pkl", 'wb'))
pickle.dump(test, open(DATA_TO_SAVE + "_tmp_test_data.pkl", 'wb'))

# %%
import pickle

train = pickle.load(open(DATA_TO_SAVE + "_tmp_train_data.pkl", 'rb'))
test = pickle.load(open(DATA_TO_SAVE + "_tmp_test_data.pkl", 'rb'))

# %%
train.reset_changes()
test.reset_changes()

# %% [markdown]
# # <font color=#cd0000> Preprocesamiento </font>

# %% [markdown]
# ## <font color=#cd0000> Eliminación de datos inválidos y valores atípicos </font>
# - Como ya anticipamos en el análisis en profundidad de este conjunto de datos eliminaremos todos los atributos dado su alto grado de correlación salvo los atributos: `signal_1`, `signal_10`, `signal_20`, `signal_30`, `signal_40`, `signal_50` y `signal_60`
# - Eliminaremos aquellos valores fuera de los percentiles 5 y 95.

# %% [markdown]
# ### <font color=#2451ff> Eliminación de atributos altamente correlacionados </font>

# %%
columns_to_remove = train.get_derived_data_columns()['attrs']
column_to_study = ['signal_1', 'signal_10', 'signal_20',
                   'signal_30', 'signal_40', 'signal_50', 'signal_60']

for col in columns_to_remove:
    if col in column_to_study:
        columns_to_remove.remove(col)

train.drop_derived_data_columns(columns_to_remove)
test.drop_derived_data_columns(columns_to_remove)
# Out:
#         id  TimeStamp  signal_1  signal_10  signal_20  signal_30  signal_40  \
# 0        0          0  0.004578   0.009483   0.003414   0.009437   0.008221
# 1        0          1  0.011682   0.013566   0.004089   0.012686   0.012927
# 2        0          2  0.017709   0.019086   0.011413   0.030151   0.039722
# 3        0          3  0.016318   0.017490   0.016408   0.044615   0.059496
# 4        0          4  0.011723   0.008481   0.008594   0.025718   0.030744
# ...    ...        ...       ...        ...        ...        ...        ...
# 83020  204        400  0.007057   0.001993   0.005595   0.003932   0.002723
# 83021  204        401  0.012607   0.002142   0.004760   0.000763   0.002429
# 83022  204        402  0.011410   0.004370   0.000505   0.000902   0.002300
# 83023  204        403  0.008735   0.003033   0.001830   0.001835   0.004181
# 83024  204        404  0.004821   0.001827   0.000664   0.000804   0.001529
#
#        signal_50  signal_60     class
# 0       0.030211   1.000400    normal
# 1       0.070100   0.673670    normal
# 2       0.100600   0.904520    normal
# 3       0.091279   1.322500    normal
# 4       0.024211   1.622600    normal
# ...          ...        ...       ...
# 83020   0.002055   0.353420  abnormal
# 83021   0.001636   0.349890  abnormal
# 83022   0.001022   0.264820  abnormal
# 83023   0.002472   0.130270  abnormal
# 83024   0.004270   0.082863  abnormal
#
# [83025 rows x 10 columns]

# %% [markdown]
# ### <font color=#2451ff> Eliminación de outliers </font>
# - El grado de outliers mínimo en, al menos, una dimensión para eliminar una serie temporal será del 80% (si más del 80% de los datos son anómalos descartamos la serie).
#   - A pesar de que esto pueda parecer muy grande debemos comprender que, la probabilidad con la que aparezca ruido en una de las dimensiones de una serie temporal multivariada, es muy alta (tenemos varias series temporales con ruido cada una).

# %%
train.remove_outliers(
    headers=train.get_derived_data_columns()['attrs'],
    outliers_limit=.8
)

test.remove_outliers(
    headers=test.get_derived_data_columns()['attrs'],
    outliers_limit=.8
)

# %%
import pandas as pd

# Remaining series
print("Train: Previous number of series: {}".format(
    len(pd.unique(train.original_data['id']))))
print("Train: Actual number of series: {}".format(
    len(pd.unique(train.derived_data['id']))))

print("Test: Previous number of series: {}".format(
    len(pd.unique(test.original_data['id']))))
print("Test: Actual number of series: {}".format(
    len(pd.unique(test.derived_data['id']))))
# Out:
# Train: Previous number of series: 204
# Train: Actual number of series: 198
# Test: Previous number of series: 205
# Test: Actual number of series: 199

# %% [markdown]
# ## <font color=#cd0000> Resoluciones a aplicar </font>
# - Como concluimos en el análisis en profundidad, mantendremos la resolución original.

# %%
# Nothing to see here

# %% [markdown]
# # <font color=#cd0000> División en ventanas </font>
# - Como concluimos en el análisis en profundidad no aplicaremos enventanado pues ya está preaplicado.

# %%
# Nothing to see here

# %% [markdown]
# ## <font color=#cd0000> Codificación </font>

# %%
from utils.codifications import temporal_trend_fn

train.apply_codifications([temporal_trend_fn])
test.apply_codifications([temporal_trend_fn])

# %% [markdown]
# # <font color=#cd0000> Preparación de los datos </font>

# %%
X_train = train.derived_data.drop(['id', 'class'], axis=1)
X_test = test.derived_data.drop(['id', 'class'], axis=1)

y_train = train.derived_data['class'].to_numpy()
y_test = test.derived_data['class'].to_numpy()

# %% [markdown]
# ## <font color=#cd0000> Técnicas de balanceo </font>

# %% [markdown]
# ### <font color=#cd0000> Asignación de pesos a las clases </font>

# %%
import numpy as np
from sklearn.utils import compute_class_weight

class_weights = compute_class_weight(
    'balanced', classes=np.unique(y_train), y=y_train)
class_weights = {'abnormal': class_weights[0], 'normal': class_weights[1]}

# %% [markdown]
# # <font color=#cd0000> Diseño de la topología del bosque </font>
# - Número de estimadores inicial recomendado
# - Profundidad máxima recomendada

# %% [markdown]
# ## <font color=#cd0000> Entrenamiento </font>

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(
    n_estimators=100,
    max_depth=200,
    random_state=SEED,
    class_weight=class_weights
)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=200, random_state=1)

# %% [markdown]
# ## <font color=#cd0000> Clasificación </font>

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

y_pred = clf.predict(X_test)
y_true = np.asarray(y_test)
    
print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# [[53143  4629]
#  [18488  4136]]
#               precision    recall  f1-score   support
#
#     abnormal       0.74      0.92      0.82     57772
#       normal       0.47      0.18      0.26     22624
#
#     accuracy                           0.71     80396
#    macro avg       0.61      0.55      0.54     80396
# weighted avg       0.67      0.71      0.66     80396

# %% [markdown]
# ## <font color=#cd0000> Discusión de los resultados </font>
# - Vamos a estudiar diferentes rangos de hiper-parámetros interesantes que podrían darnos alguna pista sobre el rango en el que buscar el mejor clasificador de este tipo:
#   - Para un `n_estimators` pequeño (10) y una `max_depth` pequeño (10) observamos resultados muy malos en lo que a la capacidad de generalización del clasificador se refiere (clasifica muy bien, únicamente, ejemplos de la clase `abnormal`):
#     ```
#     Confusion matrix:
#     [[55337  2435]
#      [20110  2514]]
#
#     Classification report:
#                   precision    recall  f1-score   support
#
#         abnormal       0.73      0.96      0.83     57772
#           normal       0.51      0.11      0.18     22624
#
#         accuracy                           0.72     80396
#        macro avg       0.62      0.53      0.51     80396
#     weighted avg       0.67      0.72      0.65     80396
#     ```
#   - Para un `n_estimators` pequeño (10) y una `max_depth` grande (200) observamos una mejora notable en la clasificación de ejemplos de la clase `normal`, a continuación, probaremos a incrementar el número de estimadores:
#     ```
#     Confusion matrix:
#     [[51606  6166]
#      [17926  4698]]
#
#     Classification report:
#                   precision    recall  f1-score   support
#
#         abnormal       0.74      0.89      0.81     57772
#           normal       0.43      0.21      0.28     22624
#
#         accuracy                           0.70     80396
#        macro avg       0.59      0.55      0.55     80396
#     weighted avg       0.66      0.70      0.66     80396
#     ```
#   - Para un `n_estimators` grande (200) y una `max_depth` grande (200) observamos un pequeño decremento en la correcta clasificación de ejemplos de la clase normal de modo que probaremos un valor intermedio a continuación:
#     ```
#     Confusion matrix:
#     [[53290  4482]
#      [18577  4047]]
#
#     Classification report:
#                       precision    recall  f1-score   support
#
#         abnormal       0.74      0.92      0.82     57772
#           normal       0.47      0.18      0.26     22624
#
#         accuracy                           0.71     80396
#        macro avg       0.61      0.55      0.54     80396
#     weighted avg       0.67      0.71      0.66     80396
#     ```
#   - Para un `n_estimators` intermedio (100) y una `max_depth` grande (200) no observamos una mejora notable con respecto al caso anterior pero reducimos el tiempo de entrenamiento por lo que lo tomaremos como mejor:
#     ```
#     Confusion matrix:
#     [[53143  4629]
#      [18488  4136]]
#
#     Classification report:
#                   precision    recall  f1-score   support
#
#         abnormal       0.74      0.92      0.82     57772
#           normal       0.47      0.18      0.26     22624
#
#         accuracy                           0.71     80396
#        macro avg       0.61      0.55      0.54     80396
#     weighted avg       0.67      0.71      0.66     80396
#     ```

# %% [markdown]
# ## <font color=#cd0000> Conclusiones </font>
# - Como podemos observar ni con esta codificación el clasificador RandomForest es capaz de mejorar en la tarea de clasificación con respecto a la clasificación de las series en bruto (`HeartBeat_RF_Raw.ipynb`) y, de nuevo, esto se debe a que no tiene en cuenta el orden de las secuencias con el uso de la técnica Bagging.
# - No obstante si no tuviéramos más remedio que utilizarlo de esta forma buscaríamos el mejor en el rango orientativo:
#   - `n_estimators`: [10, 100]
#   - `max_depth`: [100, 200]

# %% [markdown]
# # <font color=#cd0000> Randomized Search </font>
# - Búsqueda de hiper-parámetros aleatoria con RF maximizando ``macro avg f1-score``

# %% [markdown]
# ## <font color=#cd0000> Rangos de búsqueda </font>
# - Como vimos anteriormente los rangos de búsqueda aleatoria de los mejores hiper-parámetros serán los siguientes

# %%
N_ESTIMATORS_RANGE = range(10, 100)
MAX_DEPTH_RANGE = range(100, 200)

# %%
import random
import pickle
import utils.constants as cs
from sklearn.ensemble import RandomForestClassifier
from utils.classifier_utils import (windowed_cross_val,
                                    compute_classification_reports_means)
from utils.plot_utils import pretty_print_classification_report_dict


def rf_randomized_search_cv(
        windowed_series,
        relation_with_series,
        prefix,
        class_weights,
        cv=5):
    global PKL_DIR
    all_clf_used = {}

    n_samples = 5
    n_estimators_list = random.sample(list(N_ESTIMATORS_RANGE), n_samples)
    max_depth_list = random.sample(list(MAX_DEPTH_RANGE), n_samples)

    best_hyp_params = None
    best_score = 0
    for n_estimators in n_estimators_list:
        for max_depth in max_depth_list:
            clf = RandomForestClassifier(
                n_estimators=n_estimators,
                max_depth=max_depth,
                random_state=SEED,
                class_weight=class_weights
            )

            reports = windowed_cross_val(
                clf,
                windowed_series,
                relation_with_series,
                estimator_type=cs.ESTIMATOR_SKLEARN,
                cv=cv,
                drop_columns=['id', 'class'],
                seed=SEED
            )
            mean_report = compute_classification_reports_means(reports)
            all_clf_used[(n_estimators, max_depth)] = mean_report

            if mean_report['macro avg']['f1-score'][0] >= best_score:
                best_score = mean_report['macro avg']['f1-score'][0]
                best_hyp_params = (n_estimators, max_depth)
                best_report = mean_report

            print("\t\t--------------ACTUAL BEST: N_Estimators={}; Max_Depth={}--------------"
                  .format(best_hyp_params[0], best_hyp_params[1]))
            pretty_print_classification_report_dict(best_report)
            print("\t\t--------------ITERATION: N_Estimators={}; Max_Depth={}--------------"
                  .format(n_estimators, max_depth))
            pretty_print_classification_report_dict(mean_report)

    with open(PKL_DIR + prefix, 'wb') as file:
        pickle.dump(all_clf_used, file)

    return best_hyp_params, best_report

# %%
rf_randomized_search_cv(
    train.derived_data,
    train.derived_data_windows_per_serie,
    PKL_NAME,
    class_weights,
    cv=5)
# Out:
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=138--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=51; Max_Depth=138--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=141--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=51; Max_Depth=141--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=135--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=51; Max_Depth=135--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=164--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=51; Max_Depth=164--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=56; Max_Depth=138--------------
# Accuracy: 0.7097095578398563 +/- 0.051351914463569265
# abnormal:
# 	precision: 0.7324512031530442 +/- 0.06524915321047989
# 	recall: 0.935239016550492 +/- 0.026632317894465345
# 	f1-score: 0.8193585845433713 +/- 0.03968396996461266
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5163507723336053 +/- 0.11197557733895487
# 	recall: 0.16046594082485172 +/- 0.030060991543742248
# 	f1-score: 0.2375761363156978 +/- 0.025995187200768353
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6244009877433248 +/- 0.04397270499407465
# 	recall: 0.5478524786876718 +/- 0.009770241158330804
# 	f1-score: 0.5284673604295346 +/- 0.028932098668090846
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.678975821691108 +/- 0.044080765210440145
# 	recall: 0.7097095578398563 +/- 0.051351914463569265
# 	f1-score: 0.6530183923660614 +/- 0.06824497647503125
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=56; Max_Depth=141--------------
# Accuracy: 0.7097095578398563 +/- 0.051351914463569265
# abnormal:
# 	precision: 0.7324512031530442 +/- 0.06524915321047989
# 	recall: 0.935239016550492 +/- 0.026632317894465345
# 	f1-score: 0.8193585845433713 +/- 0.03968396996461266
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5163507723336053 +/- 0.11197557733895487
# 	recall: 0.16046594082485172 +/- 0.030060991543742248
# 	f1-score: 0.2375761363156978 +/- 0.025995187200768353
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6244009877433248 +/- 0.04397270499407465
# 	recall: 0.5478524786876718 +/- 0.009770241158330804
# 	f1-score: 0.5284673604295346 +/- 0.028932098668090846
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.678975821691108 +/- 0.044080765210440145
# 	recall: 0.7097095578398563 +/- 0.051351914463569265
# 	f1-score: 0.6530183923660614 +/- 0.06824497647503125
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=56; Max_Depth=135--------------
# Accuracy: 0.7097095578398563 +/- 0.051351914463569265
# abnormal:
# 	precision: 0.7324512031530442 +/- 0.06524915321047989
# 	recall: 0.935239016550492 +/- 0.026632317894465345
# 	f1-score: 0.8193585845433713 +/- 0.03968396996461266
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5163507723336053 +/- 0.11197557733895487
# 	recall: 0.16046594082485172 +/- 0.030060991543742248
# 	f1-score: 0.2375761363156978 +/- 0.025995187200768353
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6244009877433248 +/- 0.04397270499407465
# 	recall: 0.5478524786876718 +/- 0.009770241158330804
# 	f1-score: 0.5284673604295346 +/- 0.028932098668090846
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.678975821691108 +/- 0.044080765210440145
# 	recall: 0.7097095578398563 +/- 0.051351914463569265
# 	f1-score: 0.6530183923660614 +/- 0.06824497647503125
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=56; Max_Depth=164--------------
# Accuracy: 0.7097095578398563 +/- 0.051351914463569265
# abnormal:
# 	precision: 0.7324512031530442 +/- 0.06524915321047989
# 	recall: 0.935239016550492 +/- 0.026632317894465345
# 	f1-score: 0.8193585845433713 +/- 0.03968396996461266
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5163507723336053 +/- 0.11197557733895487
# 	recall: 0.16046594082485172 +/- 0.030060991543742248
# 	f1-score: 0.2375761363156978 +/- 0.025995187200768353
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6244009877433248 +/- 0.04397270499407465
# 	recall: 0.5478524786876718 +/- 0.009770241158330804
# 	f1-score: 0.5284673604295346 +/- 0.028932098668090846
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.678975821691108 +/- 0.044080765210440145
# 	recall: 0.7097095578398563 +/- 0.051351914463569265
# 	f1-score: 0.6530183923660614 +/- 0.06824497647503125
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=56; Max_Depth=121--------------
# Accuracy: 0.7097095578398563 +/- 0.051351914463569265
# abnormal:
# 	precision: 0.7324512031530442 +/- 0.06524915321047989
# 	recall: 0.935239016550492 +/- 0.026632317894465345
# 	f1-score: 0.8193585845433713 +/- 0.03968396996461266
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5163507723336053 +/- 0.11197557733895487
# 	recall: 0.16046594082485172 +/- 0.030060991543742248
# 	f1-score: 0.2375761363156978 +/- 0.025995187200768353
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6244009877433248 +/- 0.04397270499407465
# 	recall: 0.5478524786876718 +/- 0.009770241158330804
# 	f1-score: 0.5284673604295346 +/- 0.028932098668090846
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.678975821691108 +/- 0.044080765210440145
# 	recall: 0.7097095578398563 +/- 0.051351914463569265
# 	f1-score: 0.6530183923660614 +/- 0.06824497647503125
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=40; Max_Depth=138--------------
# Accuracy: 0.7093110687340088 +/- 0.051450188260626945
# abnormal:
# 	precision: 0.7330940152423508 +/- 0.06553543462066395
# 	recall: 0.9325544867184057 +/- 0.02717690173292732
# 	f1-score: 0.8187216502979439 +/- 0.039954457264044986
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5137682084897521 +/- 0.11050354924835389
# 	recall: 0.1658390165939671 +/- 0.030948670469919875
# 	f1-score: 0.24333748240104586 +/- 0.02672708428054176
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6234311118660514 +/- 0.04404044139821582
# 	recall: 0.5491967516561864 +/- 0.010710398553172936
# 	f1-score: 0.5310295663494948 +/- 0.02943754356746916
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6785560071293383 +/- 0.045305954823381046
# 	recall: 0.7093110687340088 +/- 0.051450188260626945
# 	f1-score: 0.6542164456260618 +/- 0.06807495747281285
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=40; Max_Depth=141--------------
# Accuracy: 0.7093110687340088 +/- 0.051450188260626945
# abnormal:
# 	precision: 0.7330940152423508 +/- 0.06553543462066395
# 	recall: 0.9325544867184057 +/- 0.02717690173292732
# 	f1-score: 0.8187216502979439 +/- 0.039954457264044986
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5137682084897521 +/- 0.11050354924835389
# 	recall: 0.1658390165939671 +/- 0.030948670469919875
# 	f1-score: 0.24333748240104586 +/- 0.02672708428054176
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6234311118660514 +/- 0.04404044139821582
# 	recall: 0.5491967516561864 +/- 0.010710398553172936
# 	f1-score: 0.5310295663494948 +/- 0.02943754356746916
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6785560071293383 +/- 0.045305954823381046
# 	recall: 0.7093110687340088 +/- 0.051450188260626945
# 	f1-score: 0.6542164456260618 +/- 0.06807495747281285
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=40; Max_Depth=135--------------
# Accuracy: 0.7093110687340088 +/- 0.051450188260626945
# abnormal:
# 	precision: 0.7330940152423508 +/- 0.06553543462066395
# 	recall: 0.9325544867184057 +/- 0.02717690173292732
# 	f1-score: 0.8187216502979439 +/- 0.039954457264044986
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5137682084897521 +/- 0.11050354924835389
# 	recall: 0.1658390165939671 +/- 0.030948670469919875
# 	f1-score: 0.24333748240104586 +/- 0.02672708428054176
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6234311118660514 +/- 0.04404044139821582
# 	recall: 0.5491967516561864 +/- 0.010710398553172936
# 	f1-score: 0.5310295663494948 +/- 0.02943754356746916
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6785560071293383 +/- 0.045305954823381046
# 	recall: 0.7093110687340088 +/- 0.051450188260626945
# 	f1-score: 0.6542164456260618 +/- 0.06807495747281285
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=40; Max_Depth=164--------------
# Accuracy: 0.7093110687340088 +/- 0.051450188260626945
# abnormal:
# 	precision: 0.7330940152423508 +/- 0.06553543462066395
# 	recall: 0.9325544867184057 +/- 0.02717690173292732
# 	f1-score: 0.8187216502979439 +/- 0.039954457264044986
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5137682084897521 +/- 0.11050354924835389
# 	recall: 0.1658390165939671 +/- 0.030948670469919875
# 	f1-score: 0.24333748240104586 +/- 0.02672708428054176
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6234311118660514 +/- 0.04404044139821582
# 	recall: 0.5491967516561864 +/- 0.010710398553172936
# 	f1-score: 0.5310295663494948 +/- 0.02943754356746916
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6785560071293383 +/- 0.045305954823381046
# 	recall: 0.7093110687340088 +/- 0.051450188260626945
# 	f1-score: 0.6542164456260618 +/- 0.06807495747281285
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=40; Max_Depth=121--------------
# Accuracy: 0.7093110687340088 +/- 0.051450188260626945
# abnormal:
# 	precision: 0.7330940152423508 +/- 0.06553543462066395
# 	recall: 0.9325544867184057 +/- 0.02717690173292732
# 	f1-score: 0.8187216502979439 +/- 0.039954457264044986
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5137682084897521 +/- 0.11050354924835389
# 	recall: 0.1658390165939671 +/- 0.030948670469919875
# 	f1-score: 0.24333748240104586 +/- 0.02672708428054176
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6234311118660514 +/- 0.04404044139821582
# 	recall: 0.5491967516561864 +/- 0.010710398553172936
# 	f1-score: 0.5310295663494948 +/- 0.02943754356746916
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6785560071293383 +/- 0.045305954823381046
# 	recall: 0.7093110687340088 +/- 0.051450188260626945
# 	f1-score: 0.6542164456260618 +/- 0.06807495747281285
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=26; Max_Depth=138--------------
# Accuracy: 0.7070565085786745 +/- 0.050036143193550875
# abnormal:
# 	precision: 0.7331378642474269 +/- 0.06487141209487471
# 	recall: 0.9273317545155878 +/- 0.027587636156532272
# 	f1-score: 0.8167439320095291 +/- 0.03933134276352505
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5004308700249174 +/- 0.10857070735675463
# 	recall: 0.1703407359966766 +/- 0.02866198972547494
# 	f1-score: 0.24709731967856405 +/- 0.024002827720421633
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6167843671361721 +/- 0.041540319541495535
# 	recall: 0.5488362452561323 +/- 0.010206897278358402
# 	f1-score: 0.5319206258440465 +/- 0.027112630766037826
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6749239833382074 +/- 0.04369817979741186
# 	recall: 0.7070565085786745 +/- 0.050036143193550875
# 	f1-score: 0.6541478323035801 +/- 0.06584738350607573
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=26; Max_Depth=141--------------
# Accuracy: 0.7070565085786745 +/- 0.050036143193550875
# abnormal:
# 	precision: 0.7331378642474269 +/- 0.06487141209487471
# 	recall: 0.9273317545155878 +/- 0.027587636156532272
# 	f1-score: 0.8167439320095291 +/- 0.03933134276352505
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5004308700249174 +/- 0.10857070735675463
# 	recall: 0.1703407359966766 +/- 0.02866198972547494
# 	f1-score: 0.24709731967856405 +/- 0.024002827720421633
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6167843671361721 +/- 0.041540319541495535
# 	recall: 0.5488362452561323 +/- 0.010206897278358402
# 	f1-score: 0.5319206258440465 +/- 0.027112630766037826
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6749239833382074 +/- 0.04369817979741186
# 	recall: 0.7070565085786745 +/- 0.050036143193550875
# 	f1-score: 0.6541478323035801 +/- 0.06584738350607573
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=26; Max_Depth=135--------------
# Accuracy: 0.7070565085786745 +/- 0.050036143193550875
# abnormal:
# 	precision: 0.7331378642474269 +/- 0.06487141209487471
# 	recall: 0.9273317545155878 +/- 0.027587636156532272
# 	f1-score: 0.8167439320095291 +/- 0.03933134276352505
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5004308700249174 +/- 0.10857070735675463
# 	recall: 0.1703407359966766 +/- 0.02866198972547494
# 	f1-score: 0.24709731967856405 +/- 0.024002827720421633
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6167843671361721 +/- 0.041540319541495535
# 	recall: 0.5488362452561323 +/- 0.010206897278358402
# 	f1-score: 0.5319206258440465 +/- 0.027112630766037826
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6749239833382074 +/- 0.04369817979741186
# 	recall: 0.7070565085786745 +/- 0.050036143193550875
# 	f1-score: 0.6541478323035801 +/- 0.06584738350607573
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=26; Max_Depth=164--------------
# Accuracy: 0.7070565085786745 +/- 0.050036143193550875
# abnormal:
# 	precision: 0.7331378642474269 +/- 0.06487141209487471
# 	recall: 0.9273317545155878 +/- 0.027587636156532272
# 	f1-score: 0.8167439320095291 +/- 0.03933134276352505
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5004308700249174 +/- 0.10857070735675463
# 	recall: 0.1703407359966766 +/- 0.02866198972547494
# 	f1-score: 0.24709731967856405 +/- 0.024002827720421633
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6167843671361721 +/- 0.041540319541495535
# 	recall: 0.5488362452561323 +/- 0.010206897278358402
# 	f1-score: 0.5319206258440465 +/- 0.027112630766037826
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6749239833382074 +/- 0.04369817979741186
# 	recall: 0.7070565085786745 +/- 0.050036143193550875
# 	f1-score: 0.6541478323035801 +/- 0.06584738350607573
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=51; Max_Depth=121--------------
# Accuracy: 0.7079267950494071 +/- 0.05018213658547491
# abnormal:
# 	precision: 0.7342410088654219 +/- 0.06527667258318577
# 	recall: 0.9265180983446315 +/- 0.028872903431569612
# 	f1-score: 0.8170531956867189 +/- 0.03936718898440059
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5066889330192443 +/- 0.10861831775509055
# 	recall: 0.17617219414249113 +/- 0.032051427941603615
# 	f1-score: 0.25362925804577074 +/- 0.02640674127917446
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6204649709423331 +/- 0.042101456824682235
# 	recall: 0.5513451462435613 +/- 0.010754986997859555
# 	f1-score: 0.5353412268662447 +/- 0.02842504882954852
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6774313855363726 +/- 0.04426057905570979
# 	recall: 0.7079267950494071 +/- 0.05018213658547491
# 	f1-score: 0.6560655198975696 +/- 0.06622772808762012
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=26; Max_Depth=121--------------
# Accuracy: 0.7070565085786745 +/- 0.050036143193550875
# abnormal:
# 	precision: 0.7331378642474269 +/- 0.06487141209487471
# 	recall: 0.9273317545155878 +/- 0.027587636156532272
# 	f1-score: 0.8167439320095291 +/- 0.03933134276352505
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.5004308700249174 +/- 0.10857070735675463
# 	recall: 0.1703407359966766 +/- 0.02866198972547494
# 	f1-score: 0.24709731967856405 +/- 0.024002827720421633
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6167843671361721 +/- 0.041540319541495535
# 	recall: 0.5488362452561323 +/- 0.010206897278358402
# 	f1-score: 0.5319206258440465 +/- 0.027112630766037826
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6749239833382074 +/- 0.04369817979741186
# 	recall: 0.7070565085786745 +/- 0.050036143193550875
# 	f1-score: 0.6541478323035801 +/- 0.06584738350607573
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=29; Max_Depth=138--------------
# Accuracy: 0.7062955090808775 +/- 0.0476713994506117
# abnormal:
# 	precision: 0.7370851384639506 +/- 0.06479601391199621
# 	recall: 0.9155003196033957 +/- 0.030561858707398373
# 	f1-score: 0.8144349753565961 +/- 0.03828447386048705
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.49818713234644785 +/- 0.10430134937398812
# 	recall: 0.197993145468393 +/- 0.032867464716308886
# 	f1-score: 0.27525365473897845 +/- 0.02440633190507574
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6176361354051991 +/- 0.03797554577906345
# 	recall: 0.5567467325358944 +/- 0.010806706574222506
# 	f1-score: 0.5448443150477874 +/- 0.026198613034333053
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6771636350856702 +/- 0.042380669851290693
# 	recall: 0.7062955090808775 +/- 0.0476713994506117
# 	f1-score: 0.6606163137833847 +/- 0.062498401502266966
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=29; Max_Depth=138--------------
# Accuracy: 0.7062955090808775 +/- 0.0476713994506117
# abnormal:
# 	precision: 0.7370851384639506 +/- 0.06479601391199621
# 	recall: 0.9155003196033957 +/- 0.030561858707398373
# 	f1-score: 0.8144349753565961 +/- 0.03828447386048705
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.49818713234644785 +/- 0.10430134937398812
# 	recall: 0.197993145468393 +/- 0.032867464716308886
# 	f1-score: 0.27525365473897845 +/- 0.02440633190507574
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6176361354051991 +/- 0.03797554577906345
# 	recall: 0.5567467325358944 +/- 0.010806706574222506
# 	f1-score: 0.5448443150477874 +/- 0.026198613034333053
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6771636350856702 +/- 0.042380669851290693
# 	recall: 0.7062955090808775 +/- 0.0476713994506117
# 	f1-score: 0.6606163137833847 +/- 0.062498401502266966
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=29; Max_Depth=141--------------
# Accuracy: 0.7062955090808775 +/- 0.0476713994506117
# abnormal:
# 	precision: 0.7370851384639506 +/- 0.06479601391199621
# 	recall: 0.9155003196033957 +/- 0.030561858707398373
# 	f1-score: 0.8144349753565961 +/- 0.03828447386048705
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.49818713234644785 +/- 0.10430134937398812
# 	recall: 0.197993145468393 +/- 0.032867464716308886
# 	f1-score: 0.27525365473897845 +/- 0.02440633190507574
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6176361354051991 +/- 0.03797554577906345
# 	recall: 0.5567467325358944 +/- 0.010806706574222506
# 	f1-score: 0.5448443150477874 +/- 0.026198613034333053
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6771636350856702 +/- 0.042380669851290693
# 	recall: 0.7062955090808775 +/- 0.0476713994506117
# 	f1-score: 0.6606163137833847 +/- 0.062498401502266966
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=29; Max_Depth=141--------------
# Accuracy: 0.7062955090808775 +/- 0.0476713994506117
# abnormal:
# 	precision: 0.7370851384639506 +/- 0.06479601391199621
# 	recall: 0.9155003196033957 +/- 0.030561858707398373
# 	f1-score: 0.8144349753565961 +/- 0.03828447386048705
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.49818713234644785 +/- 0.10430134937398812
# 	recall: 0.197993145468393 +/- 0.032867464716308886
# 	f1-score: 0.27525365473897845 +/- 0.02440633190507574
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6176361354051991 +/- 0.03797554577906345
# 	recall: 0.5567467325358944 +/- 0.010806706574222506
# 	f1-score: 0.5448443150477874 +/- 0.026198613034333053
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6771636350856702 +/- 0.042380669851290693
# 	recall: 0.7062955090808775 +/- 0.0476713994506117
# 	f1-score: 0.6606163137833847 +/- 0.062498401502266966
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=29; Max_Depth=135--------------
# Accuracy: 0.7062955090808775 +/- 0.0476713994506117
# abnormal:
# 	precision: 0.7370851384639506 +/- 0.06479601391199621
# 	recall: 0.9155003196033957 +/- 0.030561858707398373
# 	f1-score: 0.8144349753565961 +/- 0.03828447386048705
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.49818713234644785 +/- 0.10430134937398812
# 	recall: 0.197993145468393 +/- 0.032867464716308886
# 	f1-score: 0.27525365473897845 +/- 0.02440633190507574
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6176361354051991 +/- 0.03797554577906345
# 	recall: 0.5567467325358944 +/- 0.010806706574222506
# 	f1-score: 0.5448443150477874 +/- 0.026198613034333053
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6771636350856702 +/- 0.042380669851290693
# 	recall: 0.7062955090808775 +/- 0.0476713994506117
# 	f1-score: 0.6606163137833847 +/- 0.062498401502266966
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=29; Max_Depth=135--------------
# Accuracy: 0.7062955090808775 +/- 0.0476713994506117
# abnormal:
# 	precision: 0.7370851384639506 +/- 0.06479601391199621
# 	recall: 0.9155003196033957 +/- 0.030561858707398373
# 	f1-score: 0.8144349753565961 +/- 0.03828447386048705
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.49818713234644785 +/- 0.10430134937398812
# 	recall: 0.197993145468393 +/- 0.032867464716308886
# 	f1-score: 0.27525365473897845 +/- 0.02440633190507574
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6176361354051991 +/- 0.03797554577906345
# 	recall: 0.5567467325358944 +/- 0.010806706574222506
# 	f1-score: 0.5448443150477874 +/- 0.026198613034333053
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6771636350856702 +/- 0.042380669851290693
# 	recall: 0.7062955090808775 +/- 0.0476713994506117
# 	f1-score: 0.6606163137833847 +/- 0.062498401502266966
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=29; Max_Depth=164--------------
# Accuracy: 0.7062955090808775 +/- 0.0476713994506117
# abnormal:
# 	precision: 0.7370851384639506 +/- 0.06479601391199621
# 	recall: 0.9155003196033957 +/- 0.030561858707398373
# 	f1-score: 0.8144349753565961 +/- 0.03828447386048705
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.49818713234644785 +/- 0.10430134937398812
# 	recall: 0.197993145468393 +/- 0.032867464716308886
# 	f1-score: 0.27525365473897845 +/- 0.02440633190507574
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6176361354051991 +/- 0.03797554577906345
# 	recall: 0.5567467325358944 +/- 0.010806706574222506
# 	f1-score: 0.5448443150477874 +/- 0.026198613034333053
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6771636350856702 +/- 0.042380669851290693
# 	recall: 0.7062955090808775 +/- 0.0476713994506117
# 	f1-score: 0.6606163137833847 +/- 0.062498401502266966
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=29; Max_Depth=164--------------
# Accuracy: 0.7062955090808775 +/- 0.0476713994506117
# abnormal:
# 	precision: 0.7370851384639506 +/- 0.06479601391199621
# 	recall: 0.9155003196033957 +/- 0.030561858707398373
# 	f1-score: 0.8144349753565961 +/- 0.03828447386048705
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.49818713234644785 +/- 0.10430134937398812
# 	recall: 0.197993145468393 +/- 0.032867464716308886
# 	f1-score: 0.27525365473897845 +/- 0.02440633190507574
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6176361354051991 +/- 0.03797554577906345
# 	recall: 0.5567467325358944 +/- 0.010806706574222506
# 	f1-score: 0.5448443150477874 +/- 0.026198613034333053
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6771636350856702 +/- 0.042380669851290693
# 	recall: 0.7062955090808775 +/- 0.0476713994506117
# 	f1-score: 0.6606163137833847 +/- 0.062498401502266966
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ACTUAL BEST: N_Estimators=29; Max_Depth=121--------------
# Accuracy: 0.7062955090808775 +/- 0.0476713994506117
# abnormal:
# 	precision: 0.7370851384639506 +/- 0.06479601391199621
# 	recall: 0.9155003196033957 +/- 0.030561858707398373
# 	f1-score: 0.8144349753565961 +/- 0.03828447386048705
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.49818713234644785 +/- 0.10430134937398812
# 	recall: 0.197993145468393 +/- 0.032867464716308886
# 	f1-score: 0.27525365473897845 +/- 0.02440633190507574
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6176361354051991 +/- 0.03797554577906345
# 	recall: 0.5567467325358944 +/- 0.010806706574222506
# 	f1-score: 0.5448443150477874 +/- 0.026198613034333053
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6771636350856702 +/- 0.042380669851290693
# 	recall: 0.7062955090808775 +/- 0.0476713994506117
# 	f1-score: 0.6606163137833847 +/- 0.062498401502266966
# 	support: 15998.4 +/- 412.000776698297
# 		--------------ITERATION: N_Estimators=29; Max_Depth=121--------------
# Accuracy: 0.7062955090808775 +/- 0.0476713994506117
# abnormal:
# 	precision: 0.7370851384639506 +/- 0.06479601391199621
# 	recall: 0.9155003196033957 +/- 0.030561858707398373
# 	f1-score: 0.8144349753565961 +/- 0.03828447386048705
# 	support: 11392.8 +/- 1125.4137727964767
# normal:
# 	precision: 0.49818713234644785 +/- 0.10430134937398812
# 	recall: 0.197993145468393 +/- 0.032867464716308886
# 	f1-score: 0.27525365473897845 +/- 0.02440633190507574
# 	support: 4605.6 +/- 976.3101146664415
# macro avg:
# 	precision: 0.6176361354051991 +/- 0.03797554577906345
# 	recall: 0.5567467325358944 +/- 0.010806706574222506
# 	f1-score: 0.5448443150477874 +/- 0.026198613034333053
# 	support: 15998.4 +/- 412.000776698297
# weighted avg:
# 	precision: 0.6771636350856702 +/- 0.042380669851290693
# 	recall: 0.7062955090808775 +/- 0.0476713994506117
# 	f1-score: 0.6606163137833847 +/- 0.062498401502266966
# 	support: 15998.4 +/- 412.000776698297
# ((29, 121),
#  {'accuracy': (0.7062955090808775, 0.0476713994506117),
#   'abnormal': {'precision': (0.7370851384639506, 0.06479601391199621),
#    'recall': (0.9155003196033957, 0.030561858707398373),
#    'f1-score': (0.8144349753565961, 0.03828447386048705),
#    'support': (11392.8, 1125.4137727964767)},
#   'normal': {'precision': (0.49818713234644785, 0.10430134937398812),
#    'recall': (0.197993145468393, 0.032867464716308886),
#    'f1-score': (0.27525365473897845, 0.02440633190507574),
#    'support': (4605.6, 976.3101146664415)},
#   'macro avg': {'precision': (0.6176361354051991, 0.03797554577906345),
#    'recall': (0.5567467325358944, 0.010806706574222506),
#    'f1-score': (0.5448443150477874, 0.026198613034333053),
#    'support': (15998.4, 412.000776698297)},
#   'weighted avg': {'precision': (0.6771636350856702, 0.042380669851290693),
#    'recall': (0.7062955090808775, 0.0476713994506117),
#    'f1-score': (0.6606163137833847, 0.062498401502266966),
#    'support': (15998.4, 412.000776698297)}})

# %% [markdown]
# # <font color=#cd0000> Randomized Search con múltiples ejecuciones en lugar de Validación Cruzada </font>
# - No llevaremos a cabo esta aproximación ya que tenemos datos suficientes como para ejecutar validación cruzada.

# %%
# Nothing to see here

# %% [markdown]
# # <font color=#cd0000> Análisis de resultados </font>
# - Según la búsqueda aleatoria de hiper-parámetros, la mejor combinación, es la de ``n_estimators`` = 29 y ``max_depth`` = 121:
#     ```
#         Accuracy: 0.7062955090808775 +/- 0.0476713994506117
#         abnormal:
#             precision: 0.7370851384639506 +/- 0.06479601391199621
#             recall: 0.9155003196033957 +/- 0.030561858707398373
#             f1-score: 0.8144349753565961 +/- 0.03828447386048705
#             support: 11392.8 +/- 1125.4137727964767
#         normal:
#             precision: 0.49818713234644785 +/- 0.10430134937398812
#             recall: 0.197993145468393 +/- 0.032867464716308886
#             f1-score: 0.27525365473897845 +/- 0.02440633190507574
#             support: 4605.6 +/- 976.3101146664415
#         macro avg:
#             precision: 0.6176361354051991 +/- 0.03797554577906345
#             recall: 0.5567467325358944 +/- 0.010806706574222506
#             f1-score: 0.5448443150477874 +/- 0.026198613034333053
#             support: 15998.4 +/- 412.000776698297
#         weighted avg:
#             precision: 0.6771636350856702 +/- 0.042380669851290693
#             recall: 0.7062955090808775 +/- 0.0476713994506117
#             f1-score: 0.6606163137833847 +/- 0.062498401502266966
#             support: 15998.4 +/- 412.000776698297
#     ```
# - Ahora vamos a visualizar la evolución de los resultados (25 resultados) para observar cómo avanza nuestra métrica objetivo -> Macro Average F1-Score.

# %%
import pickle

all_reports = pickle.load(open(PKL_DIR + PKL_NAME, 'rb'))

# %%
from utils.plot_utils import plot_score

macro_avg_f1_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['macro avg']['f1-score'][0],
                   'std': all_reports[z]['macro avg']['f1-score'][1]}),
    all_reports
))

plot_score(
    [macro_avg_f1_scores],
    ('n_estimators', 'max_depth'),
    'RandomForest',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Macro Average F1-Score'
)

# %%
abnormal_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['abnormal']['recall'][0],
                   'std': all_reports[z]['abnormal']['recall'][1]}),
    all_reports
))

normal_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['normal']['recall'][0],
                   'std': all_reports[z]['normal']['recall'][1]}),
    all_reports
))

plot_score(
    [abnormal_recall_scores],
    ('n_estimators', 'max_depth'),
    'RandomForest',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Abnormal recall score'
)

plot_score(
    [normal_recall_scores],
    ('n_estimators', 'max_depth'),
    'RandomForest',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Normal recall score'
)

# %% [markdown]
# ## <font color=#cd0000> Evaluación sobre el conjunto de validación </font>
# - Vamos a llevar a cabo la evaluación final sobre el conjunto de validación (esto es lo que irá al apartado de ``Pruebas y Resultados`` de la memoria).

# %% [markdown]
# ### <font color=#cd0000> Entrenamiento </font>

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(
    n_estimators=29,
    max_depth=121,
    class_weight=class_weights,
    random_state=SEED
)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight={'abnormal': 0.7021276595744681,
#                                      'normal': 1.736842105263158},
#                        max_depth=121, n_estimators=29, random_state=1)

# %% [markdown]
# ### <font color=#cd0000> Clasificación </font>

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

y_pred = clf.predict(X_test)
y_true = np.asarray(y_test)
    
print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# [[52500  5272]
#  [18324  4300]]
#               precision    recall  f1-score   support
#
#     abnormal       0.74      0.91      0.82     57772
#       normal       0.45      0.19      0.27     22624
#
#     accuracy                           0.71     80396
#    macro avg       0.60      0.55      0.54     80396
# weighted avg       0.66      0.71      0.66     80396

# %% [markdown]
# # <font color=#cd0000> Conclusiones </font>
# - Como podemos observar en los gráficos obtenidos en el apartado de análisis de resultados, cuanto más profundo son los árboles del bosque peor clasifica la clase minoritaria y esto puede darse a que el bosque se sobreajusta significativamente y se limita a clasificar mejor los ejemplos de la clase mayoritaria.
# - No obstante, frente al conjunto de validación el mejor clasificador es aquel con una profundidad máxima menor que generaliza mejor los datos de la clase minoritaria.
# - Sin embargo, como ya veíamos anteriormente, este clasificador con la codificación actual no es el adecuado para enfrentarse a esta tarea de clasificación como consecuencia de la distribución aleatoria de los datos de cada serie entre los estimadores usando la técnica Bagging.
