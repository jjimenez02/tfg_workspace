# %% [markdown]
# # <font color=#cd0000> Propósito principal </font>
# - La idea de este librillo es preparar el entorno para realizar pruebas para HeartBeat a ser clasificado por una mezcla de las codificaciones simbólica y tendencia aplicadas a SMTS
#
# ## <font color=#cd0000> Leyenda </font>
# - Los apartados titulados con el código de colores HEX: `#cd0000` serán apartados que tendrán todos los librillos, en concreto, aquellos especificados en el apartado `Síntesis de los criterios usados` del trabajo.
# - Los apartados titulados con el código de colores HEX: `#2451ff` serán apartados de conclusiones propias de este librillo resultado de aplicar un estudio personalizado para cada planteamiento.

# %% [markdown]
# # <font color=#cd0000> Prerrequisitos </font>
# ## <font color=#cd0000> Entorno de ejecución </font>
# - Cambiamos el directorio raíz del librillo para acceder cómodamente a las funciones de utilidad.

# %%
import os

os.chdir('../../../../')
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.gitmodules',
#  'data',
#  'HeartBeat_tmp_test_data.pkl',
#  'HeartBeat_tmp_train_data.pkl',
#  'pkl',
#  'Pruebas',
#  'README.md',
#  'smts_implementation',
#  'utils']

# %% [markdown]
# ## <font color=#cd0000> Constantes y variables predefinidas </font>

# %%
HEARTBEAT_PATH = "data/heartbeat"

DATA_TO_SAVE = "HeartBeat"

PKL_DIR = "pkl/SMTS/HeartBeat/"
PKL_NAME = "heartbeat_SMTS_codifSimb_trend.pkl"

SEED = 1

# %% [markdown]
# # <font color=#cd0000> Carga del Dataset </font>

# %%
from utils.load_data import import_heartbeat_dataset

train, test = import_heartbeat_dataset(HEARTBEAT_PATH)

# %%
import pickle

pickle.dump(train, open(DATA_TO_SAVE + "_tmp_train_data.pkl", 'wb'))
pickle.dump(test, open(DATA_TO_SAVE + "_tmp_test_data.pkl", 'wb'))

# %%
import pickle

train = pickle.load(open(DATA_TO_SAVE + "_tmp_train_data.pkl", 'rb'))
test = pickle.load(open(DATA_TO_SAVE + "_tmp_test_data.pkl", 'rb'))

# %%
train.reset_changes()
test.reset_changes()

# %% [markdown]
# # <font color=#cd0000> Preprocesamiento </font>

# %% [markdown]
# ## <font color=#cd0000> Eliminación de datos inválidos y valores atípicos </font>
# - Como ya anticipamos en el análisis en profundidad de este conjunto de datos eliminaremos todos los atributos dado su alto grado de correlación salvo los atributos: `signal_1`, `signal_10`, `signal_20`, `signal_30`, `signal_40`, `signal_50` y `signal_60`
# - Eliminaremos aquellos valores fuera de los percentiles 5 y 95.

# %% [markdown]
# ### <font color=#2451ff> Eliminación de atributos altamente correlacionados </font>

# %%
columns_to_remove = train.get_derived_data_columns()['attrs']
column_to_study = ['signal_1', 'signal_10', 'signal_20',
                   'signal_30', 'signal_40', 'signal_50', 'signal_60']

for col in columns_to_remove:
    if col in column_to_study:
        columns_to_remove.remove(col)

train.drop_derived_data_columns(columns_to_remove)
test.drop_derived_data_columns(columns_to_remove)
# Out:
#         id  TimeStamp  signal_1  signal_10  signal_20  signal_30  signal_40  \
# 0        0          0  0.004578   0.009483   0.003414   0.009437   0.008221
# 1        0          1  0.011682   0.013566   0.004089   0.012686   0.012927
# 2        0          2  0.017709   0.019086   0.011413   0.030151   0.039722
# 3        0          3  0.016318   0.017490   0.016408   0.044615   0.059496
# 4        0          4  0.011723   0.008481   0.008594   0.025718   0.030744
# ...    ...        ...       ...        ...        ...        ...        ...
# 83020  204        400  0.007057   0.001993   0.005595   0.003932   0.002723
# 83021  204        401  0.012607   0.002142   0.004760   0.000763   0.002429
# 83022  204        402  0.011410   0.004370   0.000505   0.000902   0.002300
# 83023  204        403  0.008735   0.003033   0.001830   0.001835   0.004181
# 83024  204        404  0.004821   0.001827   0.000664   0.000804   0.001529
#
#        signal_50  signal_60     class
# 0       0.030211   1.000400    normal
# 1       0.070100   0.673670    normal
# 2       0.100600   0.904520    normal
# 3       0.091279   1.322500    normal
# 4       0.024211   1.622600    normal
# ...          ...        ...       ...
# 83020   0.002055   0.353420  abnormal
# 83021   0.001636   0.349890  abnormal
# 83022   0.001022   0.264820  abnormal
# 83023   0.002472   0.130270  abnormal
# 83024   0.004270   0.082863  abnormal
#
# [83025 rows x 10 columns]

# %% [markdown]
# ### <font color=#2451ff> Eliminación de outliers </font>
# - El grado de outliers mínimo en, al menos, una dimensión para eliminar una serie temporal será del 80% (si más del 80% de los datos son anómalos descartamos la serie).
#   - A pesar de que esto pueda parecer muy grande debemos comprender que, la probabilidad con la que aparezca ruido en una de las dimensiones de una serie temporal multivariada, es muy alta (tenemos varias series temporales con ruido cada una).

# %%
train.remove_outliers(
    headers=train.get_derived_data_columns()['attrs'],
    outliers_limit=.8
)

test.remove_outliers(
    headers=test.get_derived_data_columns()['attrs'],
    outliers_limit=.8
)

# %%
import pandas as pd

# Remaining series
print("Train: Previous number of series: {}".format(
    len(pd.unique(train.original_data['id']))))
print("Train: Actual number of series: {}".format(
    len(pd.unique(train.derived_data['id']))))

print("Test: Previous number of series: {}".format(
    len(pd.unique(test.original_data['id']))))
print("Test: Actual number of series: {}".format(
    len(pd.unique(test.derived_data['id']))))
# Out:
# Train: Previous number of series: 204
# Train: Actual number of series: 198
# Test: Previous number of series: 205
# Test: Actual number of series: 199

# %% [markdown]
# ## <font color=#cd0000> Resoluciones a aplicar </font>
# - Como concluimos en el análisis en profundidad, mantendremos la resolución original.

# %%
# Nothing to see here

# %% [markdown]
# # <font color=#cd0000> División en ventanas </font>
# - Como concluimos en el análisis en profundidad no aplicaremos enventanado pues ya está preaplicado.

# %%
# Nothing to see here

# %% [markdown]
# ## <font color=#cd0000> Codificación </font>

# %%
from utils.codifications import temporal_trend_fn

# Trend's codification (first derivative)
train.apply_codifications([temporal_trend_fn])
test.apply_codifications([temporal_trend_fn])

# %% [markdown]
# # <font color=#cd0000> Preparación de los datos </font>

# %%
X_train = train.derived_data.drop(['TimeStamp', 'class'], axis=1)
X_test = test.derived_data.drop(['TimeStamp', 'class'], axis=1)

y_train = train.derived_data['class'].to_numpy()
y_test = test.derived_data['class'].to_numpy()

# %% [markdown]
# ## <font color=#cd0000> Técnicas de balanceo </font>

# %% [markdown]
# ### <font color=#cd0000> Asignación de pesos a las clases </font>

# %%
import numpy as np
from sklearn.utils import compute_class_weight

class_weights = compute_class_weight(
    'balanced', classes=np.unique(y_train), y=y_train)
class_weights = {'abnormal': class_weights[0], 'normal': class_weights[1]}

# %% [markdown]
# # <font color=#cd0000> Diseño de la topología del bosque </font>
# - Número de árboles inicial recomendado
# - Número de símbolos inicial recomendado
# - Número de árboles del segundo RandomForest recomendado

# %% [markdown]
# ## <font color=#cd0000> Entrenamiento </font>

# %%
from smts_implementation.smts import SMTS

clf = SMTS(
    j_ins=100,
    n_symbols=200,
    class_weight=class_weights,
    random_state=SEED
)
clf.fit(X_train, y_train)

# %% [markdown]
# ## <font color=#cd0000> Clasificación </font>

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = clf.predict(X_test)
y_true = X_test.assign(class_name=y_test).groupby('id')\
    .first()['class_name'].to_numpy()

print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# [[121  22]
#  [ 31  25]]
#               precision    recall  f1-score   support
#
#     abnormal       0.80      0.85      0.82       143
#       normal       0.53      0.45      0.49        56
#
#     accuracy                           0.73       199
#    macro avg       0.66      0.65      0.65       199
# weighted avg       0.72      0.73      0.73       199

# %% [markdown]
# ## <font color=#cd0000> Discusión de los resultados </font>
# - Vamos a estudiar diferentes rangos de hiper-parámetros interesantes que podrían darnos alguna pista sobre el rango en el que buscar el mejor clasificador de este tipo:
#   - Para un `j_ins` pequeño (10) y un `n_symbols` pequeño (10) observamos unos resultados algo peores a los de aplicar únicamente la ``Codificación Simbólica``:
#     ```
#     Confusion matrix:
#     [[122  21]
#      [ 31  25]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#         abnormal       0.80      0.85      0.82       143
#           normal       0.54      0.45      0.49        56
#
#         accuracy                           0.74       199
#        macro avg       0.67      0.65      0.66       199
#     weighted avg       0.73      0.74      0.73       199
#     ```
#   - Para un `j_ins` pequeño (10) y un `n_symbols` grande (200) observamos una ligera mejoría, probemos a variar el `j_ins`:
#     ```
#     Confusion matrix:
#     [[125  18]
#      [ 31  25]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#         abnormal       0.80      0.87      0.84       143
#           normal       0.58      0.45      0.51        56
#
#         accuracy                           0.75       199
#        macro avg       0.69      0.66      0.67       199
#     weighted avg       0.74      0.75      0.74       199
#     ```
#   - Para un `j_ins` grande (200) y un `n_symbols` grande (200) observamos resultados similares a los anteriores lo que nos da alguna pista de que no va a cambiar mucho:
#     ```
#     Confusion matrix:
#     [[125  18]
#      [ 31  25]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#         abnormal       0.80      0.87      0.84       143
#           normal       0.58      0.45      0.51        56
#
#         accuracy                           0.75       199
#        macro avg       0.69      0.66      0.67       199
#     weighted avg       0.74      0.75      0.74       199
#     ```
#   - Para un `j_ins` intermedio (100) y un `n_symbols` grande (200) observamos que los resultados empeoran pero no significativamente por lo que no parece existir un rango ideal en nuestro espacio de búsqueda:
#     ```
#     Confusion matrix:
#     [[121  22]
#      [ 31  25]]
#
#     Classification report:
#                     precision    recall  f1-score   support
#
#         abnormal       0.80      0.85      0.82       143
#           normal       0.53      0.45      0.49        56
#
#         accuracy                           0.73       199
#        macro avg       0.66      0.65      0.65       199
#     weighted avg       0.72      0.73      0.73       199
#     ```

# %% [markdown]
# ## <font color=#cd0000> Conclusiones </font>
# - Como podemos observar la influencia de añadir la tendencia no parece obtener resultados mucho mejores que con, únicamente, utilizar la codificación simbólica en este caso.
#   - Quizás en la búsqueda de hiper-parámetros aleatoria nos llevemos alguna sorpresa.
# - Parece que, como en otros estudios, sería más interesante profundizar en los rangos:
#   - `j_ins`: [TODO]
#   - `n_symbols`: [TODO]

# %% [markdown]
# # <font color=#cd0000> Randomized Search </font>
# - Búsqueda de hiper-parámetros aleatoria con SMTS maximizando ``macro avg f1-score``

# %% [markdown]
# ## <font color=#cd0000> Rangos de búsqueda </font>
# - Como vimos anteriormente los rangos de búsqueda aleatoria de los mejores hiper-parámetros serán los siguientes

# %%
J_INS_RANGE = range(10, 200)
N_SYMBOLS_RANGE = range(10, 200)

# %%
import random
import pickle
import utils.constants as cs
from smts_implementation.smts import SMTS
from utils.classifier_utils import (windowed_cross_val,
                                    compute_classification_reports_means)
from utils.plot_utils import pretty_print_classification_report_dict


def smts_randomized_search_cv(
        windowed_series,
        relation_with_series,
        prefix,
        class_weights,
        cv=5):
    global PKL_DIR
    all_clf_used = {}

    n_samples = 5
    j_ins_list = random.sample(list(J_INS_RANGE), n_samples)
    n_symbols_list = random.sample(list(N_SYMBOLS_RANGE), n_samples)

    best_hyp_params = None
    best_score = 0
    for j_ins in j_ins_list:
        for n_symbols in n_symbols_list:
            clf = SMTS(
                j_ins=j_ins,
                n_symbols=n_symbols,
                class_weight=class_weights,
                random_state=SEED
            )

            reports = windowed_cross_val(
                clf,
                windowed_series,
                relation_with_series,
                estimator_type=cs.ESTIMATOR_SMTS,
                cv=cv,
                drop_columns=['class'],
                seed=SEED
            )
            mean_report = compute_classification_reports_means(reports)
            all_clf_used[(j_ins, n_symbols)] = mean_report

            if mean_report['macro avg']['f1-score'][0] >= best_score:
                best_score = mean_report['macro avg']['f1-score'][0]
                best_hyp_params = (j_ins, n_symbols)
                best_report = mean_report

            print("\t\t--------------ACTUAL BEST: J_ins={}; N_symbols={}--------------"
                  .format(best_hyp_params[0], best_hyp_params[1]))
            pretty_print_classification_report_dict(best_report)
            print("\t\t--------------ITERATION: J_ins={}; N_symbols={}--------------"
                  .format(j_ins, n_symbols))
            pretty_print_classification_report_dict(mean_report)

    with open(PKL_DIR + prefix, 'wb') as file:
        pickle.dump(all_clf_used, file)

    return best_hyp_params, best_report

# %%
smts_randomized_search_cv(
    train.derived_data,
    train.derived_data_windows_per_serie,
    PKL_NAME,
    class_weights,
    cv=5
)
# Out:
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=157--------------
# Accuracy: 0.7565164082814917 +/- 0.05740092900646482
# abnormal:
# 	precision: 0.7959579908411945 +/- 0.072639884577528
# 	recall: 0.8855717532938598 +/- 0.06044726526631393
# 	f1-score: 0.8356790032247696 +/- 0.048944308546007745
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6361904761904762 +/- 0.1348754359398132
# 	recall: 0.4524475524475525 +/- 0.09771610704694289
# 	f1-score: 0.5112046783625731 +/- 0.07258726412229269
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7160742335158352 +/- 0.06617897179600786
# 	recall: 0.6690096528707061 +/- 0.048159412465898624
# 	f1-score: 0.6734418407936713 +/- 0.05397882176888157
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7580397000435882 +/- 0.05860986256583928
# 	recall: 0.7565164082814917 +/- 0.05740092900646482
# 	f1-score: 0.7434429610180948 +/- 0.061981960295226075
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=186; N_symbols=157--------------
# Accuracy: 0.7565164082814917 +/- 0.05740092900646482
# abnormal:
# 	precision: 0.7959579908411945 +/- 0.072639884577528
# 	recall: 0.8855717532938598 +/- 0.06044726526631393
# 	f1-score: 0.8356790032247696 +/- 0.048944308546007745
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6361904761904762 +/- 0.1348754359398132
# 	recall: 0.4524475524475525 +/- 0.09771610704694289
# 	f1-score: 0.5112046783625731 +/- 0.07258726412229269
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7160742335158352 +/- 0.06617897179600786
# 	recall: 0.6690096528707061 +/- 0.048159412465898624
# 	f1-score: 0.6734418407936713 +/- 0.05397882176888157
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7580397000435882 +/- 0.05860986256583928
# 	recall: 0.7565164082814917 +/- 0.05740092900646482
# 	f1-score: 0.7434429610180948 +/- 0.061981960295226075
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=51--------------
# Accuracy: 0.760996346400711 +/- 0.08705571092498275
# abnormal:
# 	precision: 0.8070951749400026 +/- 0.09348400489419767
# 	recall: 0.8677355101251217 +/- 0.07559772190811954
# 	f1-score: 0.8342385356476573 +/- 0.07409902792641809
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.626010101010101 +/- 0.14288645537160038
# 	recall: 0.5078321678321678 +/- 0.15170564320761357
# 	f1-score: 0.5459138041181385 +/- 0.1125968298602081
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7165526379750518 +/- 0.09302404432765554
# 	recall: 0.6877838389786449 +/- 0.09050616706142095
# 	f1-score: 0.6900761698828978 +/- 0.08659350192647702
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7610525686840232 +/- 0.09341791277083994
# 	recall: 0.760996346400711 +/- 0.08705571092498275
# 	f1-score: 0.7522953259911319 +/- 0.09025255437789918
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=186; N_symbols=51--------------
# Accuracy: 0.760996346400711 +/- 0.08705571092498275
# abnormal:
# 	precision: 0.8070951749400026 +/- 0.09348400489419767
# 	recall: 0.8677355101251217 +/- 0.07559772190811954
# 	f1-score: 0.8342385356476573 +/- 0.07409902792641809
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.626010101010101 +/- 0.14288645537160038
# 	recall: 0.5078321678321678 +/- 0.15170564320761357
# 	f1-score: 0.5459138041181385 +/- 0.1125968298602081
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7165526379750518 +/- 0.09302404432765554
# 	recall: 0.6877838389786449 +/- 0.09050616706142095
# 	f1-score: 0.6900761698828978 +/- 0.08659350192647702
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7610525686840232 +/- 0.09341791277083994
# 	recall: 0.760996346400711 +/- 0.08705571092498275
# 	f1-score: 0.7522953259911319 +/- 0.09025255437789918
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=51--------------
# Accuracy: 0.760996346400711 +/- 0.08705571092498275
# abnormal:
# 	precision: 0.8070951749400026 +/- 0.09348400489419767
# 	recall: 0.8677355101251217 +/- 0.07559772190811954
# 	f1-score: 0.8342385356476573 +/- 0.07409902792641809
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.626010101010101 +/- 0.14288645537160038
# 	recall: 0.5078321678321678 +/- 0.15170564320761357
# 	f1-score: 0.5459138041181385 +/- 0.1125968298602081
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7165526379750518 +/- 0.09302404432765554
# 	recall: 0.6877838389786449 +/- 0.09050616706142095
# 	f1-score: 0.6900761698828978 +/- 0.08659350192647702
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7610525686840232 +/- 0.09341791277083994
# 	recall: 0.760996346400711 +/- 0.08705571092498275
# 	f1-score: 0.7522953259911319 +/- 0.09025255437789918
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=186; N_symbols=41--------------
# Accuracy: 0.7458743951811988 +/- 0.07809618826826313
# abnormal:
# 	precision: 0.7971196419014256 +/- 0.07853016152749524
# 	recall: 0.853942406676846 +/- 0.07537296814444863
# 	f1-score: 0.8232219066045154 +/- 0.06899967710416413
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.5936507936507937 +/- 0.15136899430326528
# 	recall: 0.48321678321678324 +/- 0.06653874632925613
# 	f1-score: 0.5245604206594918 +/- 0.07591483801729754
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.6953852177761096 +/- 0.08948242778548769
# 	recall: 0.6685795949468146 +/- 0.06189686176053082
# 	f1-score: 0.6738911636320035 +/- 0.06767689765835642
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7449336224676685 +/- 0.08418718027672957
# 	recall: 0.7458743951811988 +/- 0.07809618826826313
# 	f1-score: 0.7394413712044597 +/- 0.07894578696878199
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=186; N_symbols=199--------------
# Accuracy: 0.7513814555149599 +/- 0.062323360539577
# abnormal:
# 	precision: 0.7847519550342131 +/- 0.08000199634386135
# 	recall: 0.9007190183709988 +/- 0.04421761386304908
# 	f1-score: 0.8357770482010303 +/- 0.048683725432370664
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.631031746031746 +/- 0.12156087822627129
# 	recall: 0.40578088578088584 +/- 0.09910257438276907
# 	f1-score: 0.4779560308972074 +/- 0.07251161233300928
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7078918505329795 +/- 0.06521851613679266
# 	recall: 0.6532499520759423 +/- 0.048070962168666624
# 	f1-score: 0.6568665395491188 +/- 0.05916593891447652
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.748127959582096 +/- 0.06659282636857698
# 	recall: 0.7513814555149599 +/- 0.062323360539577
# 	f1-score: 0.7318990611369676 +/- 0.07479256217391492
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=198; N_symbols=157--------------
# Accuracy: 0.7561312991672426 +/- 0.07131785077034677
# abnormal:
# 	precision: 0.796557519559548 +/- 0.08440291636634233
# 	recall: 0.8855717532938598 +/- 0.06044726526631393
# 	f1-score: 0.8356776556776557 +/- 0.05669241076374562
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6311111111111111 +/- 0.14561915489249666
# 	recall: 0.4563170163170163 +/- 0.13427241954348504
# 	f1-score: 0.5116030271757825 +/- 0.10091113484453393
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7138343153353295 +/- 0.0826569043338854
# 	recall: 0.670944384805438 +/- 0.07192032065689101
# 	f1-score: 0.673640341426719 +/- 0.07427202598524546
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7566522191494591 +/- 0.07725499592707301
# 	recall: 0.7561312991672426 +/- 0.07131785077034677
# 	f1-score: 0.7426858872094091 +/- 0.07779785112830087
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=198; N_symbols=51--------------
# Accuracy: 0.7359963464007109 +/- 0.0698463608550203
# abnormal:
# 	precision: 0.7811904761904762 +/- 0.07804009558729649
# 	recall: 0.8695346105748969 +/- 0.06077489391609707
# 	f1-score: 0.8212248199121003 +/- 0.06007717411647755
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.5805555555555556 +/- 0.139553963189783
# 	recall: 0.41631701631701634 +/- 0.0702455974095386
# 	f1-score: 0.474702442380461 +/- 0.0594589729222828
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.6808730158730159 +/- 0.07983182816187365
# 	recall: 0.6429258134459566 +/- 0.05113018144978729
# 	f1-score: 0.6479636311462805 +/- 0.05684054231124896
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7301097612079239 +/- 0.07874618938013751
# 	recall: 0.7359963464007109 +/- 0.0698463608550203
# 	f1-score: 0.722735760260176 +/- 0.07405267860785737
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=198; N_symbols=41--------------
# Accuracy: 0.7661375530759356 +/- 0.07311342603535784
# abnormal:
# 	precision: 0.8056913455037188 +/- 0.0842002009247859
# 	recall: 0.8851268144729479 +/- 0.04951389111611745
# 	f1-score: 0.8413310010983199 +/- 0.057951632154226294
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6364285714285715 +/- 0.1387696540343976
# 	recall: 0.4898834498834499 +/- 0.11900542885917613
# 	f1-score: 0.5427141382868936 +/- 0.09937759211736064
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.721059958466145 +/- 0.08348436683432146
# 	recall: 0.687505132178199 +/- 0.07126396008063751
# 	f1-score: 0.6920225696926069 +/- 0.075473337262924
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7641891400130293 +/- 0.08015184762038281
# 	recall: 0.7661375530759356 +/- 0.07311342603535784
# 	f1-score: 0.7557457389636698 +/- 0.08039930692548222
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=198; N_symbols=50--------------
# Accuracy: 0.7564007109706725 +/- 0.06951252652564904
# abnormal:
# 	precision: 0.8064918381145562 +/- 0.076237506641952
# 	recall: 0.864437159300534 +/- 0.06075457065425885
# 	f1-score: 0.8323256491640949 +/- 0.05590244815861673
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6112265512265511 +/- 0.15546499758785956
# 	recall: 0.5032167832167833 +/- 0.1034346819707866
# 	f1-score: 0.5410267379679146 +/- 0.09477890215037728
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7088591946705536 +/- 0.08585427295892178
# 	recall: 0.6838269712586587 +/- 0.06806197838334282
# 	f1-score: 0.6866761935660047 +/- 0.0711369180553227
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7583429242581248 +/- 0.07437615671468381
# 	recall: 0.7564007109706725 +/- 0.06951252652564904
# 	f1-score: 0.7499263531354021 +/- 0.0725409609535601
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=198; N_symbols=199--------------
# Accuracy: 0.7561375530759357 +/- 0.07462120427965803
# abnormal:
# 	precision: 0.7944413455037187 +/- 0.07909000638265234
# 	recall: 0.8848969294154767 +/- 0.054335357700343104
# 	f1-score: 0.8354187853394622 +/- 0.058909042245703334
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6214285714285714 +/- 0.15652435600788633
# 	recall: 0.4517016317016317 +/- 0.09611289938348139
# 	f1-score: 0.5149948400412796 +/- 0.10069333142430828
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7079349584661451 +/- 0.09228333227329764
# 	recall: 0.6682992805585541 +/- 0.06721595288083793
# 	f1-score: 0.675206812690371 +/- 0.07638219120437738
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7515328900130293 +/- 0.08235359188305554
# 	recall: 0.7561375530759357 +/- 0.07462120427965803
# 	f1-score: 0.7440193712198788 +/- 0.08073592502166606
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=35; N_symbols=157--------------
# Accuracy: 0.7659963464007109 +/- 0.08554959579476136
# abnormal:
# 	precision: 0.8008963585434173 +/- 0.09000473815403096
# 	recall: 0.8902242657473106 +/- 0.07139265936608155
# 	f1-score: 0.8408746230732731 +/- 0.06988983691824763
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6622222222222223 +/- 0.1635410621597698
# 	recall: 0.47449883449883445 +/- 0.12641673602662232
# 	f1-score: 0.5370278637770898 +/- 0.10245752908136282
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7315592903828196 +/- 0.10050119770907556
# 	recall: 0.6823615501230726 +/- 0.07785780170251956
# 	f1-score: 0.6889512434251813 +/- 0.08252489664442075
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7667611092471396 +/- 0.09352866774400097
# 	recall: 0.7659963464007109 +/- 0.08554959579476136
# 	f1-score: 0.7535442975041996 +/- 0.09040225605822118
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=35; N_symbols=51--------------
# Accuracy: 0.7667858200849216 +/- 0.045757545387657604
# abnormal:
# 	precision: 0.8050533367468852 +/- 0.06260788606793094
# 	recall: 0.8851268144729479 +/- 0.04951389111611745
# 	f1-score: 0.8414613583138173 +/- 0.04252257166389389
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6411616161616162 +/- 0.12374355787473715
# 	recall: 0.4811655011655011 +/- 0.07030952218485399
# 	f1-score: 0.5386520600142891 +/- 0.05210085233281659
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7231074764542506 +/- 0.05616536611018273
# 	recall: 0.6831461578192245 +/- 0.035056976967790754
# 	f1-score: 0.6900567091640533 +/- 0.03783290537012235
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.765813192383819 +/- 0.04827956496920834
# 	recall: 0.7667858200849216 +/- 0.045757545387657604
# 	f1-score: 0.7567044835316648 +/- 0.04833898425617344
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=35; N_symbols=41--------------
# Accuracy: 0.760996346400711 +/- 0.08263592925994215
# abnormal:
# 	precision: 0.8039324116743473 +/- 0.09096787162960876
# 	recall: 0.8764311622990348 +/- 0.06148872269497342
# 	f1-score: 0.8364301786288285 +/- 0.06735583253306038
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6288888888888888 +/- 0.1406510435417481
# 	recall: 0.49268065268065264 +/- 0.1287553018106878
# 	f1-score: 0.5393808049535604 +/- 0.10373363358601259
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.716410650281618 +/- 0.08990803808026307
# 	recall: 0.6845559074898437 +/- 0.0787561613615899
# 	f1-score: 0.6879054917911944 +/- 0.08192052063561363
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.759795581100397 +/- 0.09007377188151426
# 	recall: 0.760996346400711 +/- 0.08263592925994215
# 	f1-score: 0.7509691341055068 +/- 0.08903848922664548
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=35; N_symbols=50--------------
# Accuracy: 0.7608743951811988 +/- 0.08290224826020123
# abnormal:
# 	precision: 0.8073949579831933 +/- 0.08945457860258978
# 	recall: 0.8695346105748969 +/- 0.06077489391609707
# 	f1-score: 0.8353533476777495 +/- 0.06730442882291075
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6203174603174604 +/- 0.14714345644644308
# 	recall: 0.5080652680652681 +/- 0.11916202471950729
# 	f1-score: 0.5484033613445377 +/- 0.10416589247175986
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7138562091503268 +/- 0.09338810014930568
# 	recall: 0.6887999393200824 +/- 0.07831350414474307
# 	f1-score: 0.6918783545111437 +/- 0.08261380095550303
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7599582124786762 +/- 0.09124389132579361
# 	recall: 0.7608743951811988 +/- 0.08290224826020123
# 	f1-score: 0.7531733289997888 +/- 0.08877359264369017
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=35; N_symbols=199--------------
# Accuracy: 0.756638359501004 +/- 0.06502115663838799
# abnormal:
# 	precision: 0.7977103884000436 +/- 0.08226752971789589
# 	recall: 0.8855717532938598 +/- 0.06044726526631393
# 	f1-score: 0.8360336690507468 +/- 0.052185009035797376
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6328571428571429 +/- 0.12662011317805905
# 	recall: 0.4570629370629371 +/- 0.15187716479758537
# 	f1-score: 0.5065882352941176 +/- 0.11660369879431288
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7152837656285932 +/- 0.06819181598904844
# 	recall: 0.6713173451783986 +/- 0.072371806465834
# 	f1-score: 0.6713109521724322 +/- 0.07633885361735847
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7581218514317979 +/- 0.06666974865146574
# 	recall: 0.756638359501004 +/- 0.06502115663838799
# 	f1-score: 0.7415014990275688 +/- 0.07460197795152436
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=112; N_symbols=157--------------
# Accuracy: 0.7566316118626772 +/- 0.07972045477863648
# abnormal:
# 	precision: 0.7812172671349535 +/- 0.08509907415583504
# 	recall: 0.9118083124336449 +/- 0.05504373791387197
# 	f1-score: 0.8393782248217733 +/- 0.06243346697382528
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6525396825396825 +/- 0.13175406362971429
# 	recall: 0.3873659673659674 +/- 0.14034511099666516
# 	f1-score: 0.4700980392156862 +/- 0.12815041863463505
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.716878474837318 +/- 0.08688835681921976
# 	recall: 0.6495871398998061 +/- 0.07621746571695208
# 	f1-score: 0.6547381320187297 +/- 0.08792087059224613
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7489081981764024 +/- 0.08494515389757537
# 	recall: 0.7566316118626772 +/- 0.07972045477863648
# 	f1-score: 0.7325412949259393 +/- 0.09046246316038663
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=112; N_symbols=51--------------
# Accuracy: 0.7667858200849216 +/- 0.06398244259094481
# abnormal:
# 	precision: 0.8160426929392447 +/- 0.08219383348118105
# 	recall: 0.8731328114744471 +/- 0.05767681747439934
# 	f1-score: 0.8402208847829709 +/- 0.04941292818000884
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6343434343434343 +/- 0.14379666856225531
# 	recall: 0.526013986013986 +/- 0.14966368151843362
# 	f1-score: 0.5561095834214693 +/- 0.10476911760679661
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7251930636413395 +/- 0.07481267572415129
# 	recall: 0.6995733987442166 +/- 0.0765350619688573
# 	f1-score: 0.69816523410222 +/- 0.07249873396610997
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7729648822098802 +/- 0.0663075270169109
# 	recall: 0.7667858200849216 +/- 0.06398244259094481
# 	f1-score: 0.7589622665011799 +/- 0.06975612594804886
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=112; N_symbols=41--------------
# Accuracy: 0.7558743951811987 +/- 0.08265305026681123
# abnormal:
# 	precision: 0.8001138519924099 +/- 0.09197650003780206
# 	recall: 0.8782302627488099 +/- 0.04984265397525753
# 	f1-score: 0.8347482447475463 +/- 0.06285604151359425
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6114285714285714 +/- 0.14942705729637779
# 	recall: 0.47655011655011653 +/- 0.13801475639850008
# 	f1-score: 0.5236828644501279 +/- 0.1193461866766279
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7057712117104906 +/- 0.09563511494400695
# 	recall: 0.6773901896494633 +/- 0.08232642717336437
# 	f1-score: 0.679215554598837 +/- 0.08919555126605003
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7524630363663523 +/- 0.09359629014102584
# 	recall: 0.7558743951811987 +/- 0.08265305026681123
# 	f1-score: 0.744421278258856 +/- 0.09345776222111994
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=112; N_symbols=50--------------
# Accuracy: 0.7507331885059741 +/- 0.09075311969805303
# abnormal:
# 	precision: 0.798423645320197 +/- 0.09850041358083021
# 	recall: 0.8695346105748969 +/- 0.06077489391609707
# 	f1-score: 0.8298734385925272 +/- 0.0712811368659843
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6044444444444445 +/- 0.1501604080580103
# 	recall: 0.4793473193473193 +/- 0.14675932919148366
# 	f1-score: 0.5203331859059412 +/- 0.12030810365674781
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7014340448823206 +/- 0.10075560154791834
# 	recall: 0.6744409649611081 +/- 0.08842134657057986
# 	f1-score: 0.6751033122492341 +/- 0.09335410296395111
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7482799469092462 +/- 0.1024648640363072
# 	recall: 0.7507331885059741 +/- 0.09075311969805303
# 	f1-score: 0.7397059885124038 +/- 0.10027875574636168
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=112; N_symbols=199--------------
# Accuracy: 0.7562595042954477 +/- 0.0653864932042339
# abnormal:
# 	precision: 0.7953470787647652 +/- 0.07914571715119864
# 	recall: 0.8851268144729479 +/- 0.04951389111611745
# 	f1-score: 0.8356152044676636 +/- 0.05382704177754028
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.625 +/- 0.12850037229133754
# 	recall: 0.45449883449883444 +/- 0.09252645312329924
# 	f1-score: 0.5142930856553146 +/- 0.07139481185861625
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7101735393823825 +/- 0.0720874594352141
# 	recall: 0.6698128244858912 +/- 0.054042748306921184
# 	f1-score: 0.6749541450614892 +/- 0.05980661542348445
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7535587666992662 +/- 0.07145150127731964
# 	recall: 0.7562595042954477 +/- 0.0653864932042339
# 	f1-score: 0.7435506373778187 +/- 0.07240612098577873
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=176; N_symbols=157--------------
# Accuracy: 0.7665159145518581 +/- 0.0755794054513596
# abnormal:
# 	precision: 0.7969047619047619 +/- 0.08365109484599853
# 	recall: 0.8962309398296243 +/- 0.06134474267975577
# 	f1-score: 0.8419563492063492 +/- 0.06431007230088398
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6500432900432901 +/- 0.10555976808883458
# 	recall: 0.4514685314685315 +/- 0.1436593086718257
# 	f1-score: 0.5192375168690958 +/- 0.10682463344296488
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.723474025974026 +/- 0.07388410432679392
# 	recall: 0.6738497356490779 +/- 0.0757341418464433
# 	f1-score: 0.6805969330377225 +/- 0.07543701666568613
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7593782678596542 +/- 0.08130228221257918
# 	recall: 0.7665159145518581 +/- 0.0755794054513596
# 	f1-score: 0.7502040688579119 +/- 0.08126647383726004
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=186; N_symbols=50--------------
# Accuracy: 0.7775622922221125 +/- 0.03057904071774624
# abnormal:
# 	precision: 0.8098813496477568 +/- 0.0615642754450611
# 	recall: 0.9020731799998618 +/- 0.036229629849238096
# 	f1-score: 0.8510227156771559 +/- 0.0265034225553309
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6688888888888889 +/- 0.1116431705518264
# 	recall: 0.48396270396270397 +/- 0.09886708351454607
# 	f1-score: 0.5461570593149541 +/- 0.06602053283853164
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7393851192683228 +/- 0.033734457797484074
# 	recall: 0.6930179419812829 +/- 0.03655529894396573
# 	f1-score: 0.6985898874960549 +/- 0.03700598524305775
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7790192295884536 +/- 0.025801311838923667
# 	recall: 0.7775622922221125 +/- 0.03057904071774624
# 	f1-score: 0.7649042141624733 +/- 0.041374675664081664
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=176; N_symbols=51--------------
# Accuracy: 0.7656304927421743 +/- 0.08613025790976685
# abnormal:
# 	precision: 0.8073483102918587 +/- 0.08482342432389664
# 	recall: 0.8764311622990348 +/- 0.06148872269497342
# 	f1-score: 0.8392092574734811 +/- 0.06919835645160985
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.625 +/- 0.1546601211897228
# 	recall: 0.5006526806526806 +/- 0.10310710255607111
# 	f1-score: 0.55115113988179 +/- 0.11613895907512725
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7161741551459293 +/- 0.09994741829739764
# 	recall: 0.6885419214758578 +/- 0.0795275413193981
# 	f1-score: 0.6951801986776356 +/- 0.08880139437592294
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.76108308984242 +/- 0.09350360068682256
# 	recall: 0.7656304927421743 +/- 0.08613025790976685
# 	f1-score: 0.7578194950775454 +/- 0.09148463623059161
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=176; N_symbols=41--------------
# Accuracy: 0.7657524439616865 +/- 0.09948501466939305
# abnormal:
# 	precision: 0.8122077922077923 +/- 0.09643809136715238
# 	recall: 0.8693047255174257 +/- 0.0682843235372295
# 	f1-score: 0.8380959852682389 +/- 0.07691821131457599
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6238888888888889 +/- 0.17718303293626575
# 	recall: 0.5252680652680652 +/- 0.15370804000385244
# 	f1-score: 0.5626890756302523 +/- 0.1480271070365499
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7180483405483405 +/- 0.11716985987019518
# 	recall: 0.6972863953927455 +/- 0.10484732133732852
# 	f1-score: 0.7003925304492455 +/- 0.10926286667784037
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7640440969433268 +/- 0.10737484351843521
# 	recall: 0.7657524439616865 +/- 0.09948501466939305
# 	f1-score: 0.759197809467697 +/- 0.10491891868676036
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=176; N_symbols=41--------------
# Accuracy: 0.7657524439616865 +/- 0.09948501466939305
# abnormal:
# 	precision: 0.8122077922077923 +/- 0.09643809136715238
# 	recall: 0.8693047255174257 +/- 0.0682843235372295
# 	f1-score: 0.8380959852682389 +/- 0.07691821131457599
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6238888888888889 +/- 0.17718303293626575
# 	recall: 0.5252680652680652 +/- 0.15370804000385244
# 	f1-score: 0.5626890756302523 +/- 0.1480271070365499
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7180483405483405 +/- 0.11716985987019518
# 	recall: 0.6972863953927455 +/- 0.10484732133732852
# 	f1-score: 0.7003925304492455 +/- 0.10926286667784037
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7640440969433268 +/- 0.10737484351843521
# 	recall: 0.7657524439616865 +/- 0.09948501466939305
# 	f1-score: 0.759197809467697 +/- 0.10491891868676036
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=176; N_symbols=41--------------
# Accuracy: 0.7657524439616865 +/- 0.09948501466939305
# abnormal:
# 	precision: 0.8122077922077923 +/- 0.09643809136715238
# 	recall: 0.8693047255174257 +/- 0.0682843235372295
# 	f1-score: 0.8380959852682389 +/- 0.07691821131457599
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6238888888888889 +/- 0.17718303293626575
# 	recall: 0.5252680652680652 +/- 0.15370804000385244
# 	f1-score: 0.5626890756302523 +/- 0.1480271070365499
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7180483405483405 +/- 0.11716985987019518
# 	recall: 0.6972863953927455 +/- 0.10484732133732852
# 	f1-score: 0.7003925304492455 +/- 0.10926286667784037
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7640440969433268 +/- 0.10737484351843521
# 	recall: 0.7657524439616865 +/- 0.09948501466939305
# 	f1-score: 0.759197809467697 +/- 0.10491891868676036
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=176; N_symbols=50--------------
# Accuracy: 0.7515226621901847 +/- 0.06673996663491377
# abnormal:
# 	precision: 0.7957910906298002 +/- 0.08199505729890165
# 	recall: 0.880029363198585 +/- 0.04912241536419288
# 	f1-score: 0.832863770933675 +/- 0.050334221204472736
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6094444444444445 +/- 0.1503452816143683
# 	recall: 0.4563170163170163 +/- 0.13427241954348504
# 	f1-score: 0.5063373266926907 +/- 0.10546096174341708
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7026177675371222 +/- 0.08195117657097416
# 	recall: 0.6681731897578007 +/- 0.0736701027191585
# 	f1-score: 0.669600548813183 +/- 0.07484090855878743
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7509691467349134 +/- 0.07343182671001006
# 	recall: 0.7515226621901847 +/- 0.06673996663491377
# 	f1-score: 0.7389600231168688 +/- 0.07530963045586672
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ACTUAL BEST: J_ins=176; N_symbols=41--------------
# Accuracy: 0.7657524439616865 +/- 0.09948501466939305
# abnormal:
# 	precision: 0.8122077922077923 +/- 0.09643809136715238
# 	recall: 0.8693047255174257 +/- 0.0682843235372295
# 	f1-score: 0.8380959852682389 +/- 0.07691821131457599
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.6238888888888889 +/- 0.17718303293626575
# 	recall: 0.5252680652680652 +/- 0.15370804000385244
# 	f1-score: 0.5626890756302523 +/- 0.1480271070365499
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.7180483405483405 +/- 0.11716985987019518
# 	recall: 0.6972863953927455 +/- 0.10484732133732852
# 	f1-score: 0.7003925304492455 +/- 0.10926286667784037
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.7640440969433268 +/- 0.10737484351843521
# 	recall: 0.7657524439616865 +/- 0.09948501466939305
# 	f1-score: 0.759197809467697 +/- 0.10491891868676036
# 	support: 39.6 +/- 1.0198039027185568
# 		--------------ITERATION: J_ins=176; N_symbols=199--------------
# Accuracy: 0.7311120437115303 +/- 0.0776732806500857
# abnormal:
# 	precision: 0.7819311676208228 +/- 0.0865758989529115
# 	recall: 0.8628531126141998 +/- 0.07227736084914813
# 	f1-score: 0.8173540091058504 +/- 0.06363898542953944
# 	support: 28.2 +/- 2.7856776554368237
# normal:
# 	precision: 0.58 +/- 0.14352700094407322
# 	recall: 0.4237296037296037 +/- 0.12902963523519118
# 	f1-score: 0.468048552754435 +/- 0.10765956866653749
# 	support: 11.4 +/- 2.4166091947189146
# macro avg:
# 	precision: 0.6809655838104114 +/- 0.08511259279985604
# 	recall: 0.6432913581719018 +/- 0.07028372109676564
# 	f1-score: 0.6427012809301427 +/- 0.07860672526113935
# 	support: 39.6 +/- 1.0198039027185568
# weighted avg:
# 	precision: 0.730231728396938 +/- 0.08381542582208525
# 	recall: 0.7311120437115303 +/- 0.0776732806500857
# 	f1-score: 0.7165664515814468 +/- 0.08522005628442009
# 	support: 39.6 +/- 1.0198039027185568
# ((176, 41),
#  {'accuracy': (0.7657524439616865, 0.09948501466939305),
#   'abnormal': {'precision': (0.8122077922077923, 0.09643809136715238),
#    'recall': (0.8693047255174257, 0.0682843235372295),
#    'f1-score': (0.8380959852682389, 0.07691821131457599),
#    'support': (28.2, 2.7856776554368237)},
#   'normal': {'precision': (0.6238888888888889, 0.17718303293626575),
#    'recall': (0.5252680652680652, 0.15370804000385244),
#    'f1-score': (0.5626890756302523, 0.1480271070365499),
#    'support': (11.4, 2.4166091947189146)},
#   'macro avg': {'precision': (0.7180483405483405, 0.11716985987019518),
#    'recall': (0.6972863953927455, 0.10484732133732852),
#    'f1-score': (0.7003925304492455, 0.10926286667784037),
#    'support': (39.6, 1.0198039027185568)},
#   'weighted avg': {'precision': (0.7640440969433268, 0.10737484351843521),
#    'recall': (0.7657524439616865, 0.09948501466939305),
#    'f1-score': (0.759197809467697, 0.10491891868676036),
#    'support': (39.6, 1.0198039027185568)}})

# %% [markdown]
# # <font color=#cd0000> Randomized Search con múltiples ejecuciones en lugar de Validación Cruzada </font>
# - No llevaremos a cabo esta aproximación ya que tenemos datos suficientes como para ejecutar validación cruzada.

# %%
# Nothing to see here

# %% [markdown]
# # <font color=#cd0000> Análisis de resultados </font>
# - Según la búsqueda aleatoria de hiper-parámetros, la mejor combinación, es la de ``j_ins`` = 176 y ``n_symbols`` = 41:
#     ```
#         Accuracy: 0.7657524439616865 +/- 0.09948501466939305
#         abnormal:
#             precision: 0.8122077922077923 +/- 0.09643809136715238
#             recall: 0.8693047255174257 +/- 0.0682843235372295
#             f1-score: 0.8380959852682389 +/- 0.07691821131457599
#             support: 28.2 +/- 2.7856776554368237
#         normal:
#             precision: 0.6238888888888889 +/- 0.17718303293626575
#             recall: 0.5252680652680652 +/- 0.15370804000385244
#             f1-score: 0.5626890756302523 +/- 0.1480271070365499
#             support: 11.4 +/- 2.4166091947189146
#         macro avg:
#             precision: 0.7180483405483405 +/- 0.11716985987019518
#             recall: 0.6972863953927455 +/- 0.10484732133732852
#             f1-score: 0.7003925304492455 +/- 0.10926286667784037
#             support: 39.6 +/- 1.0198039027185568
#         weighted avg:
#             precision: 0.7640440969433268 +/- 0.10737484351843521
#             recall: 0.7657524439616865 +/- 0.09948501466939305
#             f1-score: 0.759197809467697 +/- 0.10491891868676036
#             support: 39.6 +/- 1.0198039027185568
#     ```
# - Ahora vamos a visualizar la evolución de los resultados (25 resultados) para observar cómo avanza nuestra métrica objetivo -> Macro Average F1-Score.

# %%
import pickle

all_reports = pickle.load(open(PKL_DIR + PKL_NAME, 'rb'))

# %%
from utils.plot_utils import plot_score

macro_avg_f1_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['macro avg']['f1-score'][0],
                   'std': all_reports[z]['macro avg']['f1-score'][1]}),
    all_reports
))

plot_score(
    [macro_avg_f1_scores],
    ('j_ins', 'n_symbols'),
    'SMTS',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Macro Average F1-Score'
)

# %%
abnormal_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['abnormal']['recall'][0],
                   'std': all_reports[z]['abnormal']['recall'][1]}),
    all_reports
))

normal_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['normal']['recall'][0],
                   'std': all_reports[z]['normal']['recall'][1]}),
    all_reports
))

plot_score(
    [abnormal_recall_scores],
    ('j_ins', 'n_symbols'),
    'SMTS',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Abnormal recall score'
)

plot_score(
    [normal_recall_scores],
    ('j_ins', 'n_symbols'),
    'SMTS',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Normal recall score'
)

# %% [markdown]
# # <font color=#cd0000> Evaluación sobre el conjunto de validación </font>
# - Vamos a llevar a cabo la evaluación final sobre el conjunto de validación (esto es lo que irá al apartado de ``Pruebas y Resultados`` de la memoria).

# %% [markdown]
# ## <font color=#cd0000> Entrenamiento </font>

# %%
from smts_implementation.smts import SMTS

clf = SMTS(
    j_ins=176,
    n_symbols=41,
    class_weight=class_weights,
    random_state=SEED
)
clf.fit(X_train, y_train)

# %% [markdown]
# ## <font color=#cd0000> Clasificación </font>

# %%
from sklearn.metrics import confusion_matrix, classification_report

y_pred = clf.predict(X_test)
y_true = X_test.assign(class_name=y_test).groupby('id')\
    .first()['class_name'].to_numpy()

print(confusion_matrix(y_true, y_pred))
print(classification_report(y_true, y_pred, zero_division=0))
# Out:
# [[123  20]
#  [ 31  25]]
#               precision    recall  f1-score   support
#
#     abnormal       0.80      0.86      0.83       143
#       normal       0.56      0.45      0.50        56
#
#     accuracy                           0.74       199
#    macro avg       0.68      0.65      0.66       199
# weighted avg       0.73      0.74      0.73       199

# %% [markdown]
# # <font color=#cd0000> Conclusiones </font>
# - No observamos una diferencia significativa con el mejor clasificador SMTS con SOLO codificación simbólica aunque, el entrenamiento, es algo más rápido dado el menor número de estimadores.
#   - También sigue siendo apreciable la mala clasificación de la clase minoritaria, pero tener en cuenta el orden de las secuencias de nuestros datos sigue siendo mejor que no tenerla en cuenta como ocurre con el clasificador RandomForest.
