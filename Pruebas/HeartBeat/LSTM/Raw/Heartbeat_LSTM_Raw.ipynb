# %% [markdown]
# # <font color=#cd0000> Propósito principal </font>
# - La idea de este librillo es preparar el entorno para realizar pruebas para cualquier Heartbeat a ser clasificado con sus series en bruto con LSTM
#
# ## <font color=#cd0000> Leyenda </font>
# - Los apartados titulados con el código de colores HEX: `#cd0000` serán apartados que tendrán todos los librillos, en concreto, aquellos especificados en el apartado `Síntesis de los criterios usados` del trabajo.
# - Los apartados titulados con el código de colores HEX: `#2451ff` serán apartados de conclusiones propias de este librillo resultado de aplicar un estudio personalizado para cada planteamiento.

# %% [markdown]
# # <font color=#cd0000> Prerrequisitos </font>
# ## <font color=#cd0000> Entorno de ejecución </font>
# - Cambiamos el directorio raíz del librillo para acceder cómodamente a las funciones de utilidad.

# %%
import os

os.chdir('../../../../')
os.listdir()
# Out:
# ['.git',
#  '.gitignore',
#  '.gitmodules',
#  'data',
#  'HeartBeat_tmp_test_data.pkl',
#  'HeartBeat_tmp_train_data.pkl',
#  'pkl',
#  'Pruebas',
#  'README.md',
#  'smts_implementation',
#  'utils']

# %% [markdown]
# ## <font color=#cd0000> Constantes y variables predefinidas </font>

# %%
HEARTBEAT_PATH = "data/heartbeat"

DATA_TO_SAVE = "HeartBeat"

PKL_DIR = "pkl/LSTM/Heartbeat/"
PKL_NAME = "heartbeat_LSTM_raw.pkl"

SEED = 1

# %% [markdown]
# # <font color=#cd0000> Carga del Dataset </font>

# %%
# from utils.load_data import import_heartbeat_dataset

# train, test = import_heartbeat_dataset(HEARTBEAT_PATH)

# %%
# import pickle

# pickle.dump(train, open(DATA_TO_SAVE + "_tmp_train_data.pkl", 'wb'))
# pickle.dump(test, open(DATA_TO_SAVE + "_tmp_test_data.pkl", 'wb'))

# %%
import pickle

train = pickle.load(open(DATA_TO_SAVE + "_tmp_train_data.pkl", 'rb'))
test = pickle.load(open(DATA_TO_SAVE + "_tmp_test_data.pkl", 'rb'))

# %%
train.reset_changes()
test.reset_changes()

# %% [markdown]
# # <font color=#cd0000> Preprocesamiento </font>

# %% [markdown]
# ## <font color=#cd0000> Eliminación de datos inválidos y valores atípicos </font>
# - Como ya anticipamos en el análisis en profundidad de este conjunto de datos eliminaremos todos los atributos dado su alto grado de correlación salvo los atributos: `signal_1`, `signal_10`, `signal_20`, `signal_30`, `signal_40`, `signal_50` y `signal_60`
# - Eliminaremos aquellos valores fuera de los percentiles 5 y 95.

# %% [markdown]
# ### <font color=#2451ff> Eliminación de atributos altamente correlacionados </font>

# %%
columns_to_remove = train.get_derived_data_columns()['attrs']
column_to_study = ['signal_1', 'signal_10', 'signal_20',
                   'signal_30', 'signal_40', 'signal_50', 'signal_60']

for col in columns_to_remove:
    if col in column_to_study:
        columns_to_remove.remove(col)

train.drop_derived_data_columns(columns_to_remove)
test.drop_derived_data_columns(columns_to_remove)
# Out:
#         id  TimeStamp  signal_1  signal_10  signal_20  signal_30  signal_40  \
# 0        0          0  0.004578   0.009483   0.003414   0.009437   0.008221
# 1        0          1  0.011682   0.013566   0.004089   0.012686   0.012927
# 2        0          2  0.017709   0.019086   0.011413   0.030151   0.039722
# 3        0          3  0.016318   0.017490   0.016408   0.044615   0.059496
# 4        0          4  0.011723   0.008481   0.008594   0.025718   0.030744
# ...    ...        ...       ...        ...        ...        ...        ...
# 83020  204        400  0.007057   0.001993   0.005595   0.003932   0.002723
# 83021  204        401  0.012607   0.002142   0.004760   0.000763   0.002429
# 83022  204        402  0.011410   0.004370   0.000505   0.000902   0.002300
# 83023  204        403  0.008735   0.003033   0.001830   0.001835   0.004181
# 83024  204        404  0.004821   0.001827   0.000664   0.000804   0.001529
#
#        signal_50  signal_60     class
# 0       0.030211   1.000400    normal
# 1       0.070100   0.673670    normal
# 2       0.100600   0.904520    normal
# 3       0.091279   1.322500    normal
# 4       0.024211   1.622600    normal
# ...          ...        ...       ...
# 83020   0.002055   0.353420  abnormal
# 83021   0.001636   0.349890  abnormal
# 83022   0.001022   0.264820  abnormal
# 83023   0.002472   0.130270  abnormal
# 83024   0.004270   0.082863  abnormal
#
# [83025 rows x 10 columns]

# %% [markdown]
# ### <font color=#2451ff> Eliminación de outliers </font>
# - El grado de outliers mínimo en, al menos, una dimensión para eliminar una serie temporal será del 80% (si más del 80% de los datos son anómalos descartamos la serie).
#   - A pesar de que esto pueda parecer muy grande debemos comprender que, la probabilidad con la que aparezca ruido en una de las dimensiones de una serie temporal multivariada, es muy alta (tenemos varias series temporales con ruido cada una).

# %%
train.remove_outliers(
    headers=train.get_derived_data_columns()['attrs'],
    outliers_limit=.8
)

test.remove_outliers(
    headers=test.get_derived_data_columns()['attrs'],
    outliers_limit=.8
)

# %%
import pandas as pd

# Remaining series
print("Train: Previous number of series: {}".format(
    len(pd.unique(train.original_data['id']))))
print("Train: Actual number of series: {}".format(
    len(pd.unique(train.derived_data['id']))))

print("Test: Previous number of series: {}".format(
    len(pd.unique(test.original_data['id']))))
print("Test: Actual number of series: {}".format(
    len(pd.unique(test.derived_data['id']))))
# Out:
# Train: Previous number of series: 204
# Train: Actual number of series: 198
# Test: Previous number of series: 205
# Test: Actual number of series: 199

# %% [markdown]
# ## <font color=#cd0000> Resoluciones a aplicar </font>
# - Como concluimos en el análisis en profundidad, mantendremos la resolución original.

# %%
# Nothing to see here

# %% [markdown]
# # <font color=#cd0000> División en ventanas </font>
# - Como concluimos en el análisis en profundidad no aplicaremos enventanado pues ya está preaplicado.

# %%
# Nothing to see here

# %% [markdown]
# # <font color=#cd0000> Codificación </font>
# - Series en bruto

# %%
# Nothing to see here

# %% [markdown]
# ## <font color=#cd0000> Normalización </font>

# %%
from utils.codifications import standardize_data

train.derived_data, test.derived_data = standardize_data(
    train.derived_data,
    test.derived_data,
    headers=train.get_derived_data_columns()['attrs']
)

# %% [markdown]
# ## <font color=#cd0000> Tensores entrada y salida de la red </font>

# %%
# All lengths must be equal
series_length = train.get_shortest_serie().shape[0]
n_dims = len(train.get_derived_data_columns()['attrs'])

(
    train.get_shortest_serie().shape[0],
    train.get_largest_serie().shape[0],
    test.get_shortest_serie().shape[0],
    test.get_largest_serie().shape[0]
)
# Out:
# (405, 405, 405, 405)

# %%
import pandas as pd

# This will determine the number of series of each split
train_n_series = pd.unique(train.derived_data['id']).shape[0]
test_n_series = pd.unique(test.derived_data['id']).shape[0]

(train_n_series, test_n_series)
# Out:
# (198, 199)

# %%
X_train, _ = train.transform_derived_data_into_X_y()
X_test, _ = test.transform_derived_data_into_X_y()

y_train = train.derived_data.groupby('id').first()['class'].to_numpy()
y_test = test.derived_data.groupby('id').first()['class'].to_numpy()

# %% [markdown]
# ## <font color=#cd0000> Técnicas de balanceo </font>

# %% [markdown]
# ### <font color=#cd0000> Asignación de pesos a las clases </font>

# %%
import numpy as np
from sklearn.utils import compute_class_weight

class_weights = compute_class_weight(
    'balanced', classes=np.unique(y_train), y=y_train)
class_weights = {0: class_weights[0], 1: class_weights[1]}

# %%
from utils.classifier_utils import apply_lstm_format
from sklearn.preprocessing import LabelEncoder

sequences_fragmenter = 1

enc = LabelEncoder()
enc.fit(y_train)

X_train, y_train = apply_lstm_format(
    X_train, y_train, train_n_series, series_length, sequences_fragmenter, enc)
X_test, y_test = apply_lstm_format(
    X_test, y_test, test_n_series, series_length, sequences_fragmenter, enc)

# %% [markdown]
# # <font color=#cd0000> Diseño de la topología de red </font>

# %%
import keras as k
from keras.models import Sequential
from keras.layers import LSTM, Dense

nn = Sequential()

# Number of initial dimensions
nn.add(LSTM(units=56, return_sequences=True, dropout=.2, recurrent_dropout=.2))
nn.add(LSTM(units=28, dropout=.2, recurrent_dropout=.2))
# Number of Heartbeat's classes
nn.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## <font color=#cd0000> Compilación de la red </font>

# %%
from keras.optimizers import RMSprop

metrics = [
    k.metrics.CategoricalAccuracy(name="ACC"),
    k.metrics.Precision(name='Prec'),
    k.metrics.Recall(name='Rec'),
    k.metrics.AUC(name='AUC')
]

nn.compile(optimizer=RMSprop(
    learning_rate=3e-4), loss='binary_crossentropy', metrics=metrics)

# %% [markdown]
# ## <font color=#cd0000> Visualización de resultados preliminares </font>

# %%
import matplotlib.pyplot as plt


def show_metrics(history):
    for metric in history.history.keys():
        if not metric.startswith('val_'):
            plt.plot(history.history[metric], label=metric)
            plt.plot(history.history[f'val_{metric}'], label=f'val_{metric}')
            plt.title(metric)
            plt.ylabel('')
            plt.xlabel('Epoch')
            plt.legend(loc="upper left")
            plt.show()

# %% [markdown]
# ## <font color=#cd0000> Entrenamiento del modelo </font>

# %%
import numpy as np
from keras import backend as K
from sklearn.metrics import confusion_matrix, classification_report

epochs = 100

history = nn.fit(X_train, y_train, epochs=epochs,
                 validation_data=(X_test, y_test),
                 class_weight=class_weights,
                 verbose=1)
nn.summary()
print('\n\n')

y_pred = nn.predict(X_test)
y_pred = y_pred > .5

show_metrics(history)

# %% [markdown]
# ## <font color=#cd0000> Clasificación </font>

# %%
y_real = enc.inverse_transform(y_test)
y_pred = y_pred.astype('int')
y_pred = enc.inverse_transform(y_pred)
print(confusion_matrix(y_real, y_pred))
print(classification_report(y_real, y_pred, zero_division=0))

# %% [markdown]
# ## <font color=#cd0000> Discusión de los resultados </font>
# - Dimensionalidad de entrada inicial -> 7 atributos
# - Vamos a estudiar diferentes rangos de hiper-parámetros que podrían darnos alguna pista sobre el rango en el que buscar el mejor clasificador de este tipo:
#   - Dado que las series son algo complejas convendría añadir algo de profundidad al modelo para adaptarlo a dicha complejidad, pero con el fin de probar diferentes arquitecturas empezaremos con una capa oculta que iremos aumentando de complejidad en función de su nº de neuronas:
#     - Para un `n_units` de 2 veces la dim_entrada (14) y un `learning_rate` rápido (1e-2) obtenemos resultados similares a los de RF y con gran sobreajuste así que probaremos a añadir un Dropout de 0.2:
#    ```
#    Confusion matrix:
#    [[97 46]
#     [37 19]]
#
#    Classification report:
#                   precision    recall  f1-score   support
#
#       abnormal       0.72      0.68      0.70       143
#         normal       0.29      0.34      0.31        56
#
#       accuracy                           0.58       199
#      macro avg       0.51      0.51      0.51       199
#   weighted avg       0.60      0.58      0.59       199
#    ```
#     - Para un `n_units` de 2 veces la dim_entrada (14) y un `learning_rate` rápido (1e-2) y un Dropout de 0.2 obtenemos resultados algo mejores pero mantenemos el sobreajuste, probaremos a decrementar la tasa de aprendizaje y a incrementar la complejidad de la red doblando el nº de neuronas:
#    ```
#    Confusion matrix:
#    [[102  41]
#     [ 35  21]]
#
#    Classification report:
#                   precision    recall  f1-score   support
#
#       abnormal       0.74      0.71      0.73       143
#         normal       0.34      0.38      0.36        56
#
#       accuracy                           0.62       199
#      macro avg       0.54      0.54      0.54       199
#   weighted avg       0.63      0.62      0.62       199
#    ```
#     - Para un `n_units` de 4 veces la dim_entrada (28), un `learning_rate` más lento (1e-3) y un Dropout de .2 obtenemos  resultados algo mejores, parece que aumentar la complejidad de la red funciona así que probaremos a añadir una segunda capa oculta con la mitad de neuronas ocultas que la anterior:
#    ```
#    Confusion matrix:
#    [[83 60]
#     [17 39]]
#
#    Classification report:
#                   precision    recall  f1-score   support
#
#       abnormal       0.83      0.58      0.68       143
#         normal       0.39      0.70      0.50        56
#
#       accuracy                           0.61       199
#      macro avg       0.61      0.64      0.59       199
#   weighted avg       0.71      0.61      0.63       199
#    ```
#
# - Probemos con 2 capas ocultas donde, la segunda, tendrá la mitad de neuronas que la primera:
#     - Para un `n_units_capa1` de 4 veces la dim_entrada (28), `n_units_capa2` de 14, un `learning_rate` más lento (1e-3) y Dropout en ambas capas (de 0.2) obtenemos una ligera mejora en los resultados, finalmente, probaremos a aumentar aún más la complejidad del modelo doblando el nº de neuronas y disminuyendo la tasa de aprendizaje:
#    ```
#    Confusion matrix:
#    [[88 55]
#     [14 42]]
#
#    Classification report:
#                   precision    recall  f1-score   support
#
#       abnormal       0.86      0.62      0.72       143
#         normal       0.43      0.75      0.55        56
#
#       accuracy                           0.65       199
#     macro avg       0.65      0.68      0.63       199
#   weighted avg       0.74      0.65      0.67       199
#    ```
#     - Para un `n_units_capa1` de 8 veces la dim_entrada (56), `n_units_capa2` de 28, un `learning_rate` más lento (5e-4) y Dropout en ambas capas (de 0.2) obtenemos unos mejores resultados:
#    ```
#    Confusion matrix:
#    [[108  35]
#     [ 23  33]]
#
#    Classification report:
#                   precision    recall  f1-score   support
#
#       abnormal       0.82      0.76      0.79       143
#         normal       0.49      0.59      0.53        56
#
#       accuracy                           0.71       199
#      macro avg       0.65      0.67      0.66       199
#   weighted avg       0.73      0.71      0.72       199
#    ```

# %% [markdown]
# ## <font color=#cd0000> Conclusiones </font>
# - Como podemos observar los resultados son algo mejores ya que la red mantiene información a un mayor plazo en sus memorias algo que no contemplaba un RandomForest
# - Los rangos orientativos de búsqueda podrían ser:
#   - `n_units_capa1`: [28, 56]
#   - `n_units_capa2` fijo a 28
#   - `learning_rate`: [1e-3, 8e-4, 7e-4, 5e-4, 1e-4]

# %% [markdown]
# # <font color=#cd0000> Randomized Search </font>
# - Búsqueda de hiper-parámetros aleatoria con LSTM maximizando ``macro avg f1-score``

# %% [markdown]
# ## <font color=#cd0000> Rangos de búsqueda </font>
# - Como vimos anteriormente los rangos de búsqueda aleatoria de los mejores hiper-parámetros serán los siguientes

# %%
N_UNITS_RANGE = range(28, 56)
LEARNING_RATE_CHOICES = [1e-3, 8e-4, 7e-4, 5e-4, 3e-4]

# %%
import random
import pickle
import utils.constants as cs
from utils.classifier_utils import (windowed_cross_val,
                                    compute_classification_reports_means)
from utils.plot_utils import pretty_print_classification_report_dict
from keras.layers import LSTM, Dense
from keras.optimizers import RMSprop


def lstm_randomized_search_cv(
        windowed_series,
        relation_with_series,
        prefix,
        cv=5,
        lstm_dict={}):
    global PKL_DIR
    all_clf_used = {}

    n_samples = 5
    units_list = random.sample(
        list(N_UNITS_RANGE), n_samples)
    learning_rate_list = random.sample(
        LEARNING_RATE_CHOICES, n_samples)

    best_hyp_params = None
    best_score = 0
    for units in units_list:
        for learning_rate in learning_rate_list:
            lstm_dict[cs.LSTM_HYP_PARAM_UNITS] = units
            lstm_dict[cs.LSTM_HYP_PARAM_LEARNING_RATE] = learning_rate
            reports = windowed_cross_val(
                None,
                windowed_series,
                relation_with_series,
                cv=cv,
                seed=SEED,
                drop_columns=['class'],
                estimator_type=cs.ESTIMATOR_LSTM,
                lstm_dict=lstm_dict
            )

            mean_report = compute_classification_reports_means(reports)
            all_clf_used[(units, learning_rate)] = mean_report

            if mean_report['macro avg']['f1-score'][0] >= best_score:
                best_score = mean_report['macro avg']['f1-score'][0]
                best_hyp_params = (units, learning_rate)
                best_report = mean_report

            print("\t\t--------------ACTUAL BEST: Units={}; Learning Rate={}--------------"
                  .format(best_hyp_params[0], best_hyp_params[1]))
            pretty_print_classification_report_dict(best_report)
            print("\t\t--------------ITERATION: Units={}; Learning Rate={}--------------"
                  .format(units, learning_rate))
            pretty_print_classification_report_dict(mean_report)

    with open(PKL_DIR + prefix, 'wb') as file:
        pickle.dump(all_clf_used, file)

    return best_hyp_params, best_report

# %%
# IMPORTANTE -> ALGUNOS DE LOS PARÁMETROS DEL MODELO SON FIJADOS EN EL MÉTODO lstm_build_model del módulo
# classifier_utils.py ante problemas a la hora de clonar modelos neuronales de Keras.

# Los parámetros fijados a fuego en el código son:
#   · Una segunda capa oculta con el nº de neuronas fijas a 28
#   · Las tasas de Dropout recurrentes y de la misma capa a 0.2

lstm_dict = {
    cs.LSTM_SERIES_LENGTH: series_length,
    cs.LSTM_SEQUENCES_FRAGMENTER: 1,
    cs.LSTM_FITTED_LABELS_ENCODER: enc,
    cs.LSTM_ARGMAX_FUNCTION: None,
    cs.LSTM_N_CLASSES: 2,
    cs.LSTM_CLASS_WEIGHTS: class_weights,
    cs.LSTM_HYP_PARAM_EPOCHS: 100
}

lstm_randomized_search_cv(
    train.derived_data,
    train.derived_data_windows_per_serie,
    PKL_NAME,
    cv=5,
    lstm_dict=lstm_dict
)

# %% [markdown]
# # <font color=#cd0000> Randomized Search con múltiples ejecuciones en lugar de Validación Cruzada </font>
# - En este caso ejecutaremos CV dado que tenemos suficientes series

# %%
# Nothing to see here

# %% [markdown]
# # <font color=#cd0000> Análisis de resultados </font>
# - Según la búsqueda aleatoria de hiper-parámetros, la mejor combinación, es la de ``n_units`` = 50 y ``learning_rate`` = 0.0003:
#     ```
#         Accuracy: 0.9851156973108193 +/- 0.019643247459062513
#         abnormal:
#             precision: 0.9804166666666667 +/- 0.02647063362378098
#             recall: 1.0 +/- 0.0
#             f1-score: 0.9899288451012589 +/- 0.013666546528114368
#             support: 28.2 +/- 2.7856776554368237
#         normal:
#             precision: 1.0 +/- 0.0
#             recall: 0.9442307692307692 +/- 0.06890951102757276
#             f1-score: 0.9700000000000001 +/- 0.037118429085533484
#             support: 11.4 +/- 2.4166091947189146
#         macro avg:
#             precision: 0.9902083333333334 +/- 0.01323531681189049
#             recall: 0.9721153846153847 +/- 0.034454755513786364
#             f1-score: 0.9799644225506295 +/- 0.025164402876360757
#             support: 39.6 +/- 1.0198039027185568
#         weighted avg:
#             precision: 0.9859263602251407 +/- 0.018436466145328553
#             recall: 0.9851156973108193 +/- 0.019643247459062513
#             f1-score: 0.9847471616941761 +/- 0.02012577000326144
#             support: 39.6 +/- 1.0198039027185568
#     ```
# - Ahora vamos a visualizar la evolución de los resultados (25 resultados) para observar cómo avanza nuestra métrica objetivo -> Macro Average F1-Score.

# %%
import pickle

all_reports = pickle.load(open(PKL_DIR + PKL_NAME, 'rb'))

# %%
from utils.plot_utils import plot_score

macro_avg_f1_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['macro avg']['f1-score'][0],
                   'std': all_reports[z]['macro avg']['f1-score'][1]}),
    all_reports
))

plot_score(
    [macro_avg_f1_scores],
    ('n_units', 'learning_rate'),
    'LSTM',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Macro Average F1-Score'
)

# %%
abnormal_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['abnormal']['recall'][0],
                   'std': all_reports[z]['abnormal']['recall'][1]}),
    all_reports
))

normal_recall_scores = dict(map(
    lambda z: (z, {'score': all_reports[z]['normal']['recall'][0],
                   'std': all_reports[z]['normal']['recall'][1]}),
    all_reports
))

plot_score(
    [abnormal_recall_scores],
    ('n_units', 'learning_rate'),
    'LSTM',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Abnormal recall score'
)

plot_score(
    [normal_recall_scores],
    ('n_units', 'learning_rate'),
    'LSTM',
    inverse=False,
    mode='score',
    in_same_graphic=True,
    accuracy_mode='accuracy',
    metric_name='Normal recall score'
)

# %% [markdown]
# ## <font color=#cd0000> Evaluación sobre el conjunto de validación </font>
# - Vamos a llevar a cabo la evaluación final sobre el conjunto de validación (esto es lo que irá al apartado de ``Pruebas y Resultados`` de la memoria).

# %% [markdown]
# ### <font color=#cd0000> Construcción del modelo </font>

# %%
import keras as k
from keras.models import Sequential
from keras.layers import LSTM, Dense

nn = Sequential()

# Number of initial dimensions
nn.add(LSTM(units=50, return_sequences=True, dropout=.2, recurrent_dropout=.2))
nn.add(LSTM(units=28, dropout=.2, recurrent_dropout=.2))
# Number of Heartbeat's classes
nn.add(Dense(1, activation='sigmoid'))

# %%
from keras.optimizers import RMSprop

metrics = [
    k.metrics.CategoricalAccuracy(name="ACC"),
    k.metrics.Precision(name='Prec'),
    k.metrics.Recall(name='Rec'),
    k.metrics.AUC(name='AUC')
]

nn.compile(optimizer=RMSprop(
    learning_rate=0.0003), loss='binary_crossentropy', metrics=metrics)

# %% [markdown]
# ### <font color=#cd0000> Entrenamiento </font>

# %%
import numpy as np
from keras import backend as K
from sklearn.metrics import confusion_matrix, classification_report

epochs = 100

history = nn.fit(X_train, y_train, epochs=epochs,
                 validation_data=(X_test, y_test))
nn.summary()
print('\n\n')

y_pred = nn.predict(X_test)
y_pred = y_pred > .5

show_metrics(history)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 465ms/step - loss: 0.6660 - ACC: 1.0000 - Prec: 0.3962 - Rec: 0.3684 - AUC: 0.6680 - val_loss: 0.6659 - val_ACC: 1.0000 - val_Prec: 0.3400 - val_Rec: 0.3036 - val_AUC: 0.5597
# Epoch 2/100
# 7/7 [==============================] - 2s 340ms/step - loss: 0.6297 - ACC: 1.0000 - Prec: 0.5366 - Rec: 0.3860 - AUC: 0.7120 - val_loss: 0.6457 - val_ACC: 1.0000 - val_Prec: 0.3256 - val_Rec: 0.2500 - val_AUC: 0.5609
# Epoch 3/100
# 7/7 [==============================] - 3s 463ms/step - loss: 0.6065 - ACC: 1.0000 - Prec: 0.5238 - Rec: 0.3860 - AUC: 0.6934 - val_loss: 0.6262 - val_ACC: 1.0000 - val_Prec: 0.3171 - val_Rec: 0.2321 - val_AUC: 0.5714
# Epoch 4/100
# 7/7 [==============================] - 3s 449ms/step - loss: 0.5751 - ACC: 1.0000 - Prec: 0.5263 - Rec: 0.3509 - AUC: 0.7083 - val_loss: 0.6063 - val_ACC: 1.0000 - val_Prec: 0.3784 - val_Rec: 0.2500 - val_AUC: 0.5836
# Epoch 5/100
# 7/7 [==============================] - 3s 457ms/step - loss: 0.5598 - ACC: 1.0000 - Prec: 0.5676 - Rec: 0.3684 - AUC: 0.6776 - val_loss: 0.5990 - val_ACC: 1.0000 - val_Prec: 0.3824 - val_Rec: 0.2321 - val_AUC: 0.5982
# Epoch 6/100
# 7/7 [==============================] - 3s 448ms/step - loss: 0.5509 - ACC: 1.0000 - Prec: 0.5556 - Rec: 0.3509 - AUC: 0.7067 - val_loss: 0.5880 - val_ACC: 1.0000 - val_Prec: 0.4333 - val_Rec: 0.2321 - val_AUC: 0.6168
# Epoch 7/100
# 7/7 [==============================] - 3s 446ms/step - loss: 0.5335 - ACC: 1.0000 - Prec: 0.6176 - Rec: 0.3684 - AUC: 0.7316 - val_loss: 0.5809 - val_ACC: 1.0000 - val_Prec: 0.4138 - val_Rec: 0.2143 - val_AUC: 0.6299
# Epoch 8/100
# 7/7 [==============================] - 3s 448ms/step - loss: 0.5315 - ACC: 1.0000 - Prec: 0.5806 - Rec: 0.3158 - AUC: 0.7309 - val_loss: 0.5750 - val_ACC: 1.0000 - val_Prec: 0.4444 - val_Rec: 0.2143 - val_AUC: 0.6442
# Epoch 9/100
# 7/7 [==============================] - 3s 443ms/step - loss: 0.5240 - ACC: 1.0000 - Prec: 0.6364 - Rec: 0.3684 - AUC: 0.7488 - val_loss: 0.5676 - val_ACC: 1.0000 - val_Prec: 0.4583 - val_Rec: 0.1964 - val_AUC: 0.6615
# Epoch 10/100
# 7/7 [==============================] - 3s 446ms/step - loss: 0.5189 - ACC: 1.0000 - Prec: 0.5806 - Rec: 0.3158 - AUC: 0.7528 - val_loss: 0.5561 - val_ACC: 1.0000 - val_Prec: 0.5200 - val_Rec: 0.2321 - val_AUC: 0.6889
# Epoch 11/100
# 7/7 [==============================] - 3s 444ms/step - loss: 0.5104 - ACC: 1.0000 - Prec: 0.5938 - Rec: 0.3333 - AUC: 0.7673 - val_loss: 0.5515 - val_ACC: 1.0000 - val_Prec: 0.5200 - val_Rec: 0.2321 - val_AUC: 0.6983
# Epoch 12/100
# 7/7 [==============================] - 3s 444ms/step - loss: 0.5121 - ACC: 1.0000 - Prec: 0.6129 - Rec: 0.3333 - AUC: 0.7579 - val_loss: 0.5439 - val_ACC: 1.0000 - val_Prec: 0.5000 - val_Rec: 0.2500 - val_AUC: 0.7065
# Epoch 13/100
# 7/7 [==============================] - 3s 445ms/step - loss: 0.5033 - ACC: 1.0000 - Prec: 0.5806 - Rec: 0.3158 - AUC: 0.7746 - val_loss: 0.5521 - val_ACC: 1.0000 - val_Prec: 0.5385 - val_Rec: 0.2500 - val_AUC: 0.7103
# Epoch 14/100
# 7/7 [==============================] - 3s 443ms/step - loss: 0.5015 - ACC: 1.0000 - Prec: 0.6250 - Rec: 0.3509 - AUC: 0.7728 - val_loss: 0.5501 - val_ACC: 1.0000 - val_Prec: 0.5600 - val_Rec: 0.2500 - val_AUC: 0.7196
# Epoch 15/100
# 7/7 [==============================] - 3s 444ms/step - loss: 0.5016 - ACC: 1.0000 - Prec: 0.6000 - Rec: 0.3158 - AUC: 0.7746 - val_loss: 0.5384 - val_ACC: 1.0000 - val_Prec: 0.5172 - val_Rec: 0.2679 - val_AUC: 0.7211
# Epoch 16/100
# 7/7 [==============================] - 3s 479ms/step - loss: 0.4876 - ACC: 1.0000 - Prec: 0.6000 - Rec: 0.3684 - AUC: 0.7936 - val_loss: 0.5314 - val_ACC: 1.0000 - val_Prec: 0.4848 - val_Rec: 0.2857 - val_AUC: 0.7255
# Epoch 17/100
# 7/7 [==============================] - 3s 453ms/step - loss: 0.5011 - ACC: 1.0000 - Prec: 0.6111 - Rec: 0.3860 - AUC: 0.7727 - val_loss: 0.5366 - val_ACC: 1.0000 - val_Prec: 0.4848 - val_Rec: 0.2857 - val_AUC: 0.7255
# Epoch 18/100
# 7/7 [==============================] - 3s 444ms/step - loss: 0.4897 - ACC: 1.0000 - Prec: 0.6286 - Rec: 0.3860 - AUC: 0.7899 - val_loss: 0.5313 - val_ACC: 1.0000 - val_Prec: 0.4848 - val_Rec: 0.2857 - val_AUC: 0.7243
# Epoch 19/100
# 7/7 [==============================] - 3s 450ms/step - loss: 0.4968 - ACC: 1.0000 - Prec: 0.6111 - Rec: 0.3860 - AUC: 0.7737 - val_loss: 0.5283 - val_ACC: 1.0000 - val_Prec: 0.4444 - val_Rec: 0.2857 - val_AUC: 0.7224
# Epoch 20/100
# 7/7 [==============================] - 3s 456ms/step - loss: 0.4904 - ACC: 1.0000 - Prec: 0.6216 - Rec: 0.4035 - AUC: 0.7850 - val_loss: 0.5317 - val_ACC: 1.0000 - val_Prec: 0.4286 - val_Rec: 0.3214 - val_AUC: 0.7172
# Epoch 21/100
# 7/7 [==============================] - 3s 459ms/step - loss: 0.4872 - ACC: 1.0000 - Prec: 0.6429 - Rec: 0.4737 - AUC: 0.7961 - val_loss: 0.5244 - val_ACC: 1.0000 - val_Prec: 0.4865 - val_Rec: 0.3214 - val_AUC: 0.7275
# Epoch 22/100
# 7/7 [==============================] - 3s 456ms/step - loss: 0.4839 - ACC: 1.0000 - Prec: 0.6389 - Rec: 0.4035 - AUC: 0.7932 - val_loss: 0.5247 - val_ACC: 1.0000 - val_Prec: 0.4706 - val_Rec: 0.2857 - val_AUC: 0.7316
# Epoch 23/100
# 7/7 [==============================] - 3s 446ms/step - loss: 0.4837 - ACC: 1.0000 - Prec: 0.5897 - Rec: 0.4035 - AUC: 0.7931 - val_loss: 0.5257 - val_ACC: 1.0000 - val_Prec: 0.4688 - val_Rec: 0.2679 - val_AUC: 0.7318
# Epoch 24/100
# 7/7 [==============================] - 3s 457ms/step - loss: 0.4878 - ACC: 1.0000 - Prec: 0.6667 - Rec: 0.4211 - AUC: 0.7841 - val_loss: 0.5260 - val_ACC: 1.0000 - val_Prec: 0.4474 - val_Rec: 0.3036 - val_AUC: 0.7160
# Epoch 25/100
# 7/7 [==============================] - 3s 443ms/step - loss: 0.4831 - ACC: 1.0000 - Prec: 0.6047 - Rec: 0.4561 - AUC: 0.7938 - val_loss: 0.5350 - val_ACC: 1.0000 - val_Prec: 0.4848 - val_Rec: 0.2857 - val_AUC: 0.7332
# Epoch 26/100
# 7/7 [==============================] - 3s 460ms/step - loss: 0.4779 - ACC: 1.0000 - Prec: 0.6316 - Rec: 0.4211 - AUC: 0.7981 - val_loss: 0.5314 - val_ACC: 1.0000 - val_Prec: 0.4000 - val_Rec: 0.2857 - val_AUC: 0.7119
# Epoch 27/100
# 7/7 [==============================] - 3s 452ms/step - loss: 0.4809 - ACC: 1.0000 - Prec: 0.6500 - Rec: 0.4561 - AUC: 0.8015 - val_loss: 0.5280 - val_ACC: 1.0000 - val_Prec: 0.4857 - val_Rec: 0.3036 - val_AUC: 0.7219
# Epoch 28/100
# 7/7 [==============================] - 3s 444ms/step - loss: 0.4769 - ACC: 1.0000 - Prec: 0.6154 - Rec: 0.4211 - AUC: 0.7998 - val_loss: 0.5305 - val_ACC: 1.0000 - val_Prec: 0.4857 - val_Rec: 0.3036 - val_AUC: 0.7255
# Epoch 29/100
# 7/7 [==============================] - 3s 449ms/step - loss: 0.4776 - ACC: 1.0000 - Prec: 0.6364 - Rec: 0.4912 - AUC: 0.7975 - val_loss: 0.5334 - val_ACC: 1.0000 - val_Prec: 0.4857 - val_Rec: 0.3036 - val_AUC: 0.7263
# Epoch 30/100
# 7/7 [==============================] - 3s 452ms/step - loss: 0.4785 - ACC: 1.0000 - Prec: 0.5897 - Rec: 0.4035 - AUC: 0.7959 - val_loss: 0.5269 - val_ACC: 1.0000 - val_Prec: 0.4146 - val_Rec: 0.3036 - val_AUC: 0.7114
# Epoch 31/100
# 7/7 [==============================] - 3s 463ms/step - loss: 0.4839 - ACC: 1.0000 - Prec: 0.6667 - Rec: 0.4912 - AUC: 0.7958 - val_loss: 0.5270 - val_ACC: 1.0000 - val_Prec: 0.4146 - val_Rec: 0.3036 - val_AUC: 0.7122
# Epoch 32/100
# 7/7 [==============================] - 3s 453ms/step - loss: 0.4661 - ACC: 1.0000 - Prec: 0.6750 - Rec: 0.4737 - AUC: 0.8185 - val_loss: 0.5266 - val_ACC: 1.0000 - val_Prec: 0.4103 - val_Rec: 0.2857 - val_AUC: 0.7121
# Epoch 33/100
# 7/7 [==============================] - 3s 448ms/step - loss: 0.4703 - ACC: 1.0000 - Prec: 0.6098 - Rec: 0.4386 - AUC: 0.8041 - val_loss: 0.5272 - val_ACC: 1.0000 - val_Prec: 0.4545 - val_Rec: 0.2679 - val_AUC: 0.7132
# Epoch 34/100
# 7/7 [==============================] - 3s 465ms/step - loss: 0.4702 - ACC: 1.0000 - Prec: 0.6923 - Rec: 0.4737 - AUC: 0.8106 - val_loss: 0.5516 - val_ACC: 1.0000 - val_Prec: 0.4483 - val_Rec: 0.2321 - val_AUC: 0.7296
# Epoch 35/100
# 7/7 [==============================] - 3s 462ms/step - loss: 0.4712 - ACC: 1.0000 - Prec: 0.6389 - Rec: 0.4035 - AUC: 0.8063 - val_loss: 0.5328 - val_ACC: 1.0000 - val_Prec: 0.4483 - val_Rec: 0.2321 - val_AUC: 0.7170
# Epoch 36/100
# 7/7 [==============================] - 3s 458ms/step - loss: 0.4729 - ACC: 1.0000 - Prec: 0.6250 - Rec: 0.4386 - AUC: 0.8055 - val_loss: 0.5314 - val_ACC: 1.0000 - val_Prec: 0.4545 - val_Rec: 0.2679 - val_AUC: 0.7133
# Epoch 37/100
# 7/7 [==============================] - 3s 453ms/step - loss: 0.4628 - ACC: 1.0000 - Prec: 0.6500 - Rec: 0.4561 - AUC: 0.8155 - val_loss: 0.5339 - val_ACC: 1.0000 - val_Prec: 0.4706 - val_Rec: 0.2857 - val_AUC: 0.7128
# Epoch 38/100
# 7/7 [==============================] - 3s 445ms/step - loss: 0.4655 - ACC: 1.0000 - Prec: 0.6842 - Rec: 0.4561 - AUC: 0.8094 - val_loss: 0.5575 - val_ACC: 1.0000 - val_Prec: 0.4516 - val_Rec: 0.2500 - val_AUC: 0.7280
# Epoch 39/100
# 7/7 [==============================] - 3s 447ms/step - loss: 0.4725 - ACC: 1.0000 - Prec: 0.6250 - Rec: 0.4386 - AUC: 0.8012 - val_loss: 0.5393 - val_ACC: 1.0000 - val_Prec: 0.4688 - val_Rec: 0.2679 - val_AUC: 0.7234
# Epoch 40/100
# 7/7 [==============================] - 3s 447ms/step - loss: 0.4624 - ACC: 1.0000 - Prec: 0.6757 - Rec: 0.4386 - AUC: 0.8136 - val_loss: 0.5582 - val_ACC: 1.0000 - val_Prec: 0.4815 - val_Rec: 0.2321 - val_AUC: 0.7232
# Epoch 41/100
# 7/7 [==============================] - 3s 450ms/step - loss: 0.4850 - ACC: 1.0000 - Prec: 0.6765 - Rec: 0.4035 - AUC: 0.7969 - val_loss: 0.5283 - val_ACC: 1.0000 - val_Prec: 0.4571 - val_Rec: 0.2857 - val_AUC: 0.7091
# Epoch 42/100
# 7/7 [==============================] - 3s 457ms/step - loss: 0.4619 - ACC: 1.0000 - Prec: 0.6389 - Rec: 0.4035 - AUC: 0.8155 - val_loss: 0.5288 - val_ACC: 1.0000 - val_Prec: 0.4571 - val_Rec: 0.2857 - val_AUC: 0.7095
# Epoch 43/100
# 7/7 [==============================] - 3s 440ms/step - loss: 0.4665 - ACC: 1.0000 - Prec: 0.6750 - Rec: 0.4737 - AUC: 0.8117 - val_loss: 0.6917 - val_ACC: 1.0000 - val_Prec: 0.5652 - val_Rec: 0.2321 - val_AUC: 0.6996
# Epoch 44/100
# 7/7 [==============================] - 3s 445ms/step - loss: 0.5033 - ACC: 1.0000 - Prec: 0.6765 - Rec: 0.4035 - AUC: 0.7987 - val_loss: 0.5362 - val_ACC: 1.0000 - val_Prec: 0.4667 - val_Rec: 0.2500 - val_AUC: 0.7241
# Epoch 45/100
# 7/7 [==============================] - 3s 453ms/step - loss: 0.4541 - ACC: 1.0000 - Prec: 0.6471 - Rec: 0.3860 - AUC: 0.8268 - val_loss: 0.5293 - val_ACC: 1.0000 - val_Prec: 0.4474 - val_Rec: 0.3036 - val_AUC: 0.7035
# Epoch 46/100
# 7/7 [==============================] - 3s 451ms/step - loss: 0.4486 - ACC: 1.0000 - Prec: 0.6923 - Rec: 0.4737 - AUC: 0.8351 - val_loss: 0.5801 - val_ACC: 1.0000 - val_Prec: 0.5172 - val_Rec: 0.2679 - val_AUC: 0.7232
# Epoch 47/100
# 7/7 [==============================] - 3s 454ms/step - loss: 0.4584 - ACC: 1.0000 - Prec: 0.6857 - Rec: 0.4211 - AUC: 0.8282 - val_loss: 0.6817 - val_ACC: 1.0000 - val_Prec: 0.6500 - val_Rec: 0.2321 - val_AUC: 0.6934
# Epoch 48/100
# 7/7 [==============================] - 3s 459ms/step - loss: 0.4934 - ACC: 1.0000 - Prec: 0.6571 - Rec: 0.4035 - AUC: 0.7882 - val_loss: 0.5286 - val_ACC: 1.0000 - val_Prec: 0.4516 - val_Rec: 0.2500 - val_AUC: 0.7146
# Epoch 49/100
# 7/7 [==============================] - 3s 454ms/step - loss: 0.4652 - ACC: 1.0000 - Prec: 0.6757 - Rec: 0.4386 - AUC: 0.8140 - val_loss: 0.5331 - val_ACC: 1.0000 - val_Prec: 0.4688 - val_Rec: 0.2679 - val_AUC: 0.7245
# Epoch 50/100
# 7/7 [==============================] - 3s 444ms/step - loss: 0.4516 - ACC: 1.0000 - Prec: 0.7059 - Rec: 0.4211 - AUC: 0.8266 - val_loss: 0.5422 - val_ACC: 1.0000 - val_Prec: 0.5357 - val_Rec: 0.2679 - val_AUC: 0.7298
# Epoch 51/100
# 7/7 [==============================] - 3s 443ms/step - loss: 0.4684 - ACC: 1.0000 - Prec: 0.7647 - Rec: 0.4561 - AUC: 0.8223 - val_loss: 0.5314 - val_ACC: 1.0000 - val_Prec: 0.5000 - val_Rec: 0.3036 - val_AUC: 0.7056
# Epoch 52/100
# 7/7 [==============================] - 3s 441ms/step - loss: 0.4587 - ACC: 1.0000 - Prec: 0.7273 - Rec: 0.4211 - AUC: 0.8267 - val_loss: 0.5303 - val_ACC: 1.0000 - val_Prec: 0.5000 - val_Rec: 0.3036 - val_AUC: 0.7078
# Epoch 53/100
# 7/7 [==============================] - 3s 447ms/step - loss: 0.4500 - ACC: 1.0000 - Prec: 0.7222 - Rec: 0.4561 - AUC: 0.8370 - val_loss: 0.5385 - val_ACC: 1.0000 - val_Prec: 0.5556 - val_Rec: 0.2679 - val_AUC: 0.7261
# Epoch 54/100
# 7/7 [==============================] - 3s 443ms/step - loss: 0.4534 - ACC: 1.0000 - Prec: 0.6765 - Rec: 0.4035 - AUC: 0.8264 - val_loss: 0.5308 - val_ACC: 1.0000 - val_Prec: 0.5312 - val_Rec: 0.3036 - val_AUC: 0.7148
# Epoch 55/100
# 7/7 [==============================] - 3s 455ms/step - loss: 0.4602 - ACC: 1.0000 - Prec: 0.6757 - Rec: 0.4386 - AUC: 0.8195 - val_loss: 0.5338 - val_ACC: 1.0000 - val_Prec: 0.5385 - val_Rec: 0.2500 - val_AUC: 0.7205
# Epoch 56/100
# 7/7 [==============================] - 3s 442ms/step - loss: 0.4543 - ACC: 1.0000 - Prec: 0.6774 - Rec: 0.3684 - AUC: 0.8249 - val_loss: 0.5316 - val_ACC: 1.0000 - val_Prec: 0.5172 - val_Rec: 0.2679 - val_AUC: 0.7100
# Epoch 57/100
# 7/7 [==============================] - 3s 442ms/step - loss: 0.4313 - ACC: 1.0000 - Prec: 0.7027 - Rec: 0.4561 - AUC: 0.8422 - val_loss: 0.5399 - val_ACC: 1.0000 - val_Prec: 0.5385 - val_Rec: 0.2500 - val_AUC: 0.7157
# Epoch 58/100
# 7/7 [==============================] - 3s 442ms/step - loss: 0.4574 - ACC: 1.0000 - Prec: 0.7273 - Rec: 0.4211 - AUC: 0.8219 - val_loss: 0.5391 - val_ACC: 1.0000 - val_Prec: 0.5000 - val_Rec: 0.2500 - val_AUC: 0.7084
# Epoch 59/100
# 7/7 [==============================] - 3s 440ms/step - loss: 0.4342 - ACC: 1.0000 - Prec: 0.7059 - Rec: 0.4211 - AUC: 0.8376 - val_loss: 0.5354 - val_ACC: 1.0000 - val_Prec: 0.5000 - val_Rec: 0.2321 - val_AUC: 0.7059
# Epoch 60/100
# 7/7 [==============================] - 3s 443ms/step - loss: 0.4414 - ACC: 1.0000 - Prec: 0.6970 - Rec: 0.4035 - AUC: 0.8285 - val_loss: 0.5446 - val_ACC: 1.0000 - val_Prec: 0.5333 - val_Rec: 0.2857 - val_AUC: 0.7005
# Epoch 61/100
# 7/7 [==============================] - 3s 442ms/step - loss: 0.4519 - ACC: 1.0000 - Prec: 0.7027 - Rec: 0.4561 - AUC: 0.8355 - val_loss: 0.6008 - val_ACC: 1.0000 - val_Prec: 0.5714 - val_Rec: 0.2143 - val_AUC: 0.7318
# Epoch 62/100
# 7/7 [==============================] - 3s 442ms/step - loss: 0.4360 - ACC: 1.0000 - Prec: 0.7353 - Rec: 0.4386 - AUC: 0.8371 - val_loss: 0.6594 - val_ACC: 1.0000 - val_Prec: 0.5789 - val_Rec: 0.1964 - val_AUC: 0.7175
# Epoch 63/100
# 7/7 [==============================] - 3s 441ms/step - loss: 0.4509 - ACC: 1.0000 - Prec: 0.7143 - Rec: 0.4386 - AUC: 0.8295 - val_loss: 0.5840 - val_ACC: 1.0000 - val_Prec: 0.5789 - val_Rec: 0.1964 - val_AUC: 0.7293
# Epoch 64/100
# 7/7 [==============================] - 3s 441ms/step - loss: 0.4645 - ACC: 1.0000 - Prec: 0.7419 - Rec: 0.4035 - AUC: 0.8145 - val_loss: 0.5694 - val_ACC: 1.0000 - val_Prec: 0.5455 - val_Rec: 0.2143 - val_AUC: 0.7222
# Epoch 65/100
# 7/7 [==============================] - 3s 446ms/step - loss: 0.4432 - ACC: 1.0000 - Prec: 0.7333 - Rec: 0.3860 - AUC: 0.8288 - val_loss: 0.5381 - val_ACC: 1.0000 - val_Prec: 0.5000 - val_Rec: 0.2500 - val_AUC: 0.7025
# Epoch 66/100
# 7/7 [==============================] - 3s 445ms/step - loss: 0.4515 - ACC: 1.0000 - Prec: 0.6667 - Rec: 0.3860 - AUC: 0.8288 - val_loss: 0.5408 - val_ACC: 1.0000 - val_Prec: 0.4815 - val_Rec: 0.2321 - val_AUC: 0.6998
# Epoch 67/100
# 7/7 [==============================] - 3s 443ms/step - loss: 0.4356 - ACC: 1.0000 - Prec: 0.7500 - Rec: 0.4737 - AUC: 0.8419 - val_loss: 0.5392 - val_ACC: 1.0000 - val_Prec: 0.5000 - val_Rec: 0.2321 - val_AUC: 0.7040
# Epoch 68/100
# 7/7 [==============================] - 3s 444ms/step - loss: 0.4438 - ACC: 1.0000 - Prec: 0.8182 - Rec: 0.4737 - AUC: 0.8281 - val_loss: 0.5482 - val_ACC: 1.0000 - val_Prec: 0.5200 - val_Rec: 0.2321 - val_AUC: 0.7037
# Epoch 69/100
# 7/7 [==============================] - 3s 449ms/step - loss: 0.4433 - ACC: 1.0000 - Prec: 0.7059 - Rec: 0.4211 - AUC: 0.8327 - val_loss: 0.5521 - val_ACC: 1.0000 - val_Prec: 0.5600 - val_Rec: 0.2500 - val_AUC: 0.7137
# Epoch 70/100
# 7/7 [==============================] - 3s 452ms/step - loss: 0.4338 - ACC: 1.0000 - Prec: 0.7353 - Rec: 0.4386 - AUC: 0.8453 - val_loss: 0.5662 - val_ACC: 1.0000 - val_Prec: 0.5769 - val_Rec: 0.2679 - val_AUC: 0.7196
# Epoch 71/100
# 7/7 [==============================] - 3s 457ms/step - loss: 0.4332 - ACC: 1.0000 - Prec: 0.7714 - Rec: 0.4737 - AUC: 0.8370 - val_loss: 0.5662 - val_ACC: 1.0000 - val_Prec: 0.5217 - val_Rec: 0.2143 - val_AUC: 0.7054
# Epoch 72/100
# 7/7 [==============================] - 3s 448ms/step - loss: 0.4202 - ACC: 1.0000 - Prec: 0.7429 - Rec: 0.4561 - AUC: 0.8580 - val_loss: 0.6200 - val_ACC: 1.0000 - val_Prec: 0.6316 - val_Rec: 0.2143 - val_AUC: 0.7215
# Epoch 73/100
# 7/7 [==============================] - 3s 446ms/step - loss: 0.4335 - ACC: 1.0000 - Prec: 0.7879 - Rec: 0.4561 - AUC: 0.8425 - val_loss: 0.5471 - val_ACC: 1.0000 - val_Prec: 0.4800 - val_Rec: 0.2143 - val_AUC: 0.7122
# Epoch 74/100
# 7/7 [==============================] - 3s 452ms/step - loss: 0.4257 - ACC: 1.0000 - Prec: 0.7188 - Rec: 0.4035 - AUC: 0.8476 - val_loss: 0.5637 - val_ACC: 1.0000 - val_Prec: 0.5385 - val_Rec: 0.2500 - val_AUC: 0.7305
# Epoch 75/100
# 7/7 [==============================] - 3s 456ms/step - loss: 0.4753 - ACC: 1.0000 - Prec: 0.7500 - Rec: 0.4737 - AUC: 0.8239 - val_loss: 0.5597 - val_ACC: 1.0000 - val_Prec: 0.4828 - val_Rec: 0.2500 - val_AUC: 0.7159
# Epoch 76/100
# 7/7 [==============================] - 3s 455ms/step - loss: 0.4223 - ACC: 1.0000 - Prec: 0.7273 - Rec: 0.4211 - AUC: 0.8509 - val_loss: 0.5422 - val_ACC: 1.0000 - val_Prec: 0.4516 - val_Rec: 0.2500 - val_AUC: 0.7078
# Epoch 77/100
# 7/7 [==============================] - 3s 457ms/step - loss: 0.4203 - ACC: 1.0000 - Prec: 0.7879 - Rec: 0.4561 - AUC: 0.8517 - val_loss: 0.5713 - val_ACC: 1.0000 - val_Prec: 0.5385 - val_Rec: 0.2500 - val_AUC: 0.7240
# Epoch 78/100
# 7/7 [==============================] - 3s 443ms/step - loss: 0.4298 - ACC: 1.0000 - Prec: 0.7500 - Rec: 0.4211 - AUC: 0.8422 - val_loss: 0.5510 - val_ACC: 1.0000 - val_Prec: 0.4865 - val_Rec: 0.3214 - val_AUC: 0.7032
# Epoch 79/100
# 7/7 [==============================] - 3s 453ms/step - loss: 0.4435 - ACC: 1.0000 - Prec: 0.7429 - Rec: 0.4561 - AUC: 0.8429 - val_loss: 0.5508 - val_ACC: 1.0000 - val_Prec: 0.4857 - val_Rec: 0.3036 - val_AUC: 0.7049
# Epoch 80/100
# 7/7 [==============================] - 3s 453ms/step - loss: 0.4257 - ACC: 1.0000 - Prec: 0.6944 - Rec: 0.4386 - AUC: 0.8571 - val_loss: 0.5595 - val_ACC: 1.0000 - val_Prec: 0.5000 - val_Rec: 0.2857 - val_AUC: 0.6991
# Epoch 81/100
# 7/7 [==============================] - 3s 448ms/step - loss: 0.4172 - ACC: 1.0000 - Prec: 0.7500 - Rec: 0.4737 - AUC: 0.8527 - val_loss: 0.5825 - val_ACC: 1.0000 - val_Prec: 0.4815 - val_Rec: 0.2321 - val_AUC: 0.6971
# Epoch 82/100
# 7/7 [==============================] - 3s 458ms/step - loss: 0.4294 - ACC: 1.0000 - Prec: 0.7500 - Rec: 0.4737 - AUC: 0.8407 - val_loss: 0.5521 - val_ACC: 1.0000 - val_Prec: 0.4722 - val_Rec: 0.3036 - val_AUC: 0.7047
# Epoch 83/100
# 7/7 [==============================] - 3s 448ms/step - loss: 0.4148 - ACC: 1.0000 - Prec: 0.6842 - Rec: 0.4561 - AUC: 0.8536 - val_loss: 0.5765 - val_ACC: 1.0000 - val_Prec: 0.4643 - val_Rec: 0.2321 - val_AUC: 0.7075
# Epoch 84/100
# 7/7 [==============================] - 3s 446ms/step - loss: 0.4181 - ACC: 1.0000 - Prec: 0.7714 - Rec: 0.4737 - AUC: 0.8494 - val_loss: 0.5855 - val_ACC: 1.0000 - val_Prec: 0.4839 - val_Rec: 0.2679 - val_AUC: 0.6927
# Epoch 85/100
# 7/7 [==============================] - 3s 450ms/step - loss: 0.4217 - ACC: 1.0000 - Prec: 0.7105 - Rec: 0.4737 - AUC: 0.8450 - val_loss: 0.5564 - val_ACC: 1.0000 - val_Prec: 0.4186 - val_Rec: 0.3214 - val_AUC: 0.6994
# Epoch 86/100
# 7/7 [==============================] - 3s 455ms/step - loss: 0.4155 - ACC: 1.0000 - Prec: 0.7714 - Rec: 0.4737 - AUC: 0.8660 - val_loss: 0.5907 - val_ACC: 1.0000 - val_Prec: 0.5185 - val_Rec: 0.2500 - val_AUC: 0.7091
# Epoch 87/100
# 7/7 [==============================] - 3s 445ms/step - loss: 0.4231 - ACC: 1.0000 - Prec: 0.7188 - Rec: 0.4035 - AUC: 0.8468 - val_loss: 0.5723 - val_ACC: 1.0000 - val_Prec: 0.4828 - val_Rec: 0.2500 - val_AUC: 0.7110
# Epoch 88/100
# 7/7 [==============================] - 3s 451ms/step - loss: 0.4124 - ACC: 1.0000 - Prec: 0.8276 - Rec: 0.4211 - AUC: 0.8596 - val_loss: 0.5877 - val_ACC: 1.0000 - val_Prec: 0.5556 - val_Rec: 0.2679 - val_AUC: 0.7172
# Epoch 89/100
# 7/7 [==============================] - 3s 445ms/step - loss: 0.4156 - ACC: 1.0000 - Prec: 0.7179 - Rec: 0.4912 - AUC: 0.8555 - val_loss: 0.6123 - val_ACC: 1.0000 - val_Prec: 0.5652 - val_Rec: 0.2321 - val_AUC: 0.7191
# Epoch 90/100
# 7/7 [==============================] - 3s 445ms/step - loss: 0.4206 - ACC: 1.0000 - Prec: 0.8235 - Rec: 0.4912 - AUC: 0.8596 - val_loss: 0.5579 - val_ACC: 1.0000 - val_Prec: 0.4706 - val_Rec: 0.2857 - val_AUC: 0.6996
# Epoch 91/100
# 7/7 [==============================] - 3s 447ms/step - loss: 0.4075 - ACC: 1.0000 - Prec: 0.7179 - Rec: 0.4912 - AUC: 0.8595 - val_loss: 0.5834 - val_ACC: 1.0000 - val_Prec: 0.4444 - val_Rec: 0.2857 - val_AUC: 0.6899
# Epoch 92/100
# 7/7 [==============================] - 3s 449ms/step - loss: 0.4251 - ACC: 1.0000 - Prec: 0.7368 - Rec: 0.4912 - AUC: 0.8495 - val_loss: 0.5918 - val_ACC: 1.0000 - val_Prec: 0.5000 - val_Rec: 0.2679 - val_AUC: 0.7208
# Epoch 93/100
# 7/7 [==============================] - 3s 444ms/step - loss: 0.3960 - ACC: 1.0000 - Prec: 0.7561 - Rec: 0.5439 - AUC: 0.8685 - val_loss: 0.6031 - val_ACC: 1.0000 - val_Prec: 0.5172 - val_Rec: 0.2679 - val_AUC: 0.7120
# Epoch 94/100
# 7/7 [==============================] - 3s 449ms/step - loss: 0.4177 - ACC: 1.0000 - Prec: 0.7179 - Rec: 0.4912 - AUC: 0.8575 - val_loss: 0.6262 - val_ACC: 1.0000 - val_Prec: 0.5769 - val_Rec: 0.2679 - val_AUC: 0.7238
# Epoch 95/100
# 7/7 [==============================] - 3s 447ms/step - loss: 0.4030 - ACC: 1.0000 - Prec: 0.7317 - Rec: 0.5263 - AUC: 0.8653 - val_loss: 0.7696 - val_ACC: 1.0000 - val_Prec: 0.6364 - val_Rec: 0.2500 - val_AUC: 0.6705
# Epoch 96/100
# 7/7 [==============================] - 3s 442ms/step - loss: 0.4215 - ACC: 1.0000 - Prec: 0.7368 - Rec: 0.4912 - AUC: 0.8555 - val_loss: 0.5759 - val_ACC: 1.0000 - val_Prec: 0.4839 - val_Rec: 0.2679 - val_AUC: 0.7191
# Epoch 97/100
# 7/7 [==============================] - 3s 441ms/step - loss: 0.4081 - ACC: 1.0000 - Prec: 0.7179 - Rec: 0.4912 - AUC: 0.8626 - val_loss: 0.5943 - val_ACC: 1.0000 - val_Prec: 0.5357 - val_Rec: 0.2679 - val_AUC: 0.7223
# Epoch 98/100
# 7/7 [==============================] - 3s 443ms/step - loss: 0.4129 - ACC: 1.0000 - Prec: 0.7436 - Rec: 0.5088 - AUC: 0.8573 - val_loss: 0.5666 - val_ACC: 1.0000 - val_Prec: 0.4250 - val_Rec: 0.3036 - val_AUC: 0.7138
# Epoch 99/100
# 7/7 [==============================] - 3s 461ms/step - loss: 0.4034 - ACC: 1.0000 - Prec: 0.7250 - Rec: 0.5088 - AUC: 0.8648 - val_loss: 0.5635 - val_ACC: 1.0000 - val_Prec: 0.3953 - val_Rec: 0.3036 - val_AUC: 0.7160
# Epoch 100/100
# 7/7 [==============================] - 3s 444ms/step - loss: 0.4002 - ACC: 1.0000 - Prec: 0.7073 - Rec: 0.5088 - AUC: 0.8577 - val_loss: 0.5764 - val_ACC: 1.0000 - val_Prec: 0.4043 - val_Rec: 0.3393 - val_AUC: 0.7000
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 405, 50)           11600
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 28)                8848
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 29
# =================================================================
# Total params: 20,477
# Trainable params: 20,477
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### <font color=#cd0000> Clasificación </font>

# %%
y_real = enc.inverse_transform(y_test)
y_pred = y_pred.astype('int')
y_pred = enc.inverse_transform(y_pred)
print(confusion_matrix(y_real, y_pred))
print(classification_report(y_real, y_pred, zero_division=0))
# Out:
# [[115  28]
#  [ 37  19]]
#               precision    recall  f1-score   support
#
#     abnormal       0.76      0.80      0.78       143
#       normal       0.40      0.34      0.37        56
#
#     accuracy                           0.67       199
#    macro avg       0.58      0.57      0.57       199
# weighted avg       0.66      0.67      0.66       199
# c:\Users\Javier\anaconda3\envs\tfg_env\lib\site-packages\sklearn\preprocessing\_label.py:154: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # <font color=#cd0000> Conclusiones </font>
# - Observamos resultados ligeramente mejores, en lo que a generalización se refiere, con respecto a RandomForest. No obstante, observamos que la red no ha sido capaz de extraer información significativa del espectrograma.
